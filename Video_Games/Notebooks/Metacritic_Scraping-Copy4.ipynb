# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as soup
import lxml
from bs4 import NavigableString
import re

# Must gather rating data for all the games without data in the ratings_df in the exploratory analysis notebook.
# Must gather positive, neutral, and negative ratings numbers for both users and critics as well as the
# metascore and userscore

no_rating_df = pd.read_csv("../Resources/games_to_get_ratings.csv")

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
browser = Browser("chrome", executable_path="/usr/local/bin/chromedriver", headless=True)

# %%
games_df = pd.read_csv("../Resources/vgsales.csv.zip")
list_of_games = games_df["Name"].values.tolist()

# %%
## Navigating to the correct page via the search bar using splinter is too slow. I will rewrite the code to manually 
# write in the url using string interpolation. 
# I will need to interpolate the correct console name as well into the url. Metacritics url structure is:
# "https://www.metacritic.com/game/{console}/{game}"

# %%
# must change game names into the proper format to be interpolated into the URL.

game_conversions= {
    "PSV":"playstation-vita",
    "DC":"dreamcast",
    "WiiU":"wii-u",
    "GC":"gamecube",
    "N64":"nintendo-64",
    "XB":"xbox",
    "PSP":"psp",
    "PS4":"playstation-4",
    "PS": "playstation",
    "Wii":"wii",
    "PS3": "playstation-3",
    "PS2":"playstation-2",
    "GBA":"game-boy-advance",
    "DS":"ds",
    "XB":"xbox",
    "X360":"xbox-360"
}

def convert_to_name(platform_abb):
    if platform_abb in game_conversions:
        full_platform= game_conversions[platform_abb]
    else:
        full_platform="other"
    return full_platform

# %%
# This actually shows that the vast majority of our data belongs to the consoles listed on metacritic, these "legacy consoles"
# Get rid of those games which fall into the "other" category under full_platform_name
games_df["full_platform_name"]= games_df["Platform"].map(convert_to_name)
games_df = games_df.loc[games_df["full_platform_name"]!="other"]

# %%
games_df["Name"].tolist()
# Out:
# ['Wii Sports',
#  'Mario Kart Wii',
#  'Wii Sports Resort',
#  'New Super Mario Bros.',
#  'Wii Play',
#  'New Super Mario Bros. Wii',
#  'Nintendogs',
#  'Mario Kart DS',
#  'Wii Fit',
#  'Wii Fit Plus',
#  'Kinect Adventures!',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: San Andreas',
#  'Brain Age: Train Your Brain in Minutes a Day',
#  'Pokemon Diamond/Pokemon Pearl',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: Vice City',
#  'Pokemon Ruby/Pokemon Sapphire',
#  'Pokemon Black/Pokemon White',
#  'Brain Age 2: More Training in Minutes a Day',
#  'Gran Turismo 3: A-Spec',
#  'Call of Duty: Modern Warfare 3',
#  'Call of Duty: Black Ops',
#  'Call of Duty: Black Ops 3',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Modern Warfare 2',
#  'Call of Duty: Modern Warfare 3',
#  'Grand Theft Auto III',
#  'Super Smash Bros. Brawl',
#  'Call of Duty: Black Ops',
#  'Animal Crossing: Wild World',
#  'Halo 3',
#  'Grand Theft Auto V',
#  'Pokemon HeartGold/Pokemon SoulSilver',
#  'Super Mario 64',
#  'Gran Turismo 4',
#  'Super Mario Galaxy',
#  'Grand Theft Auto IV',
#  'Gran Turismo',
#  'Gran Turismo 5',
#  'Call of Duty: Modern Warfare 2',
#  'Grand Theft Auto IV',
#  'Pokemon FireRed/Pokemon LeafGreen',
#  'Super Mario 64',
#  'Just Dance 3',
#  'Call of Duty: Ghosts',
#  'Halo: Reach',
#  'Mario Kart 64',
#  'Halo 4',
#  'Final Fantasy VII',
#  'Call of Duty: Ghosts',
#  'Just Dance 2',
#  'Gran Turismo 2',
#  'Call of Duty 4: Modern Warfare',
#  'Minecraft',
#  'Mario Party DS',
#  'The Elder Scrolls V: Skyrim',
#  'FIFA 16',
#  'Wii Party',
#  'Halo 2',
#  'Mario Party 8',
#  'Pokemon Black 2/Pokemon White 2',
#  'FIFA Soccer 13',
#  'GoldenEye 007',
#  'Mario & Sonic at the Olympic Games',
#  'Final Fantasy X',
#  'Final Fantasy VIII',
#  'Pokémon Platinum Version',
#  'Grand Theft Auto: Liberty City Stories',
#  'Super Mario Galaxy 2',
#  'Star Wars Battlefront (2015)',
#  'Call of Duty: Advanced Warfare',
#  'The Legend of Zelda: Ocarina of Time',
#  'Crash Bandicoot 2: Cortex Strikes Back',
#  'Call of Duty: World at War',
#  'Battlefield 3',
#  'The Legend of Zelda: Twilight Princess',
#  'Just Dance',
#  'Battlefield 3',
#  'Need for Speed Underground',
#  'Tekken 3',
#  'Crash Bandicoot 3: Warped',
#  'Super Smash Bros. Melee',
#  'Mario Kart 8',
#  'Fallout 4',
#  'Mario Kart: Double Dash!!',
#  'Just Dance 4',
#  'FIFA 14',
#  'Need for Speed Underground 2',
#  'Medal of Honor: Frontline',
#  "Uncharted 3: Drake's Deception",
#  'Crash Bandicoot',
#  'Zumba Fitness',
#  'Gears of War 2',
#  'Uncharted 2: Among Thieves',
#  'Call of Duty 4: Modern Warfare',
#  'FIFA 12',
#  'Big Brain Academy',
#  'Red Dead Redemption',
#  'FIFA 15',
#  'Donkey Kong Country Returns',
#  'The Elder Scrolls V: Skyrim',
#  "Assassin's Creed III",
#  'Halo: Combat Evolved',
#  'Pokémon Emerald Version',
#  'Kingdom Hearts',
#  'Halo 3: ODST',
#  'Red Dead Redemption',
#  'Super Mario Sunshine',
#  'Driver',
#  'Kinect Sports',
#  'Gears of War 3',
#  'Gears of War',
#  'Metal Gear Solid 2: Sons of Liberty',
#  'Metal Gear Solid 4: Guns of the Patriots',
#  'Metal Gear Solid',
#  'The Last of Us',
#  'Final Fantasy XII',
#  'LittleBigPlanet',
#  'Dragon Quest IX: Sentinels of the Starry Skies',
#  'LEGO Star Wars: The Complete Saga',
#  'Resident Evil 2',
#  'Tekken 2',
#  'Cooking Mama',
#  'Destiny',
#  "Assassin's Creed II",
#  'Super Smash Bros.',
#  "Assassin's Creed",
#  'Batman: Arkham City',
#  'Forza Motorsport 3',
#  'Monster Hunter Freedom Unite',
#  'Super Mario Advance',
#  'Mario Kart: Super Circuit',
#  'Super Mario World',
#  'Pokemon Stadium',
#  'Call of Duty: World at War',
#  'Crash Bandicoot: The Wrath of Cortex',
#  'Minecraft',
#  'Final Fantasy XIII',
#  "Assassin's Creed III",
#  'Final Fantasy IX',
#  'Final Fantasy X-2',
#  'Donkey Kong 64',
#  "Assassin's Creed II",
#  'Professor Layton and the Curious Village',
#  'Tomb Raider II',
#  'Madden NFL 2004',
#  'Dragon Quest VIII: Journey of the Cursed King',
#  'Super Mario Bros. 3',
#  'New Super Mario Bros. U',
#  'FIFA Soccer 13',
#  'The Legend of Zelda: Phantom Hourglass',
#  'Mario & Sonic at the Olympic Games',
#  'Medal of Honor: Rising Sun',
#  'Fable III',
#  'Guitar Hero II',
#  'Resident Evil 5',
#  'Grand Theft Auto: Vice City Stories',
#  'FIFA Soccer 11',
#  'Resident Evil',
#  "Tony Hawk's Pro Skater",
#  'Super Smash Bros. for Wii U and 3DS',
#  'Warzone 2100',
#  'Spyro the Dragon',
#  "Link's Crossbow Training",
#  'Guitar Hero III: Legends of Rock',
#  'Fallout 3',
#  'Pokemon Mystery Dungeon: Explorers of Time/Explorers of Darkness',
#  "Uncharted: Drake's Fortune",
#  'Madden NFL 06',
#  'LEGO Star Wars: The Complete Saga',
#  'Diddy Kong Racing',
#  'Monster Hunter Freedom 3',
#  'God of War III',
#  "Assassin's Creed",
#  'FIFA 15',
#  'Crash Team Racing',
#  'FIFA 17',
#  'Batman: Arkham City',
#  'Driver 2',
#  'The Simpsons: Hit & Run',
#  "Tony Hawk's Pro Skater 2",
#  'Animal Crossing: City Folk',
#  'The Lord of the Rings: The Two Towers',
#  'Forza Motorsport 4',
#  'Tomb Raider',
#  'Guitar Hero III: Legends of Rock',
#  'The Legend of Zelda: The Wind Waker',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Splatoon',
#  'The Last of Us',
#  'Guitar Hero III: Legends of Rock',
#  'Madden NFL 2005',
#  'Madden NFL 07',
#  'Spider-Man: The Movie',
#  'Dragon Quest VII: Warriors of Eden',
#  'Uncharted: The Nathan Drake Collection',
#  'Call of Duty: Advanced Warfare',
#  'God of War',
#  'Nintendo Land',
#  'Michael Jackson: The Experience',
#  "Tony Hawk's Pro Skater 3",
#  'Winning Eleven: Pro Evolution Soccer 2007',
#  'The Elder Scrolls IV: Oblivion',
#  'Need for Speed: Most Wanted',
#  'Resistance: Fall of Man',
#  'Kingdom Hearts II',
#  'FIFA 14',
#  'Call of Duty: Advanced Warfare',
#  'Fable II',
#  'Super Mario 3D World',
#  'Batman: Arkham Asylum',
#  "Assassin's Creed: Revelations",
#  'Namco Museum',
#  'Metal Gear Solid 3: Snake Eater',
#  'Daxter',
#  'FIFA Soccer 06',
#  'EyeToy Play',
#  "Uncharted 4: A Thief's End",
#  'Gran Turismo 5 Prologue',
#  "Assassin's Creed: Revelations",
#  'Street Fighter IV',
#  'FIFA 12',
#  'Frogger',
#  'Madden NFL 2003',
#  'Watch Dogs',
#  'FIFA Soccer 07',
#  'The Legend of Zelda: Skyward Sword',
#  'Carnival Games',
#  'Fallout: New Vegas',
#  'God of War II',
#  'Forza Motorsport 2',
#  'World Soccer Winning Eleven 9',
#  'Namco Museum Vol.3',
#  'Tekken Tag Tournament',
#  'Far Cry 4',
#  'Star Fox 64',
#  'Minecraft',
#  'Fallout 3',
#  'Professor Layton and the Diabolical Box',
#  'Left 4 Dead 2',
#  'Namco Museum: 50th Anniversary',
#  'EA Sports Active',
#  "Assassin's Creed: Unity",
#  "Tony Hawk's Underground",
#  "Assassin's Creed IV: Black Flag",
#  'MotorStorm',
#  'Tekken 5',
#  'Sports Champions',
#  'NBA 2K16',
#  'World Soccer Winning Eleven 8 International',
#  'Flash Focus: Vision Training in Minutes a Day',
#  'Namco Museum Vol.1',
#  "Mario & Luigi: Bowser's Inside Story",
#  'Big Brain Academy: Wii Degree',
#  'Batman: Arkham Knight',
#  'Mario & Sonic at the London 2012 Olympic Games',
#  'LEGO Indiana Jones: The Original Adventures',
#  "Resident Evil Director's Cut",
#  'Ratchet & Clank: Size Matters',
#  'Just Dance 2014',
#  'Super Paper Mario',
#  "Harry Potter and the Sorcerer's Stone",
#  'The Witcher 3: Wild Hunt',
#  'Resident Evil 3: Nemesis',
#  'Spyro: Year of the Dragon',
#  'FIFA Soccer 2005',
#  'Battlefield 4',
#  'MySims',
#  'Friend Collection',
#  "Tony Hawk's Pro Skater 4",
#  'Midnight Club 3: DUB Edition',
#  'Banjo-Kazooie',
#  'SOCOM: U.S. Navy SEALs',
#  'Guitar Hero: World Tour',
#  'Gran Turismo 6',
#  'Jak and Daxter: The Precursor Legacy',
#  'Pokemon Snap',
#  'FIFA Soccer 10',
#  'Pro Evolution Soccer 2008',
#  'Call of Duty: Ghosts',
#  'Resident Evil 4',
#  "Tom Clancy's The Division",
#  'Star Wars: Battlefront',
#  'The Simpsons: Road Rage',
#  'Cooking Mama 2: Dinner With Friends',
#  "Luigi's Mansion",
#  'Star Wars: Battlefront II',
#  'WWF SmackDown!',
#  'Croc: Legend of the Gobbos',
#  'Grand Theft Auto: Liberty City Stories',
#  'The Getaway',
#  'Tomb Raider III: Adventures of Lara Croft',
#  'James Bond 007: Agent Under Fire',
#  'LEGO Star Wars: The Video Game',
#  'Battlefield 4',
#  'FIFA Soccer 11',
#  'Rugrats in Paris: The Movie',
#  "Spyro 2: Ripto's Rage!",
#  'Left 4 Dead',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Resident Evil 5',
#  "Assassin's Creed: Brotherhood",
#  'Batman: Arkham Asylum',
#  'Clubhouse Games',
#  'FIFA Soccer 2004',
#  'Battlefield: Bad Company 2',
#  'Guitar Hero: On Tour',
#  'Far Cry 3',
#  'Borderlands',
#  'Tekken 4',
#  'Battlefield 4',
#  'LittleBigPlanet 2',
#  'Grand Theft Auto 2',
#  'Spider-Man 2',
#  'FIFA Soccer 2003',
#  'Crash Bash',
#  'LEGO Batman: The Videogame',
#  'Metal Gear Solid V: The Phantom Pain',
#  'The Legend of Zelda: Spirit Tracks',
#  'WWF War Zone',
#  "The Legend of Zelda: Majora's Mask",
#  'Professor Layton and the Unwound Future',
#  'Rugrats: Search For Reptar',
#  "Assassin's Creed IV: Black Flag",
#  'English Training: Have Fun Improving Your Skills!',
#  'James Bond 007: Nightfire',
#  'Ratchet & Clank',
#  'Mario Party 9',
#  'Star Wars Episode III: Revenge of the Sith',
#  'Max Payne',
#  'The Lord of the Rings: The Return of the King',
#  "Assassin's Creed Syndicate",
#  'True Crime: Streets of LA',
#  'Wii Music',
#  'Gran Turismo (PSP)',
#  'Tekken',
#  'L.A. Noire',
#  'Madden NFL 16',
#  '007: Tomorrow Never Dies',
#  'WWF SmackDown! 2: Know Your Role',
#  'Crisis Core: Final Fantasy VII',
#  'God of War: Chains of Olympus',
#  'Dance Central',
#  'Enter the Matrix',
#  'Super Mario Maker',
#  'Fallout: New Vegas',
#  'LEGO Batman: The Videogame',
#  'Rhythm Heaven',
#  'Ace Combat 04: Shattered Skies',
#  'Club Penguin: Elite Penguin Force',
#  'Animal Crossing',
#  'LEGO Batman: The Videogame',
#  'Sonic Rush',
#  'Resident Evil 6',
#  'FIFA Soccer 08',
#  'Spider-Man',
#  'Need for Speed III: Hot Pursuit',
#  'Star Wars Episode I Racer',
#  'Personal Trainer: Cooking',
#  'The Elder Scrolls IV: Oblivion',
#  'Heavy Rain',
#  'Mass Effect 2',
#  'FIFA 15',
#  'Dragon Ball Z: Budokai',
#  'Madden NFL 2002',
#  'Borderlands 2',
#  'Mass Effect 3',
#  'Kung Fu Panda',
#  'Far Cry 3',
#  'Epic Mickey',
#  'Saints Row 2',
#  'Rayman',
#  'Killzone 2',
#  "Tom Clancy's Splinter Cell",
#  'WWE SmackDown! Shut Your Mouth',
#  'NBA 2K13',
#  'Dragon Ball Z: Budokai Tenkaichi 3',
#  'wwe Smackdown vs. Raw 2006',
#  'Middle-Earth: Shadow of Mordor',
#  'World Soccer Winning Eleven 6 International',
#  'Devil May Cry',
#  'Battlefield: Bad Company 2',
#  'Sonic Heroes',
#  'Kirby Super Star Ultra',
#  'Hitman 2: Silent Assassin',
#  'Street Fighter IV',
#  'Wave Race 64',
#  'SOCOM II: U.S. Navy SEALs',
#  'WWE SmackDown! vs. RAW 2006',
#  'inFAMOUS',
#  'Pac-Man Collection',
#  'Mass Effect',
#  'WarioWare: Smooth Moves',
#  'Cooking Mama: Cook Off',
#  "Super Mario World 2: Yoshi's Island",
#  'FIFA 14',
#  'Sonic Mega Collection Plus',
#  'Sega Superstars Tennis',
#  'World Soccer Winning Eleven 7 International',
#  'Need for Speed: Most Wanted',
#  'Hot Shots Golf 3',
#  'Call of Duty: Finest Hour',
#  'Zumba Fitness 2',
#  'Syphon Filter',
#  'Imagine: Babyz',
#  'Colin McRae Rally',
#  'Madden NFL 13',
#  'The Elder Scrolls III: Morrowind',
#  'Mortal Kombat',
#  "Yoshi's Story",
#  "Skylanders: Spyro's Adventure",
#  'FIFA 16',
#  "Assassin's Creed: Brotherhood",
#  'BioShock',
#  'Madden NFL 10',
#  'Medal of Honor',
#  'WWE SmackDown! vs. Raw',
#  'Metroid Prime',
#  'Finding Nemo',
#  'Need for Speed: Hot Pursuit',
#  'Imagine: Fashion Designer',
#  'WWE SmackDown! Here Comes the Pain',
#  'Star Wars: The Force Unleashed',
#  "Yoshi's Island DS",
#  'Hot Shots Golf',
#  'Killzone 3',
#  "A Bug's Life",
#  'WWF SmackDown! Just Bring It',
#  'Mortal Kombat Trilogy',
#  'NBA Street',
#  'Professor Layton and the Last Specter',
#  'Jak II',
#  'inFAMOUS: Second Son',
#  'Ratchet & Clank: Going Commando',
#  'Tekken 6',
#  'The Sims',
#  'Sonic and the Secret Rings',
#  'Saints Row: The Third',
#  "Assassin's Creed IV: Black Flag",
#  'Pokémon Stadium 2',
#  'L.A. Noire',
#  'Call of Duty 3',
#  'The Legend of Zelda: A Link to the Past',
#  'Onimusha: Warlords',
#  'Mortal Kombat X',
#  'Mario Party',
#  'Madden NFL 12',
#  'LEGO Star Wars II: The Original Trilogy',
#  'Madden NFL 11',
#  'Mario vs. Donkey Kong: Mini-Land Mayhem!',
#  'Skate 3',
#  'Burnout 3: Takedown',
#  'Need for Speed: Shift',
#  'Final Fantasy XIII-2',
#  'Call Of Duty 2: Big Red One',
#  'Guitar Hero: World Tour',
#  'Medal of Honor',
#  'Fable',
#  'Hannah Montana',
#  "Tom Clancy's Splinter Cell",
#  'Skylanders Giants',
#  'Medal of Honor Heroes',
#  'Star Wars: Shadows of the Empire',
#  'LEGO Star Wars: The Complete Saga',
#  'Midnight Club: Street Racing',
#  'Pac-Man: Adventures in Time',
#  'Halo Wars',
#  'God of War Collection',
#  'ESPN NFL 2K5',
#  'Mario Strikers Charged',
#  'Medal of Honor',
#  'FIFA Soccer 10',
#  'NBA 2K12',
#  'Style Savvy',
#  'Harry Potter and the Chamber of Secrets',
#  'Super Mario All-Stars: Limited Edition',
#  'FIFA Soccer 09',
#  'Ratchet & Clank Future: Tools of Destruction',
#  'NBA Live 2005',
#  'LittleBigPlanet',
#  'Killzone: Shadow Fall',
#  'Ghostbusters: The Video Game (DS Version)',
#  'Monster Hunter Freedom 2',
#  'WWE SmackDown vs. RAW 2007',
#  'Ratchet & Clank: Up Your Arsenal',
#  'Art Academy',
#  'Dragon Age: Origins',
#  'Madden NFL 08',
#  'Sonic Adventure 2 Battle',
#  'Madden NFL 13',
#  'Pokémon Colosseum',
#  'Deca Sports',
#  'Madden NFL 09',
#  'Crazy Taxi',
#  'Perfect Dark',
#  'Game Party',
#  'Tomb Raider (2013)',
#  'Marvel: Ultimate Alliance',
#  'PES 2009: Pro Evolution Soccer',
#  'Mario Party 2',
#  'Saints Row: The Third',
#  'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#  'LEGO Harry Potter: Years 1-4',
#  'Mortal Kombat: Deadly Alliance',
#  'Resistance 2',
#  'Pure',
#  'Tomb Raider: The Last Revelation',
#  'NBA 2K13',
#  'Rock Band',
#  'NBA 2K14',
#  'Mario Party 4',
#  'uDraw Studio',
#  'Midnight Club: Los Angeles',
#  'Final Fantasy Tactics',
#  'Twisted Metal 2',
#  'Halo: Combat Evolved Anniversary',
#  'Need for Speed Carbon: Own the City',
#  "The Sims: Bustin' Out",
#  "Tom Clancy's Rainbow Six: Vegas 2",
#  'Sonic Adventure',
#  'pro evolution soccer 2011',
#  'Dragon Ball Z: Budokai 2',
#  'ATV Offroad Fury',
#  'Dino Crisis',
#  'Need for Speed: ProStreet',
#  'Tetris Plus',
#  "Frogger's Adventures: Temple of the Frog",
#  'Need for Speed (2015)',
#  'Zumba Fitness',
#  'LEGO Indiana Jones: The Original Adventures',
#  'Batman: Arkham Origins',
#  'Dead Island',
#  'Guitar Hero',
#  'LEGO Star Wars: The Complete Saga',
#  'Kinect: Disneyland Adventures',
#  'WCW/nWo Revenge',
#  'Bloodborne',
#  'NBA 2K15',
#  'Madden NFL 11',
#  'Yu-Gi-Oh! The Duelists of the Roses',
#  'Madden NFL 08',
#  'The Incredibles',
#  "Tony Hawk's Underground 2",
#  'Madden NFL 10',
#  'Kinect Sports: Season Two',
#  'LEGO Harry Potter: Years 1-4',
#  'Midnight Club: Los Angeles',
#  'Skylanders SWAP Force',
#  'WWE SmackDown vs Raw 2008',
#  'My Fitness Coach',
#  'Resident Evil - Code: Veronica X',
#  'The Sims 3',
#  'Just Dance Kids',
#  'Mario Tennis',
#  'Grand Theft Auto',
#  'James Bond 007: Everything or Nothing',
#  'WarioWare Touched!',
#  'Need For Speed: High Stakes',
#  'Cool Boarders 3',
#  'LEGO Marvel Super Heroes',
#  'Pokemon Ranger: Shadows of Almia',
#  'Dead Island',
#  'God of War: Ascension',
#  'Need for Speed Underground 2',
#  'Pro Evolution Soccer 2010',
#  'Just Dance 2015',
#  'FIFA Soccer 09',
#  'Star Wars: The Force Unleashed',
#  'Borderlands 2',
#  'TOCA Touring Car Championship',
#  "Sonic's Ultimate Genesis Collection",
#  'Super Monkey Ball: Banana Blitz',
#  'Kirby: Nightmare in Dream Land',
#  'Wario Land 4',
#  'Guitar Hero III: Legends of Rock',
#  'Call of Duty 3',
#  'Resident Evil 4',
#  'Minecraft',
#  "Onimusha 2: Samurai's Destiny",
#  'Cool Boarders 2',
#  'Paper Mario: The Thousand-Year Door',
#  'Madden NFL 12',
#  'Monster Hunter Tri',
#  'Dissidia: Final Fantasy',
#  'Sonic Advance',
#  'Spyro: Season of Ice',
#  'LEGO Indiana Jones: The Original Adventures',
#  'Dance Dance Revolution X2',
#  'New Super Luigi U',
#  'Prince of Persia: The Sands of Time',
#  'Scribblenauts',
#  'Need for Speed: Hot Pursuit',
#  'BioShock 2',
#  "Devil May Cry 3: Dante's Awakening Special Edition",
#  'Rock Band 2',
#  'Guitar Hero II',
#  'Sonic Unleashed',
#  "High School Musical: Makin' the Cut!",
#  'Pro Evolution Soccer 2012',
#  'Saints Row',
#  'Star Wars: Knights of the Old Republic',
#  'Hitman: Absolution',
#  'ATV Offroad Fury 2',
#  'Madden NFL 25',
#  'Pokemon Ranger',
#  'Mario & Luigi: Superstar Saga',
#  'Final Fantasy XIII',
#  'Star Wars: Rogue Squadron',
#  'Your Shape featuring Jenny McCarthy',
#  'Syphon Filter 2',
#  "Tom Clancy's Rainbow Six: Siege",
#  'Call of Duty: Roads to Victory',
#  'Dance Dance Revolution Extreme',
#  'Tetris DS',
#  'Final Fantasy Tactics Advance',
#  'Far Cry: Primal',
#  'Toy Story 3: The Video Game',
#  'Final Fantasy III',
#  "Kirby's Epic Yarn",
#  'Project Gotham Racing',
#  'NBA 2K12',
#  'Borderlands',
#  "Tony Hawk's Pro Skater",
#  'PES 2009: Pro Evolution Soccer',
#  'Need for Speed: Hot Pursuit 2',
#  'Mario Sports Mix',
#  'Rock Band',
#  'Dynasty Warriors 4',
#  'Mortal Kombat',
#  'Parasite Eve',
#  'Scooby-Doo! Night of 100 Frights',
#  'Project Gotham Racing (JP weekly sales)',
#  'Need for Speed: Most Wanted 5-1-0',
#  'Portal 2',
#  "Devil May Cry 3: Dante's Awakening",
#  'Derby Stallion',
#  'Dead Rising',
#  'Finding Nemo',
#  'NBA 2K11',
#  'Wipeout: The Game',
#  'The Sims 2: Pets',
#  'Battlefield: Hardline',
#  'Metal Gear Solid: Peace Walker',
#  'Tetris Worlds',
#  'Need For Speed: Undercover',
#  'Dance Dance Revolution: Hottest Party',
#  'Mario Party 5',
#  'Ghostbusters: The Video Game (DS Version)',
#  'Skate 3',
#  'Spec Ops: Airborne Commando',
#  'Kingdom Hearts: Birth by Sleep',
#  'UFC 2009 Undisputed',
#  'Dark Souls',
#  'Yu-Gi-Oh! The Eternal Duelist Soul',
#  'Need for Speed: ProStreet',
#  'The Sims 3',
#  "Tom Clancy's Splinter Cell: Conviction",
#  'Pokemon Mystery Dungeon: Red/Blue Rescue Team',
#  'The Incredibles',
#  'R4: Ridge Racer Type 4',
#  'SoulCalibur II',
#  'Need for Speed: ProStreet',
#  'Carnival Games',
#  'NBA 2K14',
#  'Pokémon Mystery Dungeon: Blue Rescue Team',
#  'Sonic Mega Collection',
#  'Diablo III',
#  'PGR4 - Project Gotham Racing 4',
#  'Kingdom Hearts 358/2 Days',
#  'Dance Central 2',
#  'Rayman Raving Rabbids: TV Party',
#  'SOCOM: U.S. Navy SEALs: Combined Assault',
#  "Peter Jackson's King Kong: The Official Game of the Movie",
#  'Donkey Kong Country',
#  'Need for Speed: The Run',
#  'Madden NFL 15',
#  '1080°: TenEighty Snowboarding',
#  'Just Dance 3',
#  'NBA Live 2004',
#  'Dead Space',
#  'Call of Duty 2',
#  'Madden NFL 15',
#  'Forza Horizon',
#  'TouchMaster',
#  'LEGO Marvel Super Heroes',
#  'DriveClub',
#  'Mortal Kombat vs. DC Universe',
#  'Tenchu: Stealth Assassins',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Chamber of Secrets',
#  'Resident Evil 6',
#  'Dragon Age: Inquisition',
#  'Sonic Classic Collection',
#  'Spyro: Enter the Dragonfly',
#  'Call of Duty: World at War',
#  'Devil May Cry 2',
#  'Burnout Paradise',
#  'BioShock Infinite',
#  'Hot Shots Golf: Open Tee',
#  'Kirby Squeak Squad',
#  "Tom Clancy's Rainbow Six: Vegas",
#  'Destiny',
#  'Crash Nitro Kart',
#  'Grand Theft Auto: San Andreas',
#  'NBA Street Vol. 2',
#  'Def Jam Vendetta',
#  'FIFA Soccer 09',
#  'Scooby Doo and the Cyber Chase',
#  'Dragon Ball Z: Budokai 3',
#  'Jet Moto 2',
#  "Tom Clancy's Ghost Recon",
#  'X-Men Legends',
#  'Batman: Arkham Origins',
#  'Guitar Hero: World Tour',
#  'Mortal Kombat vs. DC Universe',
#  'Watch Dogs',
#  'Mario Super Sluggers',
#  'Tomb Raider (2013)',
#  'Need for Speed: Shift',
#  'Monopoly',
#  'Red Faction',
#  'MX Unleashed',
#  'PaRappa The Rapper',
#  'Toy Story Mania!',
#  'Mario Party 3',
#  'Star Wars: The Force Unleashed',
#  'Game Party 2',
#  'Destiny: The Taken King',
#  'LEGO Star Wars III: The Clone Wars',
#  'Star Wars Rogue Leader: Rogue Squadron II',
#  'Max Payne 3',
#  'Need for Speed Rivals',
#  'Madden NFL 09',
#  'Ratchet & Clank Future: A Crack in Time',
#  'Yu-Gi-Oh! Forbidden Memories',
#  'Mortal Kombat: Deception',
#  'Hot Shots Golf 2',
#  'Medal of Honor: European Assault (All Region sales)',
#  'WCW Nitro',
#  'High School Musical: Sing It!',
#  'Star Fox Adventures',
#  'FIFA 2000',
#  'Dynasty Warriors 3',
#  'Madden NFL 06',
#  'Shrek 2',
#  'The Legend of Dragoon',
#  'Turok 2: Seeds of Evil',
#  'SingStar',
#  'LittleBigPlanet 3',
#  'NBA Live 2002',
#  'Phineas and Ferb',
#  'Chrono Cross',
#  'GoldenEye 007 (2010)',
#  'Jak 3',
#  'Rayman Raving Rabbids 2',
#  'Kingdom Hearts: Chain of Memories',
#  'inFAMOUS 2',
#  'Gran Turismo Concept 2001 Tokyo',
#  "Demon's Souls",
#  'NCAA Football 06',
#  'Hey You, Pikachu!',
#  '2 Games in 1: Sonic Advance & ChuChu Rocket!',
#  'Jet Moto',
#  'Just Cause 3',
#  'The Orange Box',
#  'Air Combat',
#  'Namco Museum',
#  'Metroid Prime 3: Corruption',
#  'Dragon Quest VI: Realms of Revelation',
#  'The Evil Within',
#  'DDRMAX2: Dance Dance Revolution',
#  'Crazy Taxi',
#  'Virtua Fighter 4',
#  'Sly 2: Band of Thieves',
#  'Guitar Hero: World Tour',
#  'Sonic Advance 2',
#  'Madden NFL 07',
#  'NBA 2K11',
#  'NFL GameDay 2000',
#  'Call of Duty: Black Ops 3',
#  'Beyond: Two Souls',
#  'Kinect Star Wars',
#  'Midnight Club II',
#  'Dragon Quest Monsters: Joker',
#  'SpongeBob SquarePants: SuperSponge',
#  'The Getaway: Black Monday',
#  'Just Cause 2',
#  "Dragon's Dogma",
#  'The Legend of Zelda: The Wind Waker',
#  '50 Cent: Bulletproof',
#  'High School Musical: Sing It!',
#  'Wii Party U',
#  'Madden NFL 25',
#  'Kirby 64: The Crystal Shards',
#  'Dead or Alive 3',
#  'UFC 2009 Undisputed',
#  'WWF Attitude',
#  'The SpongeBob SquarePants Movie',
#  'Golden Sun',
#  'Def Jam: Fight for NY',
#  "Tom Clancy's Ghost Recon",
#  'State of Emergency',
#  'BioShock Infinite',
#  'Hitman: Absolution',
#  '2 Games in 1 Double Pack: The Incredibles / Finding Nemo: The Continuing Adventures',
#  'Call of Duty: Black Ops 3',
#  'The Urbz: Sims in the City',
#  'FIFA Soccer 08',
#  'Star Wars: Starfighter',
#  'Madden NFL 2000',
#  'Kingdom Hearts',
#  'Star Wars: Battlefront',
#  'Pro Evolution Soccer',
#  'Crackdown',
#  'Cooking Mama 3: Shop & Chop',
#  'Dance Dance Revolution X',
#  '2 Games in 1: Disney Princess & The Lion King',
#  'Star Wars Episode I: The Phantom Menace',
#  'Xenosaga Episode I: Der Wille zur Macht',
#  'Portal 2',
#  'The Beatles: Rock Band',
#  'Sonic Colors',
#  "Cruis'n USA",
#  'Madden NFL 99',
#  'Diablo III',
#  'Uncharted: Golden Abyss',
#  'Destiny',
#  'SSX Tricky',
#  'Overwatch',
#  'Twisted Metal III',
#  'Disney Infinity',
#  'Crash Bandicoot: The Huge Adventure',
#  'Dishonored',
#  'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#  'The Order: 1886',
#  'The Elder Scrolls Online',
#  'Call of Duty: World at War Final Fronts',
#  'Imagine: Teacher',
#  'Madden NFL 2005',
#  'Star Ocean: Till The End of Time',
#  'Game Party 3',
#  'Toy Story 2: Buzz Lightyear to the Rescue!',
#  'Deal or No Deal',
#  'Ace Combat 5: The Unsung War',
#  'Need for Speed Underground',
#  'Kanshuu Nippon Joushikiryoku Kentei Kyoukai: Imasara Hito ni wa Kikenai Otona no Joushikiryoku Training DS',
#  'Tetris Worlds',
#  "Cabela's Big Game Hunter 2010",
#  'The Crew',
#  'FIFA Soccer 10',
#  'We Ski',
#  'Personal Trainer: Math',
#  "Kirby's Return to Dreamland",
#  'Ben 10: Protector of Earth',
#  'NCAA Football 07',
#  'SOCOM 3: U.S. Navy SEALs',
#  'Saints Row 2',
#  'Saints Row IV',
#  "Jampack Winter '99",
#  'Dragon Age: Origins',
#  'FIFA 16',
#  'WCW vs. nWo: World Tour',
#  'WCW/NWO Thunder',
#  "Harry Potter and the Sorcerer's Stone",
#  'Need For Speed: Undercover',
#  'Dragon Ball Z: The Legacy of Goku',
#  'Resident Evil 4',
#  'Call of Duty Black Ops: Declassified',
#  'Star Wars Battlefront: Renegade Squadron',
#  'World Championship Poker: Featuring Howard Lederer - All In',
#  'NFL GameDay 98',
#  'LEGO Batman 2: DC Super Heroes',
#  'Time Crisis',
#  'Star Wars The Clone Wars: Lightsaber Duels',
#  'MySims',
#  'Metroid Fusion',
#  'Shaun White Snowboarding: Road Trip',
#  'SSX 3',
#  'Big Beach Sports',
#  'Madden NFL 2001',
#  'Fight Night Round 3',
#  'Knack',
#  'Star Wars: Battlefront II',
#  "Tony Hawk's Pro Skater 3",
#  'Monsters, Inc.',
#  'PGR: Project Gotham Racing 2',
#  'Spy Hunter',
#  'NCAA Football 2004',
#  'SpongeBob SquarePants: Battle for Bikini Bottom',
#  'Dying Light',
#  'Heavenly Sword',
#  'SSX',
#  'Max Payne 3',
#  'NBA Ballers',
#  'Need for Speed Carbon',
#  'NBA Live 2003',
#  'Dragon Ball Z: Budokai Tenkaichi',
#  'Mario Party 6',
#  'Go Vacation',
#  'Dragon Quest V: Tenkuu no Hanayome',
#  'Army of Two',
#  'Dragon Quest IV: Chapters of the Chosen',
#  'Kirby & the Amazing Mirror',
#  'LEGO Pirates of the Caribbean: The Video Game',
#  "Tom Clancy's Rainbow Six",
#  'Tiger Woods PGA Tour 2003',
#  'NBA Live 06 (All region sales)',
#  'Prince of Persia: Warrior Within',
#  'Kinectimals',
#  'Until Dawn',
#  'ESPN NFL 2K5',
#  'Viva Pinata',
#  'Pikmin',
#  'Sonic Generations',
#  'Tiger Woods PGA Tour 2004',
#  'Ape Escape',
#  'NBA 2K15',
#  'NCAA Football 2005',
#  'Just Cause 2',
#  'Rock Band',
#  "Tony Hawk's American Wasteland (Old all region sales)",
#  'Rage',
#  'Mario Hoops 3 on 3',
#  'Kirby Air Ride',
#  'Sled Storm',
#  'Pokemon Battle Revolution',
#  'NFL Street 2',
#  'Gears of War: Judgment',
#  'Super Mario Strikers',
#  'Buzz! The Music Quiz',
#  "SpongeBob's Atlantis SquarePantis",
#  'Dance Dance Revolution: Hottest Party 2',
#  'Moshi Monsters: Moshling Zoo',
#  'Dollar Dash',
#  'Far Cry 2',
#  'F-1 World Grand Prix',
#  'Silent Hill',
#  'Dragon Quest V: Hand of the Heavenly Bride',
#  "No Man's Sky",
#  'Sonic Heroes',
#  'ESPN NBA 2K5',
#  'The Legend of Zelda: Twilight Princess',
#  'Soul Edge',
#  'Devil May Cry 4',
#  'Pro Evolution Soccer 2008',
#  'SoulCalibur IV',
#  'LEGO Harry Potter: Years 1-4',
#  'NASCAR 2000',
#  'Wolfenstein: The New Order',
#  'Carnival Games: Mini Golf',
#  'Guitar Hero: On Tour Decades',
#  'MySims Kingdom',
#  'Jampack Summer 2K',
#  'Need for Speed: Most Wanted',
#  'Guitar Hero 5',
#  'High School Musical 3: Senior Year',
#  'Hannah Montana: Music Jam',
#  'Pokemon Mystery Dungeon: Explorers of Sky',
#  'Spyro 2: Season of Flame',
#  'Pro Evolution Soccer 2010',
#  'NCAA Football 2002',
#  'Conflict: Desert Storm',
#  'Mario Party 7',
#  'Pro Evolution Soccer 2013',
#  "Smuggler's Run",
#  'Fight Night Round 3',
#  'Twisted Metal',
#  'Dark Souls III',
#  'Pokemon Pinball: Ruby & Sapphire',
#  'LEGO Marvel Super Heroes',
#  'Mafia II',
#  'Dishonored',
#  'Stuntman',
#  "Tom Clancy's Rainbow Six 3",
#  'Active Life: Outdoor Challenge',
#  'BioShock 2',
#  '007: The World is not Enough',
#  'Spider-Man 2: Enter: Electro',
#  'Star Wars: The Force Unleashed II',
#  'Ni no Kuni: Wrath of the White Witch',
#  'LEGO Battles: Ninjago',
#  'Mario Party 10',
#  'Resident Evil: The Umbrella Chronicles',
#  'Dark Cloud',
#  "Tom Clancy's Ghost Recon Advanced Warfighter",
#  'Disney Fairies: Tinker Bell',
#  'MVP Baseball 2005',
#  'Die Hard Trilogy',
#  'Fight Night Round 4',
#  'MySims Kingdom',
#  'The Simpsons Game',
#  'NFL GameDay 99',
#  'Call of Duty: Modern Warfare: Reflex Edition',
#  'Mario Golf: Toadstool Tour',
#  'Tiger Woods 99 PGA Tour Golf',
#  'Donkey Kong Country: Tropical Freeze',
#  'Dead Space 2',
#  'Sonic Rivals 2',
#  ...]

# %%
# This worked pretty well, but I will alter the code further see if I can increase my scraping success to fail ratio

# %%
problem_games = []
abberant_side_detail_games = []
game_info_list = []
counter = 1

# zip the two 
zipped_list =list(zip(games_df["full_platform_name"].tolist(),games_df["Name"].tolist()))

for platform, name in zipped_list[12000:15000]:
    game_scores = {}
    x = re.compile("\.|:|;|\s|&")
    edited_game_title= re.sub(x,"-", name).lower().replace("---","-").replace("--","-").replace("'", "")
    # periods at the end of the url will show up as a dash. This conditional is to get rid of it.
    if edited_game_title[-1] == "-":
        edited_game_title = edited_game_title[:-1]
        print(f"\nGAME TITLE: {edited_game_title}")
    else:
        print(f"\nGAME TITLE: {edited_game_title}")
    browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
    # fill in my search term to the Metacritic Browser and us "\n" to press "enter" and initialize search
    
    game_scores["Name"]=name
    
    html= browser.html
    my_soup = soup(html, "lxml")
    # Grabbing the Metascore
    try:
        metascore = my_soup.find("a", class_="metascore_anchor").get_text()
        game_scores["metascore"]= metascore
    except:
        problem_games.append(name)
        print('THIS IS A PROBLEM CHILD')
        continue
    # Grabbing the Userscore
    try:
        userscore_first = my_soup.find("div", class_="details side_details")
        user_score = userscore_first.select("div.metascore_w")[0].get_text()
        game_scores["user_score"]= user_score
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing the release data
    try:
        product_data = my_soup.find("div",class_="product_data")
        release_data = product_data.find("li", class_="summary_detail release_data")
        release_date = release_data.find("span",class_="data").get_text()
        game_scores["release_date"]=release_date
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing the positive, mixed, and negative critic review numbers
    try:
        critic_reviews = []
        positive_scores = my_soup.find("div",class_="distribution_wrap")
        x = positive_scores.select("ol.score_counts.hover_none span.count")
        for i in x:
            critic_reviews.append(i.get_text())
        game_scores["positive_critics"] = critic_reviews[0]
        game_scores["neutral_critics"]=critic_reviews[1]
        game_scores["negative_critics"]=critic_reviews[2]
    except:
        problem_games.append(name)
        print('THIS IS A PROBLEM CHILD')
        continue
    # Grabbing the positive, mixed, and negative user review numbers
    try:
        user_reviews = []
        user_scores = my_soup.find("div",class_="user_reviews_module")
        drilling_down = user_scores.find("div",class_="distribution_wrap")
        ordered_list_html = drilling_down.select("ol.score_counts.hover_none span.count")
        for i in ordered_list_html:
            user_reviews.append(i.get_text())
        game_scores["positive_users"] = user_reviews[0]
        game_scores["neutral_users"]=user_reviews[1]
        game_scores["negative_users"]=user_reviews[2]
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing side details
    try:
        side_details = my_soup.find_all("div", class_="details side_details")[1]
        unordered_list = side_details.select("ul.summary_details li")
        developer = unordered_list[0].find("span", class_="data").get_text()
        game_scores["developer"]=developer
        number_players = unordered_list[2].find("span",class_="data").get_text()
        game_scores["number_players"]=number_players
        rating = unordered_list[4].find("span", class_="data").get_text()
        game_scores["rating"]=rating
        game_info_list.append(game_scores)
        print('SUCCESSFUL')
        print(f"This is the {counter}th game in the list.")
        counter+=1
    except:
        abberant_side_detail_games.append(game_scores)
        print("SUCCESS but no side details")
        continue
# Out:
# GAME TITLE: kevin-van-dam-big-bass-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: stolen
# SUCCESSFUL
# This is the 1th game in the list.
#
# GAME TITLE: monster-high-new-ghoul-in-school
# SUCCESS but no side details
#
# GAME TITLE: glacier2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugby-challenge-3
# SUCCESSFUL
# This is the 2th game in the list.
#
# GAME TITLE: memories-off-6-t-wave
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: superstars-v8-racing
# SUCCESS but no side details
#
# GAME TITLE: hatsune-miku-project-diva-x
# SUCCESSFUL
# This is the 3th game in the list.
#
# GAME TITLE: bullet-girls-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pro-race-driver
# SUCCESSFUL
# This is the 4th game in the list.
#
# GAME TITLE: sleepover-party
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: 100-classic-games
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ide-yosuke-no-mahjong-kazoku
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wrc-fia-world-rally-championship
# SUCCESSFUL
# This is the 5th game in the list.
#
# GAME TITLE: quiz-mobile-gundam-toi-senshi-dx
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: r-type-command-(correct-us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: e-t-the-extra-terrestrial-interplanetary-mission
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: story-hour-fairy-tales
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dynasty-warriors-vol-2-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: countdown-vampires
# SUCCESSFUL
# This is the 6th game in the list.
#
# GAME TITLE: crypt-killer
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tokumei-sentai-go-busters
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dramatic-soccer-game-nippon-daihyou-senshu-ninarou!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-treasures-of-montezuma
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: battle-hunter
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: poed
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: heathcliff!-frantic-foto
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: adidas-power-soccer
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: darklight-conflict
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-advanced-adventure
# SUCCESSFUL
# This is the 7th game in the list.
#
# GAME TITLE: rabbids-land
# SUCCESS but no side details
#
# GAME TITLE: the-ripping-friends
# SUCCESS but no side details
#
# GAME TITLE: konami-arcade-classics
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hunter-x-hunter-wonder-adventure
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: super-army-war
# SUCCESSFUL
# This is the 8th game in the list.
#
# GAME TITLE: ao-no-exorcist-genkoku-no-labyrinth
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: echo-night-beyond
# SUCCESSFUL
# This is the 9th game in the list.
#
# GAME TITLE: minna-no-chizu
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: doom-ii-hell-on-earth
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: taikou-risshiden-v
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shin-hayarigami
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jikkyou-powerful-major-league
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: suzumiya-haruhi-no-tsuisou
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: zoo-hospital
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: evolution-skateboarding
# SUCCESSFUL
# This is the 10th game in the list.
#
# GAME TITLE: greg-hastings-tournament-paintball-maxd
# SUCCESSFUL
# This is the 11th game in the list.
#
# GAME TITLE: the-idolm@ster-must-songs-red-board-/-blue-board
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jikkyou-world-soccer-2002
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tenshou-gakuen-gekkouroku
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ski-doo-snowmobile-challenge
# SUCCESS but no side details
#
# GAME TITLE: aquanauts-holiday-kakusareta-kiroku
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: real-soccer-2008
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: little-red-riding-hoods-zombie-bbq
# SUCCESSFUL
# This is the 12th game in the list.
#
# GAME TITLE: texas-hold-em-poker-ds
# SUCCESSFUL
# This is the 13th game in the list.
#
# GAME TITLE: ducktales-remastered
# SUCCESS but no side details
#
# GAME TITLE: magical-starsign-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: big-mutha-truckers
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dt-carnage
# SUCCESS but no side details
#
# GAME TITLE: teenage-zombies-invasion-of-the-alien-brain-thingys
# SUCCESS but no side details
#
# GAME TITLE: ar-nosurge-ode-to-an-unborn-star
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ragnarok-odyssey
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugby-08
# SUCCESSFUL
# This is the 14th game in the list.
#
# GAME TITLE: gopets-vacation-island
# SUCCESSFUL
# This is the 15th game in the list.
#
# GAME TITLE: pia-carrot-e-youkoso!!-2-5
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cy-girls
# SUCCESSFUL
# This is the 16th game in the list.
#
# GAME TITLE: the-sum-of-all-fears
# SUCCESSFUL
# This is the 17th game in the list.
#
# GAME TITLE: da-capo-i-ii-plus-situation-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-of-tanks
# SUCCESS but no side details
#
# GAME TITLE: hisshou-pachinko*pachi-slot-kouryaku-series-ds-vol-5-shinseiki-evangelion-tamashii-no-kiseki
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bubble-bobble-double-shot
# SUCCESSFUL
# This is the 18th game in the list.
#
# GAME TITLE: minority-report-everybody-runs
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-hunter-frontier-online-season-9-0
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: winning-post-8
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: c-o-r-e
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: garfield-the-search-for-pooky
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugby-world-cup-2015
# SUCCESS but no side details
#
# GAME TITLE: chaos-wars
# SUCCESSFUL
# This is the 19th game in the list.
#
# GAME TITLE: steambot-chronicles
# SUCCESSFUL
# This is the 20th game in the list.
#
# GAME TITLE: toki-no-kizuna-sekigahara-kitan
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mr-driller
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: norn9-norn-+-nonette
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: super-hero-generation
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: simple-ds-series-vol-15-the-kanshikikan-2-aratanaru-8-tsu-no-jiken-wo-touch-seyo
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gumby-vs-the-astrobots
# SUCCESSFUL
# This is the 21th game in the list.
#
# GAME TITLE: hisshou-pachinko*pachi-slot-kouryaku-series-vol-13-shinseiki-evangelion-yakusoku-no-toki
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: scaler
# SUCCESSFUL
# This is the 22th game in the list.
#
# GAME TITLE: nhl-legacy
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: chaos-head-noah
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tears-to-tiara-anecdotes-the-secret-of-avalon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: legasista
# SUCCESSFUL
# This is the 23th game in the list.
#
# GAME TITLE: fatal-fury-battle-archives-volume-1
# SUCCESSFUL
# This is the 24th game in the list.
#
# GAME TITLE: harukanaru-toki-no-naka-de-3-unmei-no-meikyuu-aizouban
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rhapsody-a-musical-adventure
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-16
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: music-maker-rockstar
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fading-shadows
# SUCCESSFUL
# This is the 25th game in the list.
#
# GAME TITLE: formula-1-06
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: without-warning
# SUCCESSFUL
# This is the 26th game in the list.
#
# GAME TITLE: minna-de-jibun-no-setsumeisho-b-kata,-a-kata,-ab-kata,-o-kata
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: smashing-drive
# SUCCESSFUL
# This is the 27th game in the list.
#
# GAME TITLE: fighting-vipers-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: teenage-mutant-ninja-turtles-3-mutant-nightmare
# SUCCESSFUL
# This is the 28th game in the list.
#
# GAME TITLE: sudoku-ball-detective
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: castlevania-lords-of-shadow-reverie
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: napoleon-dynamite-the-game
# SUCCESSFUL
# This is the 29th game in the list.
#
# GAME TITLE: beatdown-fists-of-vengeance
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: enchanted-arms-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-force
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: onsei-kanjou-sokuteiki-kokoro-scan
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: clock-zero-shuuen-no-ichibyou-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: san-goku-shi-ds-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: trick-x-logic-season-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: challenge-me-word-puzzles
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hakuouki-zuisouroku
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-championship-pool-2004
# SUCCESSFUL
# This is the 30th game in the list.
#
# GAME TITLE: derby-tsuku-5-derby-uma-o-tsukurou!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jikkyou-powerful-major-league-2009
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sd-gundam-force-showdown!
# SUCCESS but no side details
#
# GAME TITLE: ray-gigant
# SUCCESS but no side details
#
# GAME TITLE: negima!?-3-jikanme-~koi-to-mahou-to-sekaiju-densetsu~
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: flow-urban-dance-uprising
# SUCCESS but no side details
#
# GAME TITLE: ailu-de-puzzle
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: true-pinball
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: janes-hotel
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: stadium-games
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rlh-run-like-hell
# SUCCESSFUL
# This is the 31th game in the list.
#
# GAME TITLE: power-play-pool
# SUCCESSFUL
# This is the 32th game in the list.
#
# GAME TITLE: obscure
# SUCCESSFUL
# This is the 33th game in the list.
#
# GAME TITLE: super-robot-taisen-scramble-commander-the-2nd
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mahjong-taikai
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: espgaluda-ii-black-label
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bratz-kidz
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hot-potato!
# SUCCESS but no side details
#
# GAME TITLE: kiniro-no-corda-2-f
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: swords
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: winter-sports-3-the-great-tournament
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: deception-iii-dark-delusion
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ultimate-game-room
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: penguins-of-madagascar
# SUCCESS but no side details
#
# GAME TITLE: half-minute-hero-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-kingdom-jewel-summoner
# SUCCESSFUL
# This is the 34th game in the list.
#
# GAME TITLE: cook-wars
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kuroshitsuji-phantom-ghost
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: petz-catz-playground
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pirates-duels-on-the-high-seas
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fushigi-no-dungeon-fuurai-no-shiren-5-fortune-tower-to-unmei-no-dice
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shin-koihime-musou-otome-ryouran-*-sangokushi-engi-shu-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mahjong-300
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-ant-bully
# SUCCESSFUL
# This is the 35th game in the list.
#
# GAME TITLE: sega-arcade-gallery
# SUCCESSFUL
# This is the 36th game in the list.
#
# GAME TITLE: crazy-machines
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: astrology-ds
# SUCCESS but no side details
#
# GAME TITLE: my-world,-my-way-(us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tao-adventure-curse-demon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: aegis-of-earth-protonovus-assault
# SUCCESS but no side details
#
# GAME TITLE: double-value!-atv-thunder-ridge-riders-/-monster-trucks-mayhem
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhra-drag-racing-countdown-to-the-championship
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: black-stone-magic-steel
# SUCCESSFUL
# This is the 37th game in the list.
#
# GAME TITLE: mlb-15-the-show
# SUCCESS but no side details
#
# GAME TITLE: puyo-pop-fever(us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: assassins-creed-chronicles-china
# SUCCESS but no side details
#
# GAME TITLE: harukanaru-toki-no-naka-de-maihitoyo
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: painkiller-hell-wars
# SUCCESSFUL
# This is the 38th game in the list.
#
# GAME TITLE: housekeeping
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: funkmaster-flexs-digital-hitz-factory
# SUCCESSFUL
# This is the 39th game in the list.
#
# GAME TITLE: greg-hastings-paintball-2
# SUCCESSFUL
# This is the 40th game in the list.
#
# GAME TITLE: sangoku-koi-senki-otome-no-heihou!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: batman-a-telltale-game-series
# SUCCESS but no side details
#
# GAME TITLE: hakuouki-zuisouroku-ds
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: detective-conan-prelude-from-the-past
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: luminous-arc-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: major-league-baseball-2k8
# SUCCESSFUL
# This is the 41th game in the list.
#
# GAME TITLE: rebel-raiders-operation-nighthawk
# SUCCESSFUL
# This is the 42th game in the list.
#
# GAME TITLE: turbo-super-stunt-squad
# SUCCESS but no side details
#
# GAME TITLE: zenkoku-dekotora-matsuri
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: adventure-time-explore-the-dungeon-because-i-dont-know!
# SUCCESS but no side details
#
# GAME TITLE: fast-furious-showdown
# SUCCESS but no side details
#
# GAME TITLE: alienators-evolution-continues
# SUCCESS but no side details
#
# GAME TITLE: onechanbara-z-kagura
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: marines-modern-urban-combat
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gekiatsu!!-pachi-game-tamashi-cr-evangelion-hajimari-no-fukuin
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: travel-coach-europe-1
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: top-gun-hard-lock
# SUCCESSFUL
# This is the 43th game in the list.
#
# GAME TITLE: mx-world-tour-featuring-jamie-little
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: xblaze-code-embryo
# SUCCESSFUL
# This is the 44th game in the list.
#
# GAME TITLE: the-idolmaster-gravure-for-you!-vol-4
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: redcard-20-03
# SUCCESSFUL
# This is the 45th game in the list.
#
# GAME TITLE: katekyoo-hitman-reborn!-ds-fate-of-heat-ii-unmei-no-futari
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: puyo-puyo-7
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: asterix-obelix-kick-buttix
# SUCCESSFUL
# This is the 46th game in the list.
#
# GAME TITLE: bounty-hounds
# SUCCESSFUL
# This is the 47th game in the list.
#
# GAME TITLE: care-bears-care-quest
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: even-in-a-game-listen-to-me-girls-i-am-your-father!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tokyo-majin-gakuen-kenfuuchou
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: boboboubo-boubobo-ougi-87-5-bakuretsu-hanage-shinken
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: zatch-bell!-electric-arena
# SUCCESSFUL
# This is the 48th game in the list.
#
# GAME TITLE: boulder-dash-rocks!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhra-drag-racing-countdown-to-the-championship
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: toca-race-driver-3
# SUCCESSFUL
# This is the 49th game in the list.
#
# GAME TITLE: daito-giken-premium-pachi-slot-collection-yoshimune
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: maximum-racing-drag-stock-racer
# SUCCESS but no side details
#
# GAME TITLE: sky-dancers
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: silent-scope
# SUCCESSFUL
# This is the 50th game in the list.
#
# GAME TITLE: resident-evil-4-hd
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-series-of-poker-tournament-of-champions-2007-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: clever-kids-pirates
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: yggdra-union-well-never-fight-alone
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tour-de-france-2014
# SUCCESS but no side details
#
# GAME TITLE: gekiatsu!!-pachi-game-tamashi-max-evangelion-7-x-seimei-no-kodou
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rapala-tournament-fishing!
# SUCCESSFUL
# This is the 51th game in the list.
#
# GAME TITLE: the-legend-of-heroes-trails-in-the-sky-sc-evolution
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wangan-midnight
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: espn-nba-2night-2002
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cabelas-dangerous-hunts-2
# SUCCESS but no side details
#
# GAME TITLE: kekkaishi-kokubourou-no-kage
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: trap-gunner-countdown-to-oblivion
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: suzumiya-haruhi-no-tsuisou
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: crouching-tiger,-hidden-dragon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: simple-ds-series-vol-8-the-kanshikikan-kinkyuu-shutsudou!!-jiken-genba-wo-touch-seyo
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: harukanaru-toki-no-naka-de-yumenoukihashi-special
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sabre-wulf
# SUCCESSFUL
# This is the 52th game in the list.
#
# GAME TITLE: tsuyo-kiss-mighty-heart
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gacharoku
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sx-superstar
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cake-mania-bakers-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: motogp
# SUCCESSFUL
# This is the 53th game in the list.
#
# GAME TITLE: zoo-vet-endangered-animals
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: driven
# SUCCESS but no side details
#
# GAME TITLE: red-faction-ii
# SUCCESSFUL
# This is the 54th game in the list.
#
# GAME TITLE: criminal-girls-2
# SUCCESSFUL
# This is the 55th game in the list.
#
# GAME TITLE: original-story-from-fairy-tail-gekitotsu!-kardia-daiseidou
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: who-wants-to-be-a-millionaire-1st-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: diabolik-lovers-dark-fate
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: battle-engine-aquila
# SUCCESSFUL
# This is the 56th game in the list.
#
# GAME TITLE: astonishia-story
# SUCCESSFUL
# This is the 57th game in the list.
#
# GAME TITLE: nobunagas-ambition-sphere-of-influence-sengoku-risshiden
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: special-forces-nemesis-strike
# SUCCESSFUL
# This is the 58th game in the list.
#
# GAME TITLE: womens-volleyball-championship
# SUCCESSFUL
# This is the 59th game in the list.
#
# GAME TITLE: junior-island-adventure
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jikkyou-powerful-pro-yakyuu-wii-ketteiban
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mx-vs-atv-supercross
# SUCCESSFUL
# This is the 60th game in the list.
#
# GAME TITLE: rakushou!-pachi-slot-sengen-5-rio-paradise
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: battle-assault-3-featuring-gundam-seed
# SUCCESSFUL
# This is the 61th game in the list.
#
# GAME TITLE: crimson-tears
# SUCCESSFUL
# This is the 62th game in the list.
#
# GAME TITLE: hayate-no-gotoku!-ojousama-produce-daisakusen-boku-iro-ni-somare!-oyashiki-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: batman-forever-the-arcade-game
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: electroplankton
# SUCCESSFUL
# This is the 63th game in the list.
#
# GAME TITLE: cabelas-outdoor-adventures
# SUCCESS but no side details
#
# GAME TITLE: makai-senki-disgaea-4-fuuka-desco-hen-hajime-mashita
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: backyard-nfl-football-2006
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: game-of-thrones-(telltale)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mashiro-iro-symphony-*mutsu-no-hana
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-guardians
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sunday-vs-magazine-shuuketsu!-choujou-daikessen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: an-american-tail-fievels-gold-rush
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dead-or-alive-xtreme-3-venus
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: diabolik-lovers-more-blood
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: magna-carta-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-italian-job
# SUCCESSFUL
# This is the 64th game in the list.
#
# GAME TITLE: crazy-chicken-star-karts
# SUCCESS but no side details
#
# GAME TITLE: super-dodgeball-brawlers-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: makai-senki-disgaea-portable-tsuushin-taisen-hajime-mashita
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: m-ms-shell-shocked
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: k-on!-after-school-live!!-hd-ver
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: metal-gear-solid-the-essential-collection-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: young-justice-legacy
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: 3d-baseball
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pachitte-chonmage-tatsujin-12-pachinko-ultraman
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dream-c-club-zero
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shining-stars
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tail-concerto
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-sum-of-all-fears
# SUCCESSFUL
# This is the 65th game in the list.
#
# GAME TITLE: james-pond-codename-robocod
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: night-head-the-labyrinth
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jojos-bizarre-adventure-eyes-of-heaven
# SUCCESSFUL
# This is the 66th game in the list.
#
# GAME TITLE: utawarerumono-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: everblue-2
# SUCCESSFUL
# This is the 67th game in the list.
#
# GAME TITLE: emma-at-the-farm
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nascar-heat-evolution
# SUCCESS but no side details
#
# GAME TITLE: higurashi-no-naku-koro-ni-kizuna-dai-san-kan-rasen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: safari-adventures-africa
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: summer-athletics-the-ultimate-challenge
# SUCCESSFUL
# This is the 68th game in the list.
#
# GAME TITLE: yumeiro-patissiere-my-sweets-cooking
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: daito-giken-koushiki-pachi-slot-simulator-yoshimune-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: clannad
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: maximum-racing-gp-classic-racing
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugby-league-live-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: powerslave
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: legend-of-the-dragon
# SUCCESSFUL
# This is the 69th game in the list.
#
# GAME TITLE: project-gotham-racing-2-(jp-weekly-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ukiyo-no-shishi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ct-special-forces
# SUCCESSFUL
# This is the 70th game in the list.
#
# GAME TITLE: fifa-world-cup-germany-2006
# SUCCESSFUL
# This is the 71th game in the list.
#
# GAME TITLE: jewel-master-cradle-of-rome
# SUCCESS but no side details
#
# GAME TITLE: beastly
# SUCCESS but no side details
#
# GAME TITLE: crash-time-autobahn-pusuit
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: earthworm-jim-2
# SUCCESSFUL
# This is the 72th game in the list.
#
# GAME TITLE: garfield-a-tale-of-two-kitties
# SUCCESSFUL
# This is the 73th game in the list.
#
# GAME TITLE: suujin-taisen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: driv3r
# SUCCESSFUL
# This is the 74th game in the list.
#
# GAME TITLE: street-supremacy
# SUCCESSFUL
# This is the 75th game in the list.
#
# GAME TITLE: house-m-d
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: yokai-watch-dance-just-dance-special-version
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: river-king-mystic-valley-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: winning-post-world
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jig-a-pix-wild-world
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: best-friends-tonight
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: super-hero-generation
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: -hack-sekai-no-mukou-ni-+-versus
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sea-park-tycoon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disney-sports-soccer
# SUCCESSFUL
# This is the 76th game in the list.
#
# GAME TITLE: mame-goma-honobo-no-nikki
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ultimate-block-party
# SUCCESSFUL
# This is the 77th game in the list.
#
# GAME TITLE: disneys-hide-sneak
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: super-robot-taisen-og-saga-masou-kishin-iii-pride-of-justice
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nobunaga-no-yabou-kakushin-with-power-up-kit
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: raw-danger!
# SUCCESSFUL
# This is the 78th game in the list.
#
# GAME TITLE: arthur-and-the-invisibles
# SUCCESSFUL
# This is the 79th game in the list.
#
# GAME TITLE: flipper-critters
# SUCCESSFUL
# This is the 80th game in the list.
#
# GAME TITLE: monster-rancher-hop-a-bout
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: foto-showdown
# SUCCESS but no side details
#
# GAME TITLE: custom-beat-battle-draglade-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gotouchi-kenkei-ds
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bikkuriman-daijiten
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: accel-world-ginyoku-no-kakusei
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: elf-bowling-1-2
# SUCCESSFUL
# This is the 81th game in the list.
#
# GAME TITLE: toy-shop
# SUCCESS but no side details
#
# GAME TITLE: gungriffon-allied-strike
# SUCCESSFUL
# This is the 82th game in the list.
#
# GAME TITLE: stacked-with-daniel-negreanu
# SUCCESSFUL
# This is the 83th game in the list.
#
# GAME TITLE: vitamin-x-evolution
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: saru!-get-you!-sarusaru-daisakusen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-flintstones-big-trouble-in-bedrock
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: captain-morgane-and-the-golden-turtle
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sekai-no-hate-made-itte-q!-chinjuu-hunter-mono-no-daibouken
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: silverlicious
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: majesty-2-the-fantasy-kingdom-sim
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gakusen-toshi-asterisk-festa-houka-kenran
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: beatmania-iidx-14-gold
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: popcap-arcade-vol-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: vegas-casino
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-high-new-ghoul-in-school
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: biker-mice-from-mars
# SUCCESS but no side details
#
# GAME TITLE: smart-girls-winter-wonderland
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tork-prehistoric-punk
# SUCCESSFUL
# This is the 84th game in the list.
#
# GAME TITLE: togainu-no-chi-true-blood
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: chicken-shoot-2
# SUCCESS but no side details
#
# GAME TITLE: battle-vs-chess
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pachinko-kamen-rider-shocker-zenmetsu-daisakusen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: underground-pool
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: accel-world-ginyoku-no-kakusei
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: classic-dungeon-fuyoku-no-masoujin
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragons-dogma-online
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: river-city-super-sports-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: my-pet-shop-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: exstetra
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: konami-classics-series-arcade-hits
# SUCCESSFUL
# This is the 85th game in the list.
#
# GAME TITLE: dodge-racing-charger-vs-challenger
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gokujou!!-mecha-mote-iinchou-mm-my-best-friend!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: atelier-sophie-the-alchemist-of-the-mysterious-book
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: singstar-chartbreaker
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hiiro-no-kakera-2-hisui-no-shizuku
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pro-yakyuu-spirits-5-kanzenban
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sorcery-saga-the-curse-of-the-great-curry-god
# SUCCESSFUL
# This is the 86th game in the list.
#
# GAME TITLE: singstar-fussballhits
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: a-good-librarian-like-a-good-shepherd-library-party
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dance-factory
# SUCCESSFUL
# This is the 87th game in the list.
#
# GAME TITLE: lego-legends-of-chima-lavals-journey
# SUCCESS but no side details
#
# GAME TITLE: montessori-music
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: totally-spies!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragonheart-fire-steel
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: chaos-head-love-chu*chu!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gal-gun-double-peace
# SUCCESS but no side details
#
# GAME TITLE: roadkill
# SUCCESSFUL
# This is the 88th game in the list.
#
# GAME TITLE: the-legend-of-heroes-iii-song-of-the-ocean
# SUCCESSFUL
# This is the 89th game in the list.
#
# GAME TITLE: dungeon-maker-hunting-ground
# SUCCESSFUL
# This is the 90th game in the list.
#
# GAME TITLE: mushihimesama-futari-ver-1-5
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: f1-2002
# SUCCESSFUL
# This is the 91th game in the list.
#
# GAME TITLE: toaru-majutsu-no-kagaku-no-ensemble
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: guilty-gear-xx-accent-core-plus
# SUCCESSFUL
# This is the 92th game in the list.
#
# GAME TITLE: starsky-hutch
# SUCCESS but no side details
#
# GAME TITLE: sitting-ducks
# SUCCESS but no side details
#
# GAME TITLE: brothers-conflict-brilliant-blue
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jojos-bizarre-adventure-eyes-of-heaven
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hajime-no-ippo-the-fighting!-(2014)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: eyeshield-21-field-saikyou-no-senshi-tachi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fullmetal-alchemist-brotherhood
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: to-loveru-trouble-waku-waku!-rinkangakkou-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: doodle-hex
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hakuoki-zuisouroku-omokage-hana
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: thinksmart-family!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: last-escort-club-katze
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: stacked-with-daniel-negreanu
# SUCCESSFUL
# This is the 93th game in the list.
#
# GAME TITLE: shin-koihime-musou-otome-ryouran-*-sangokushi-engi-wei-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: otometeki-koi-kakumei-*-love-revo
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: phantasy-star-online-2-episode-4-deluxe-package
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: timmy-time
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: infinite-stratos-2-ignition-hearts
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dr-muto
# SUCCESSFUL
# This is the 94th game in the list.
#
# GAME TITLE: airship-q
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: otomedius-gorgeous
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jikandia-the-timeless-land
# SUCCESS but no side details
#
# GAME TITLE: egg-mania-eggstreme-madness
# SUCCESSFUL
# This is the 95th game in the list.
#
# GAME TITLE: super-heroine-chronicle
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: boot-camp-academy
# SUCCESS but no side details
#
# GAME TITLE: kiniro-no-corda-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: darkstalkers-resurrection
# SUCCESSFUL
# This is the 96th game in the list.
#
# GAME TITLE: emergency!-disaster-rescue-squad
# SUCCESS but no side details
#
# GAME TITLE: suggoi!-arcana-heart-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mother-goose-no-himitsu-no-yakata
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: winning-post-7-2009
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: code-lyoko-quest-for-infinity
# SUCCESSFUL
# This is the 97th game in the list.
#
# GAME TITLE: away-shuffle-dungeon
# SUCCESSFUL
# This is the 98th game in the list.
#
# GAME TITLE: digimon-world-4
# SUCCESSFUL
# This is the 99th game in the list.
#
# GAME TITLE: bubble-bobble-evolution
# SUCCESSFUL
# This is the 100th game in the list.
#
# GAME TITLE: kekkaishi-kokubourou-shuurai
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shugo-chara!-amunonijiro-chara-change
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: galleon-islands-of-mystery
# SUCCESSFUL
# This is the 101th game in the list.
#
# GAME TITLE: renai-0-kilometer
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-sports-competition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: summon-night-6-lost-borders
# SUCCESSFUL
# This is the 102th game in the list.
#
# GAME TITLE: tantei-jinguuji-saburo-ds-kienai-kokoro
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sunny-garcia-surfing
# SUCCESSFUL
# This is the 103th game in the list.
#
# GAME TITLE: motorhead
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: alias-carnival!-sacrament
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nacho-libre
# SUCCESSFUL
# This is the 104th game in the list.
#
# GAME TITLE: stormlover
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gensou-suikoden-i-ii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gloria-union
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ebikore-photo-kano-kiss
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bad-apple-wars
# SUCCESS but no side details
#
# GAME TITLE: eyeshield-21-devilbats-devildays
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jyuzaengi-engetsu-sangokuden
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shin-sangoku-musou-online-kamishou-ranbu
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dancing-blade-ii-tears-of-eden
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kokoro-no-kokoron
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hiiro-no-kakera-3-aoikuro-no-kusabi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: beatmania-iidx-13-distorted
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: go!-go!-hypergrind
# SUCCESSFUL
# This is the 105th game in the list.
#
# GAME TITLE: keshisasu-kun-battle-kas-tival
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kaidan-restaurant-zoku!-shin-menu-100-sen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hot-pixel
# SUCCESSFUL
# This is the 106th game in the list.
#
# GAME TITLE: peak-performance
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dance-dance-revolution-hottest-party-5
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: who-wants-to-be-a-millionaire-2nd-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dokidoki-majo-shinpan!-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: s-l-a-i-steel-lancer-arena-international
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pet-alien-an-intergalactic-puzzlepalooza
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: freaky-flyers
# SUCCESSFUL
# This is the 107th game in the list.
#
# GAME TITLE: blokus-portable-steambot-championship
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: renai-revenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: zoboomafoo-leapin-lemurs!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: atelier-shallie-plus-alchemists-of-the-dusk-sea
# SUCCESSFUL
# This is the 108th game in the list.
#
# GAME TITLE: dennou-senki-virtual-on-force
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: graffiti-kingdom
# SUCCESSFUL
# This is the 109th game in the list.
#
# GAME TITLE: nettou!-powerful-koushien
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: great-edo-blacksmith
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: armored-core-sl-silent-line-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gotouchi-tetsudou-gotouchi-chara-to-nihon-zenkoku-no-tabi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: combat-elite-wwii-paratroopers
# SUCCESSFUL
# This is the 110th game in the list.
#
# GAME TITLE: to-loveru-trouble-doki-doki!-rinkaigakkou-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lethal-enforcers-i-ii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: klonoa-2-dream-champ-tournament
# SUCCESSFUL
# This is the 111th game in the list.
#
# GAME TITLE: minna-no-golf-jou-vol-1
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: teenage-mutant-ninja-turtles-mutants-in-manhattan
# SUCCESSFUL
# This is the 112th game in the list.
#
# GAME TITLE: cabelas-big-game-hunter-pro-hunts
# SUCCESS but no side details
#
# GAME TITLE: super-collapse!-ii
# SUCCESS but no side details
#
# GAME TITLE: ducati-world-racing-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: popn-music-14-fever!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: golden-nugget-casino-/-texas-hold-em-double-pack
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: judie-no-atelier-guramnat-no-renkinjutsu-toraware-no-morito
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lux-pain-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: smashing-drive
# SUCCESSFUL
# This is the 113th game in the list.
#
# GAME TITLE: senko-no-ronde-duo
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: starshot-space-circus-fever
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: charlie-blasts-territory
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: big-mountain-2000
# SUCCESS but no side details
#
# GAME TITLE: tokimeki-memorial-girls-side-1st-love-plus
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cima-the-enemy
# SUCCESSFUL
# This is the 114th game in the list.
#
# GAME TITLE: n+
# SUCCESSFUL
# This is the 115th game in the list.
#
# GAME TITLE: katekyoo-hitman-reborn!-kizuna-no-tag-battle
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: code-geass-hangyaku-no-lelouch
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hudson-x-greeeen-live!?-deeees!?
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: marble-madness-/-klax
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: downstream-panic!
# SUCCESSFUL
# This is the 116th game in the list.
#
# GAME TITLE: dj-max-portable-3
# SUCCESS but no side details
#
# GAME TITLE: suzumiya-haruhi-no-chokuretsu
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-idolmaster-gravure-for-you!-vol-5
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: s-y-k-renshouden
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hiiro-no-kakera-shin-tamayori-hime-denshou-piece-of-future
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: d-c-i-f-da-capo-innocent-finale
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: galaxy-angel-ii-mugen-kairou-no-kagi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nectaris-military-madness
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tenka-bito
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: brahma-force-the-assault-on-beltlogger-9
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: petz-dolphinz-encounter
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: star-trek-tactical-assault
# SUCCESSFUL
# This is the 117th game in the list.
#
# GAME TITLE: katekyoo-hitman-reborn!-ds-ore-ga-boss!-saikyou-family-taisen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: samurai-spirits-tenkaichi-kenkakuden
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: robo-pit
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: emily-archer-and-the-curse-of-tutankhamun
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: story-hour-adventures
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: muv-luv-alternative-total-eclipse
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: r-type-iii-the-third-lightning
# SUCCESSFUL
# This is the 118th game in the list.
#
# GAME TITLE: hakuouki
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: princess-natasha-student,-secret-agent,-princess
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: atomic-betty
# SUCCESS but no side details
#
# GAME TITLE: monster-hunter-frontier-online-season-10
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: robin-hood-defender-of-the-crown
# SUCCESSFUL
# This is the 119th game in the list.
#
# GAME TITLE: street-jam-basketball
# SUCCESSFUL
# This is the 120th game in the list.
#
# GAME TITLE: master-of-monsters-disciples-of-gaia
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: armored-core-last-raven-portable
# SUCCESSFUL
# This is the 121th game in the list.
#
# GAME TITLE: sd-gundam-gashapon-wars
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: curious-george
# SUCCESSFUL
# This is the 122th game in the list.
#
# GAME TITLE: disneys-aladdin
# SUCCESSFUL
# This is the 123th game in the list.
#
# GAME TITLE: virtual-pool-tournament-edition
# SUCCESSFUL
# This is the 124th game in the list.
#
# GAME TITLE: kung-fu-panda-showdown-of-legendary-legends
# SUCCESS but no side details
#
# GAME TITLE: nippon-no-asoko-de
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: maplestory-ds
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: phantasy-star-online-2-episode-3-deluxe-package
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pimp-my-ride-street-racing
# SUCCESS but no side details
#
# GAME TITLE: lets-dance-with-mel-b
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: popeye-rush-for-spinach
# SUCCESSFUL
# This is the 125th game in the list.
#
# GAME TITLE: culdcept
# SUCCESSFUL
# This is the 126th game in the list.
#
# GAME TITLE: beatmania-iidx-15-dj-troopers
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: heathcliff!-the-fast-and-the-furriest
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hyperdimension-neptunia-vs-sega-hard-girls-yume-no-gattai-special
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: planet-of-the-apes
# SUCCESSFUL
# This is the 127th game in the list.
#
# GAME TITLE: gekiatsu!!-pachi-game-tamashi-vol-1-cr-evangelion-shinjitsu-no-tsubasa
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: worms
# SUCCESSFUL
# This is the 128th game in the list.
#
# GAME TITLE: drake-josh-talent-showdown
# SUCCESSFUL
# This is the 129th game in the list.
#
# GAME TITLE: real-world-golf
# SUCCESSFUL
# This is the 130th game in the list.
#
# GAME TITLE: winx-club-rockstars
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: oumagatoki-kaidan-romance
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kung-fu-panda-legendary-warriors
# SUCCESS but no side details
#
# GAME TITLE: mahjong-kakutou-club-zenkoku-taisenban
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hayate-no-gotoku!-nightmare-paradise
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-08
# SUCCESSFUL
# This is the 131th game in the list.
#
# GAME TITLE: secret-files-2-puritas-cordis
# SUCCESSFUL
# This is the 132th game in the list.
#
# GAME TITLE: nanashi-no-game-me
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: heroes-of-hellas-2-olympia
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bladestorm-nightmare
# SUCCESSFUL
# This is the 133th game in the list.
#
# GAME TITLE: natgeo-challenge!-wild-life
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: higurashi-no-naku-koro-ni-iki
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dream-pinball-3d
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dice-dna-integrated-cybernetic-enterprises
# SUCCESSFUL
# This is the 134th game in the list.
#
# GAME TITLE: treasure-gaust-gaust-diver-crimson-red-/-deep-purple
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: megpoid-the-music#
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wallace-gromit-in-project-zoo
# SUCCESSFUL
# This is the 135th game in the list.
#
# GAME TITLE: rugby-league-live
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: grid-runner
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: saihai-no-yukue
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: metal-dungeon
# SUCCESSFUL
# This is the 136th game in the list.
#
# GAME TITLE: drome-racers
# SUCCESSFUL
# This is the 137th game in the list.
#
# GAME TITLE: guitar-freaks-v-drummania-v
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tago-akira-no-atama-no-taisou-dai-1-shuu-nazotoki-sekai-isshuu-ryokou
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: driver-parallel-lines
# SUCCESSFUL
# This is the 138th game in the list.
#
# GAME TITLE: gekido-advance-kintaros-revenge
# SUCCESSFUL
# This is the 139th game in the list.
#
# GAME TITLE: ozmafia!!-vivace
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: girls-only
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: future-tactics-the-uprising
# SUCCESS but no side details
#
# GAME TITLE: power-poke-dash
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hisshou-pachinko*pachi-slot-kouryaku-series-ds-vol-4-shinseiki-evangelion-saigo-no-mono
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: detective-opera-milky-holmes-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: turn-it-around
# SUCCESSFUL
# This is the 140th game in the list.
#
# GAME TITLE: blaze-union-story-to-reach-the-future
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: race-driver-2006
# SUCCESSFUL
# This is the 141th game in the list.
#
# GAME TITLE: higurashi-no-naku-koro-ni-kizuna-dai-yon-kan-kizuna
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: buffy-the-vampire-slayer-wrath-of-the-darkhul-king
# SUCCESSFUL
# This is the 142th game in the list.
#
# GAME TITLE: nisekoi-yomeiri!?
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: new-tokyo-legacy-operation-babel
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gekiatsu!!-pachi-game-tamashi-vol-2-cr-evangelion-shinjitsu-no-tsubasa
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugby-league-live-3
# SUCCESS but no side details
#
# GAME TITLE: triple-pack-xbox-live-arcade-compilation
# SUCCESS but no side details
#
# GAME TITLE: 101-in-1-sports-party-megamix
# SUCCESSFUL
# This is the 143th game in the list.
#
# GAME TITLE: roadsters
# SUCCESS but no side details
#
# GAME TITLE: the-croods-prehistoric-party!
# SUCCESS but no side details
#
# GAME TITLE: exist-archive-the-other-side-of-the-sky
# SUCCESSFUL
# This is the 144th game in the list.
#
# GAME TITLE: deathsmiles-ii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: calcio-bit
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: whiteout
# SUCCESSFUL
# This is the 145th game in the list.
#
# GAME TITLE: hyakumanton-no-bara-bara
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: galaxy-angel-ii-zettairyouiki-no-tobira
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: 1000-cooking-recipes-from-elle-à-table
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hajime-no-ippo-the-fighting
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: merv-griffins-crosswords
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spectral-souls-resurrection-of-the-ethereal-empires
# SUCCESSFUL
# This is the 146th game in the list.
#
# GAME TITLE: sokukoku-no-kusabi-hiiro-no-kakera-3-portable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: syberia-ii
# SUCCESSFUL
# This is the 147th game in the list.
#
# GAME TITLE: popcap-hits!-vol-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ao-no-kanata-no-four-rhythm
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: motor-trend-presents-lotus-challenge
# SUCCESSFUL
# This is the 148th game in the list.
#
# GAME TITLE: trine-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bleach-ds-4th-flame-bringer
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pacific-liberator
# SUCCESS but no side details
#
# GAME TITLE: parfait
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tago-akira-no-atama-no-taisou-dai-2-shuu-ginga-oudan-nazotoki-adventure
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-king-of-fighters-portable-94~98-chapter-of-orochi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: puzzle-challenge-crosswords-and-more!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nisenochigiri-omoide-no-saki-e
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugby-league-live
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: in-cold-blood
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mega-minis-volume-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kamigami-no-asobi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fireblade
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kong-king-of-atlantis
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ganbare-goemon-toukai-douchuu-ooedo-tengurigaeshi-no-maki
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wrestle-angels-survivor-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: onechanbara-z-kagura
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-king-of-fighters-02/03
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: espn-winter-x-games-snowboarding-2002
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: betty-boops-double-shift
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tsuku-monogatari
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6ed560ae9058> in <module>
#      17     else:
#      18         print(f"\nGAME TITLE: {edited_game_title}")
# ---> 19     browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
#      20     # fill in my search term to the Metacritic Browser and us "\n" to press "enter" and initialize search
#      21
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py in visit(self, url)
#     285
#     286     def visit(self, url):
# --> 287         self.driver.get(url)
#     288
#     289     def back(self):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/remote_connection.py in patch_request(self, *args, **kwargs)
#      21     for _ in range(3):
#      22         try:
# ---> 23             return old_request(self, *args, **kwargs)
#      24         except (socket.error, HTTPException, IOError, OSError, MaxRetryError) as exc:
#      25             exception = exc
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
game_side_details = []
problem_games = []
abberant_side_detail_games = []
game_info_list = []
counter = 1

# zip the two 
zipped_list =list(zip(games_df["full_platform_name"].tolist(),games_df["Name"].tolist()))


for platform, name in zipped_list:
    my_details = {}
    x = re.compile("\.|:|;|\s|&")
    edited_game_title= re.sub(x,"-", name).lower().replace("---","-").replace("--","-").replace("'", "")
    # periods at the end of the url will show up as a dash. This conditional is to get rid of it.
    if edited_game_title[-1] == "-":
        edited_game_title = edited_game_title[:-1]
        print(f"\nGAME TITLE: {edited_game_title}")
    else:
        print(f"\nGAME TITLE: {edited_game_title}")
    browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
    my_details["Name"]=name
    
    html= browser.html
    my_soup = soup(html, "lxml")
    # Grabbing side details
    try:
        side_details = my_soup.find_all("div", class_="details side_details")[1]
        unordered_list = side_details.select("ul.summary_details li")
        try:
            developer = unordered_list[0].find("span", class_="data").get_text()
            my_details["developer"]=developer
        except:
            pass
        try:
            number_players = unordered_list[2].find("span",class_="data").get_text()
            my_details["number_players"]=number_players
        except:
            pass
        try:
            rating = unordered_list[4].find("span", class_="data").get_text()
            my_details["rating"]=rating
        except:
            pass
        game_side_details.append(my_details)
        print('SUCCESSFUL')
        print(f"This is the {counter}th game in the list.")
        counter+=1
    except:
        abberant_side_detail_games.append(name)
        print("SUCCESS but no side details")
        continue
# Out:
# GAME TITLE: wii-sports
# SUCCESSFUL
# This is the 1th game in the list.
#
# GAME TITLE: mario-kart-wii
# SUCCESSFUL
# This is the 2th game in the list.
#
# GAME TITLE: wii-sports-resort
# SUCCESSFUL
# This is the 3th game in the list.
#
# GAME TITLE: new-super-mario-bros
# SUCCESSFUL
# This is the 4th game in the list.
#
# GAME TITLE: wii-play
# SUCCESSFUL
# This is the 5th game in the list.
#
# GAME TITLE: new-super-mario-bros-wii
# SUCCESSFUL
# This is the 6th game in the list.
#
# GAME TITLE: nintendogs
# SUCCESS but no side details
#
# GAME TITLE: mario-kart-ds
# SUCCESSFUL
# This is the 7th game in the list.
#
# GAME TITLE: wii-fit
# SUCCESSFUL
# This is the 8th game in the list.
#
# GAME TITLE: wii-fit-plus
# SUCCESSFUL
# This is the 9th game in the list.
#
# GAME TITLE: kinect-adventures!
# SUCCESSFUL
# This is the 10th game in the list.
#
# GAME TITLE: grand-theft-auto-v
# SUCCESSFUL
# This is the 11th game in the list.
#
# GAME TITLE: grand-theft-auto-san-andreas
# SUCCESSFUL
# This is the 12th game in the list.
#
# GAME TITLE: brain-age-train-your-brain-in-minutes-a-day
# SUCCESSFUL
# This is the 13th game in the list.
#
# GAME TITLE: pokemon-diamond/pokemon-pearl
# SUCCESS but no side details
#
# GAME TITLE: grand-theft-auto-v
# SUCCESSFUL
# This is the 14th game in the list.
#
# GAME TITLE: grand-theft-auto-vice-city
# SUCCESSFUL
# This is the 15th game in the list.
#
# GAME TITLE: pokemon-ruby/pokemon-sapphire
# SUCCESS but no side details
#
# GAME TITLE: pokemon-black/pokemon-white
# SUCCESS but no side details
#
# GAME TITLE: brain-age-2-more-training-in-minutes-a-day
# SUCCESSFUL
# This is the 16th game in the list.
#
# GAME TITLE: gran-turismo-3-a-spec
# SUCCESSFUL
# This is the 17th game in the list.
#
# GAME TITLE: call-of-duty-modern-warfare-3
# SUCCESSFUL
# This is the 18th game in the list.
#
# GAME TITLE: call-of-duty-black-ops
# SUCCESSFUL
# This is the 19th game in the list.
#
# GAME TITLE: call-of-duty-black-ops-3
# SUCCESS but no side details
#
# GAME TITLE: call-of-duty-black-ops-ii
# SUCCESSFUL
# This is the 20th game in the list.
#
# GAME TITLE: call-of-duty-black-ops-ii
# SUCCESSFUL
# This is the 21th game in the list.
#
# GAME TITLE: call-of-duty-modern-warfare-2
# SUCCESSFUL
# This is the 22th game in the list.
#
# GAME TITLE: call-of-duty-modern-warfare-3
# SUCCESSFUL
# This is the 23th game in the list.
#
# GAME TITLE: grand-theft-auto-iii
# SUCCESSFUL
# This is the 24th game in the list.
#
# GAME TITLE: super-smash-bros-brawl
# SUCCESSFUL
# This is the 25th game in the list.
#
# GAME TITLE: call-of-duty-black-ops
# SUCCESSFUL
# This is the 26th game in the list.
#
# GAME TITLE: animal-crossing-wild-world
# SUCCESSFUL
# This is the 27th game in the list.
#
# GAME TITLE: halo-3
# SUCCESSFUL
# This is the 28th game in the list.
#
# GAME TITLE: grand-theft-auto-v
# SUCCESSFUL
# This is the 29th game in the list.
#
# GAME TITLE: pokemon-heartgold/pokemon-soulsilver
# SUCCESS but no side details
#
# GAME TITLE: super-mario-64
# SUCCESSFUL
# This is the 30th game in the list.
#
# GAME TITLE: gran-turismo-4
# SUCCESSFUL
# This is the 31th game in the list.
#
# GAME TITLE: super-mario-galaxy
# SUCCESSFUL
# This is the 32th game in the list.
#
# GAME TITLE: grand-theft-auto-iv
# SUCCESSFUL
# This is the 33th game in the list.
#
# GAME TITLE: gran-turismo
# SUCCESSFUL
# This is the 34th game in the list.
#
# GAME TITLE: gran-turismo-5
# SUCCESSFUL
# This is the 35th game in the list.
#
# GAME TITLE: call-of-duty-modern-warfare-2
# SUCCESSFUL
# This is the 36th game in the list.
#
# GAME TITLE: grand-theft-auto-iv
# SUCCESSFUL
# This is the 37th game in the list.
#
# GAME TITLE: pokemon-firered/pokemon-leafgreen
# SUCCESS but no side details
#
# GAME TITLE: super-mario-64
# SUCCESS but no side details
#
# GAME TITLE: just-dance-3
# SUCCESSFUL
# This is the 38th game in the list.
#
# GAME TITLE: call-of-duty-ghosts
# SUCCESSFUL
# This is the 39th game in the list.
#
# GAME TITLE: halo-reach
# SUCCESSFUL
# This is the 40th game in the list.
#
# GAME TITLE: mario-kart-64
# SUCCESSFUL
# This is the 41th game in the list.
#
# GAME TITLE: halo-4
# SUCCESSFUL
# This is the 42th game in the list.
#
# GAME TITLE: final-fantasy-vii
# SUCCESSFUL
# This is the 43th game in the list.
#
# GAME TITLE: call-of-duty-ghosts
# SUCCESSFUL
# This is the 44th game in the list.
#
# GAME TITLE: just-dance-2
# SUCCESSFUL
# This is the 45th game in the list.
#
# GAME TITLE: gran-turismo-2
# SUCCESSFUL
# This is the 46th game in the list.
#
# GAME TITLE: call-of-duty-4-modern-warfare
# SUCCESSFUL
# This is the 47th game in the list.
#
# GAME TITLE: minecraft
# SUCCESSFUL
# This is the 48th game in the list.
#
# GAME TITLE: mario-party-ds
# SUCCESSFUL
# This is the 49th game in the list.
#
# GAME TITLE: the-elder-scrolls-v-skyrim
# SUCCESSFUL
# This is the 50th game in the list.
#
# GAME TITLE: fifa-16
# SUCCESSFUL
# This is the 51th game in the list.
#
# GAME TITLE: wii-party
# SUCCESSFUL
# This is the 52th game in the list.
#
# GAME TITLE: halo-2
# SUCCESSFUL
# This is the 53th game in the list.
#
# GAME TITLE: mario-party-8
# SUCCESSFUL
# This is the 54th game in the list.
#
# GAME TITLE: pokemon-black-2/pokemon-white-2
# SUCCESS but no side details
#
# GAME TITLE: fifa-soccer-13
# SUCCESSFUL
# This is the 55th game in the list.
#
# GAME TITLE: goldeneye-007
# SUCCESSFUL
# This is the 56th game in the list.
#
# GAME TITLE: mario-sonic-at-the-olympic-games
# SUCCESSFUL
# This is the 57th game in the list.
#
# GAME TITLE: final-fantasy-x
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-565ad2a32b18> in <module>
#      19     else:
#      20         print(f"\nGAME TITLE: {edited_game_title}")
# ---> 21     browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
#      22     my_details["Name"]=name
#      23
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py in visit(self, url)
#     285
#     286     def visit(self, url):
# --> 287         self.driver.get(url)
#     288
#     289     def back(self):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/remote_connection.py in patch_request(self, *args, **kwargs)
#      21     for _ in range(3):
#      22         try:
# ---> 23             return old_request(self, *args, **kwargs)
#      24         except (socket.error, HTTPException, IOError, OSError, MaxRetryError) as exc:
#      25             exception = exc
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
game_info_list

# %%
#scraping_df = pd.DataFrame(game_info_list)
#scraping_df.to_csv("../Resources/scraped_ratings2")

# %%
# get developer, genre, number_players, rating, release_date

# %%
len(problem_games)

# %%
#problem_ratings = pd.DataFrame(problem_games)
#problem_ratings.to_csv("../Resources/problem_ratings2")

# %%
#'& III ! Pokémon

# %%
len(abberant_side_detail_games)
