# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as soup
import lxml
from bs4 import NavigableString
import re

# Must gather rating data for all the games without data in the ratings_df in the exploratory analysis notebook.
# Must gather positive, neutral, and negative ratings numbers for both users and critics as well as the
# metascore and userscore

no_rating_df = pd.read_csv("../Resources/games_to_get_ratings.csv")

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
browser = Browser("chrome", executable_path="/usr/local/bin/chromedriver", headless=True)

# %%
games_df = pd.read_csv("../Resources/vgsales.csv.zip")
list_of_games = games_df["Name"].values.tolist()

# %%
## Navigating to the correct page via the search bar using splinter is too slow. I will rewrite the code to manually 
# write in the url using string interpolation. 
# I will need to interpolate the correct console name as well into the url. Metacritics url structure is:
# "https://www.metacritic.com/game/{console}/{game}"

# %%
# must change game names into the proper format to be interpolated into the URL.

game_conversions= {
    "PSV":"playstation-vita",
    "DC":"dreamcast",
    "WiiU":"wii-u",
    "GC":"gamecube",
    "N64":"nintendo-64",
    "XB":"xbox",
    "PSP":"psp",
    "PS4":"playstation-4",
    "PS": "playstation",
    "Wii":"wii",
    "PS3": "playstation-3",
    "PS2":"playstation-2",
    "GBA":"game-boy-advance",
    "DS":"ds",
    "XB":"xbox",
    "X360":"xbox-360"
}

def convert_to_name(platform_abb):
    if platform_abb in game_conversions:
        full_platform= game_conversions[platform_abb]
    else:
        full_platform="other"
    return full_platform

# %%
# This actually shows that the vast majority of our data belongs to the consoles listed on metacritic, these "legacy consoles"
# Get rid of those games which fall into the "other" category under full_platform_name
games_df["full_platform_name"]= games_df["Platform"].map(convert_to_name)
games_df = games_df.loc[games_df["full_platform_name"]!="other"]

# %%
games_df["Name"].tolist()
# Out:
# ['Wii Sports',
#  'Mario Kart Wii',
#  'Wii Sports Resort',
#  'New Super Mario Bros.',
#  'Wii Play',
#  'New Super Mario Bros. Wii',
#  'Nintendogs',
#  'Mario Kart DS',
#  'Wii Fit',
#  'Wii Fit Plus',
#  'Kinect Adventures!',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: San Andreas',
#  'Brain Age: Train Your Brain in Minutes a Day',
#  'Pokemon Diamond/Pokemon Pearl',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: Vice City',
#  'Pokemon Ruby/Pokemon Sapphire',
#  'Pokemon Black/Pokemon White',
#  'Brain Age 2: More Training in Minutes a Day',
#  'Gran Turismo 3: A-Spec',
#  'Call of Duty: Modern Warfare 3',
#  'Call of Duty: Black Ops',
#  'Call of Duty: Black Ops 3',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Modern Warfare 2',
#  'Call of Duty: Modern Warfare 3',
#  'Grand Theft Auto III',
#  'Super Smash Bros. Brawl',
#  'Call of Duty: Black Ops',
#  'Animal Crossing: Wild World',
#  'Halo 3',
#  'Grand Theft Auto V',
#  'Pokemon HeartGold/Pokemon SoulSilver',
#  'Super Mario 64',
#  'Gran Turismo 4',
#  'Super Mario Galaxy',
#  'Grand Theft Auto IV',
#  'Gran Turismo',
#  'Gran Turismo 5',
#  'Call of Duty: Modern Warfare 2',
#  'Grand Theft Auto IV',
#  'Pokemon FireRed/Pokemon LeafGreen',
#  'Super Mario 64',
#  'Just Dance 3',
#  'Call of Duty: Ghosts',
#  'Halo: Reach',
#  'Mario Kart 64',
#  'Halo 4',
#  'Final Fantasy VII',
#  'Call of Duty: Ghosts',
#  'Just Dance 2',
#  'Gran Turismo 2',
#  'Call of Duty 4: Modern Warfare',
#  'Minecraft',
#  'Mario Party DS',
#  'The Elder Scrolls V: Skyrim',
#  'FIFA 16',
#  'Wii Party',
#  'Halo 2',
#  'Mario Party 8',
#  'Pokemon Black 2/Pokemon White 2',
#  'FIFA Soccer 13',
#  'GoldenEye 007',
#  'Mario & Sonic at the Olympic Games',
#  'Final Fantasy X',
#  'Final Fantasy VIII',
#  'Pokémon Platinum Version',
#  'Grand Theft Auto: Liberty City Stories',
#  'Super Mario Galaxy 2',
#  'Star Wars Battlefront (2015)',
#  'Call of Duty: Advanced Warfare',
#  'The Legend of Zelda: Ocarina of Time',
#  'Crash Bandicoot 2: Cortex Strikes Back',
#  'Call of Duty: World at War',
#  'Battlefield 3',
#  'The Legend of Zelda: Twilight Princess',
#  'Just Dance',
#  'Battlefield 3',
#  'Need for Speed Underground',
#  'Tekken 3',
#  'Crash Bandicoot 3: Warped',
#  'Super Smash Bros. Melee',
#  'Mario Kart 8',
#  'Fallout 4',
#  'Mario Kart: Double Dash!!',
#  'Just Dance 4',
#  'FIFA 14',
#  'Need for Speed Underground 2',
#  'Medal of Honor: Frontline',
#  "Uncharted 3: Drake's Deception",
#  'Crash Bandicoot',
#  'Zumba Fitness',
#  'Gears of War 2',
#  'Uncharted 2: Among Thieves',
#  'Call of Duty 4: Modern Warfare',
#  'FIFA 12',
#  'Big Brain Academy',
#  'Red Dead Redemption',
#  'FIFA 15',
#  'Donkey Kong Country Returns',
#  'The Elder Scrolls V: Skyrim',
#  "Assassin's Creed III",
#  'Halo: Combat Evolved',
#  'Pokémon Emerald Version',
#  'Kingdom Hearts',
#  'Halo 3: ODST',
#  'Red Dead Redemption',
#  'Super Mario Sunshine',
#  'Driver',
#  'Kinect Sports',
#  'Gears of War 3',
#  'Gears of War',
#  'Metal Gear Solid 2: Sons of Liberty',
#  'Metal Gear Solid 4: Guns of the Patriots',
#  'Metal Gear Solid',
#  'The Last of Us',
#  'Final Fantasy XII',
#  'LittleBigPlanet',
#  'Dragon Quest IX: Sentinels of the Starry Skies',
#  'LEGO Star Wars: The Complete Saga',
#  'Resident Evil 2',
#  'Tekken 2',
#  'Cooking Mama',
#  'Destiny',
#  "Assassin's Creed II",
#  'Super Smash Bros.',
#  "Assassin's Creed",
#  'Batman: Arkham City',
#  'Forza Motorsport 3',
#  'Monster Hunter Freedom Unite',
#  'Super Mario Advance',
#  'Mario Kart: Super Circuit',
#  'Super Mario World',
#  'Pokemon Stadium',
#  'Call of Duty: World at War',
#  'Crash Bandicoot: The Wrath of Cortex',
#  'Minecraft',
#  'Final Fantasy XIII',
#  "Assassin's Creed III",
#  'Final Fantasy IX',
#  'Final Fantasy X-2',
#  'Donkey Kong 64',
#  "Assassin's Creed II",
#  'Professor Layton and the Curious Village',
#  'Tomb Raider II',
#  'Madden NFL 2004',
#  'Dragon Quest VIII: Journey of the Cursed King',
#  'Super Mario Bros. 3',
#  'New Super Mario Bros. U',
#  'FIFA Soccer 13',
#  'The Legend of Zelda: Phantom Hourglass',
#  'Mario & Sonic at the Olympic Games',
#  'Medal of Honor: Rising Sun',
#  'Fable III',
#  'Guitar Hero II',
#  'Resident Evil 5',
#  'Grand Theft Auto: Vice City Stories',
#  'FIFA Soccer 11',
#  'Resident Evil',
#  "Tony Hawk's Pro Skater",
#  'Super Smash Bros. for Wii U and 3DS',
#  'Warzone 2100',
#  'Spyro the Dragon',
#  "Link's Crossbow Training",
#  'Guitar Hero III: Legends of Rock',
#  'Fallout 3',
#  'Pokemon Mystery Dungeon: Explorers of Time/Explorers of Darkness',
#  "Uncharted: Drake's Fortune",
#  'Madden NFL 06',
#  'LEGO Star Wars: The Complete Saga',
#  'Diddy Kong Racing',
#  'Monster Hunter Freedom 3',
#  'God of War III',
#  "Assassin's Creed",
#  'FIFA 15',
#  'Crash Team Racing',
#  'FIFA 17',
#  'Batman: Arkham City',
#  'Driver 2',
#  'The Simpsons: Hit & Run',
#  "Tony Hawk's Pro Skater 2",
#  'Animal Crossing: City Folk',
#  'The Lord of the Rings: The Two Towers',
#  'Forza Motorsport 4',
#  'Tomb Raider',
#  'Guitar Hero III: Legends of Rock',
#  'The Legend of Zelda: The Wind Waker',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Splatoon',
#  'The Last of Us',
#  'Guitar Hero III: Legends of Rock',
#  'Madden NFL 2005',
#  'Madden NFL 07',
#  'Spider-Man: The Movie',
#  'Dragon Quest VII: Warriors of Eden',
#  'Uncharted: The Nathan Drake Collection',
#  'Call of Duty: Advanced Warfare',
#  'God of War',
#  'Nintendo Land',
#  'Michael Jackson: The Experience',
#  "Tony Hawk's Pro Skater 3",
#  'Winning Eleven: Pro Evolution Soccer 2007',
#  'The Elder Scrolls IV: Oblivion',
#  'Need for Speed: Most Wanted',
#  'Resistance: Fall of Man',
#  'Kingdom Hearts II',
#  'FIFA 14',
#  'Call of Duty: Advanced Warfare',
#  'Fable II',
#  'Super Mario 3D World',
#  'Batman: Arkham Asylum',
#  "Assassin's Creed: Revelations",
#  'Namco Museum',
#  'Metal Gear Solid 3: Snake Eater',
#  'Daxter',
#  'FIFA Soccer 06',
#  'EyeToy Play',
#  "Uncharted 4: A Thief's End",
#  'Gran Turismo 5 Prologue',
#  "Assassin's Creed: Revelations",
#  'Street Fighter IV',
#  'FIFA 12',
#  'Frogger',
#  'Madden NFL 2003',
#  'Watch Dogs',
#  'FIFA Soccer 07',
#  'The Legend of Zelda: Skyward Sword',
#  'Carnival Games',
#  'Fallout: New Vegas',
#  'God of War II',
#  'Forza Motorsport 2',
#  'World Soccer Winning Eleven 9',
#  'Namco Museum Vol.3',
#  'Tekken Tag Tournament',
#  'Far Cry 4',
#  'Star Fox 64',
#  'Minecraft',
#  'Fallout 3',
#  'Professor Layton and the Diabolical Box',
#  'Left 4 Dead 2',
#  'Namco Museum: 50th Anniversary',
#  'EA Sports Active',
#  "Assassin's Creed: Unity",
#  "Tony Hawk's Underground",
#  "Assassin's Creed IV: Black Flag",
#  'MotorStorm',
#  'Tekken 5',
#  'Sports Champions',
#  'NBA 2K16',
#  'World Soccer Winning Eleven 8 International',
#  'Flash Focus: Vision Training in Minutes a Day',
#  'Namco Museum Vol.1',
#  "Mario & Luigi: Bowser's Inside Story",
#  'Big Brain Academy: Wii Degree',
#  'Batman: Arkham Knight',
#  'Mario & Sonic at the London 2012 Olympic Games',
#  'LEGO Indiana Jones: The Original Adventures',
#  "Resident Evil Director's Cut",
#  'Ratchet & Clank: Size Matters',
#  'Just Dance 2014',
#  'Super Paper Mario',
#  "Harry Potter and the Sorcerer's Stone",
#  'The Witcher 3: Wild Hunt',
#  'Resident Evil 3: Nemesis',
#  'Spyro: Year of the Dragon',
#  'FIFA Soccer 2005',
#  'Battlefield 4',
#  'MySims',
#  'Friend Collection',
#  "Tony Hawk's Pro Skater 4",
#  'Midnight Club 3: DUB Edition',
#  'Banjo-Kazooie',
#  'SOCOM: U.S. Navy SEALs',
#  'Guitar Hero: World Tour',
#  'Gran Turismo 6',
#  'Jak and Daxter: The Precursor Legacy',
#  'Pokemon Snap',
#  'FIFA Soccer 10',
#  'Pro Evolution Soccer 2008',
#  'Call of Duty: Ghosts',
#  'Resident Evil 4',
#  "Tom Clancy's The Division",
#  'Star Wars: Battlefront',
#  'The Simpsons: Road Rage',
#  'Cooking Mama 2: Dinner With Friends',
#  "Luigi's Mansion",
#  'Star Wars: Battlefront II',
#  'WWF SmackDown!',
#  'Croc: Legend of the Gobbos',
#  'Grand Theft Auto: Liberty City Stories',
#  'The Getaway',
#  'Tomb Raider III: Adventures of Lara Croft',
#  'James Bond 007: Agent Under Fire',
#  'LEGO Star Wars: The Video Game',
#  'Battlefield 4',
#  'FIFA Soccer 11',
#  'Rugrats in Paris: The Movie',
#  "Spyro 2: Ripto's Rage!",
#  'Left 4 Dead',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Resident Evil 5',
#  "Assassin's Creed: Brotherhood",
#  'Batman: Arkham Asylum',
#  'Clubhouse Games',
#  'FIFA Soccer 2004',
#  'Battlefield: Bad Company 2',
#  'Guitar Hero: On Tour',
#  'Far Cry 3',
#  'Borderlands',
#  'Tekken 4',
#  'Battlefield 4',
#  'LittleBigPlanet 2',
#  'Grand Theft Auto 2',
#  'Spider-Man 2',
#  'FIFA Soccer 2003',
#  'Crash Bash',
#  'LEGO Batman: The Videogame',
#  'Metal Gear Solid V: The Phantom Pain',
#  'The Legend of Zelda: Spirit Tracks',
#  'WWF War Zone',
#  "The Legend of Zelda: Majora's Mask",
#  'Professor Layton and the Unwound Future',
#  'Rugrats: Search For Reptar',
#  "Assassin's Creed IV: Black Flag",
#  'English Training: Have Fun Improving Your Skills!',
#  'James Bond 007: Nightfire',
#  'Ratchet & Clank',
#  'Mario Party 9',
#  'Star Wars Episode III: Revenge of the Sith',
#  'Max Payne',
#  'The Lord of the Rings: The Return of the King',
#  "Assassin's Creed Syndicate",
#  'True Crime: Streets of LA',
#  'Wii Music',
#  'Gran Turismo (PSP)',
#  'Tekken',
#  'L.A. Noire',
#  'Madden NFL 16',
#  '007: Tomorrow Never Dies',
#  'WWF SmackDown! 2: Know Your Role',
#  'Crisis Core: Final Fantasy VII',
#  'God of War: Chains of Olympus',
#  'Dance Central',
#  'Enter the Matrix',
#  'Super Mario Maker',
#  'Fallout: New Vegas',
#  'LEGO Batman: The Videogame',
#  'Rhythm Heaven',
#  'Ace Combat 04: Shattered Skies',
#  'Club Penguin: Elite Penguin Force',
#  'Animal Crossing',
#  'LEGO Batman: The Videogame',
#  'Sonic Rush',
#  'Resident Evil 6',
#  'FIFA Soccer 08',
#  'Spider-Man',
#  'Need for Speed III: Hot Pursuit',
#  'Star Wars Episode I Racer',
#  'Personal Trainer: Cooking',
#  'The Elder Scrolls IV: Oblivion',
#  'Heavy Rain',
#  'Mass Effect 2',
#  'FIFA 15',
#  'Dragon Ball Z: Budokai',
#  'Madden NFL 2002',
#  'Borderlands 2',
#  'Mass Effect 3',
#  'Kung Fu Panda',
#  'Far Cry 3',
#  'Epic Mickey',
#  'Saints Row 2',
#  'Rayman',
#  'Killzone 2',
#  "Tom Clancy's Splinter Cell",
#  'WWE SmackDown! Shut Your Mouth',
#  'NBA 2K13',
#  'Dragon Ball Z: Budokai Tenkaichi 3',
#  'wwe Smackdown vs. Raw 2006',
#  'Middle-Earth: Shadow of Mordor',
#  'World Soccer Winning Eleven 6 International',
#  'Devil May Cry',
#  'Battlefield: Bad Company 2',
#  'Sonic Heroes',
#  'Kirby Super Star Ultra',
#  'Hitman 2: Silent Assassin',
#  'Street Fighter IV',
#  'Wave Race 64',
#  'SOCOM II: U.S. Navy SEALs',
#  'WWE SmackDown! vs. RAW 2006',
#  'inFAMOUS',
#  'Pac-Man Collection',
#  'Mass Effect',
#  'WarioWare: Smooth Moves',
#  'Cooking Mama: Cook Off',
#  "Super Mario World 2: Yoshi's Island",
#  'FIFA 14',
#  'Sonic Mega Collection Plus',
#  'Sega Superstars Tennis',
#  'World Soccer Winning Eleven 7 International',
#  'Need for Speed: Most Wanted',
#  'Hot Shots Golf 3',
#  'Call of Duty: Finest Hour',
#  'Zumba Fitness 2',
#  'Syphon Filter',
#  'Imagine: Babyz',
#  'Colin McRae Rally',
#  'Madden NFL 13',
#  'The Elder Scrolls III: Morrowind',
#  'Mortal Kombat',
#  "Yoshi's Story",
#  "Skylanders: Spyro's Adventure",
#  'FIFA 16',
#  "Assassin's Creed: Brotherhood",
#  'BioShock',
#  'Madden NFL 10',
#  'Medal of Honor',
#  'WWE SmackDown! vs. Raw',
#  'Metroid Prime',
#  'Finding Nemo',
#  'Need for Speed: Hot Pursuit',
#  'Imagine: Fashion Designer',
#  'WWE SmackDown! Here Comes the Pain',
#  'Star Wars: The Force Unleashed',
#  "Yoshi's Island DS",
#  'Hot Shots Golf',
#  'Killzone 3',
#  "A Bug's Life",
#  'WWF SmackDown! Just Bring It',
#  'Mortal Kombat Trilogy',
#  'NBA Street',
#  'Professor Layton and the Last Specter',
#  'Jak II',
#  'inFAMOUS: Second Son',
#  'Ratchet & Clank: Going Commando',
#  'Tekken 6',
#  'The Sims',
#  'Sonic and the Secret Rings',
#  'Saints Row: The Third',
#  "Assassin's Creed IV: Black Flag",
#  'Pokémon Stadium 2',
#  'L.A. Noire',
#  'Call of Duty 3',
#  'The Legend of Zelda: A Link to the Past',
#  'Onimusha: Warlords',
#  'Mortal Kombat X',
#  'Mario Party',
#  'Madden NFL 12',
#  'LEGO Star Wars II: The Original Trilogy',
#  'Madden NFL 11',
#  'Mario vs. Donkey Kong: Mini-Land Mayhem!',
#  'Skate 3',
#  'Burnout 3: Takedown',
#  'Need for Speed: Shift',
#  'Final Fantasy XIII-2',
#  'Call Of Duty 2: Big Red One',
#  'Guitar Hero: World Tour',
#  'Medal of Honor',
#  'Fable',
#  'Hannah Montana',
#  "Tom Clancy's Splinter Cell",
#  'Skylanders Giants',
#  'Medal of Honor Heroes',
#  'Star Wars: Shadows of the Empire',
#  'LEGO Star Wars: The Complete Saga',
#  'Midnight Club: Street Racing',
#  'Pac-Man: Adventures in Time',
#  'Halo Wars',
#  'God of War Collection',
#  'ESPN NFL 2K5',
#  'Mario Strikers Charged',
#  'Medal of Honor',
#  'FIFA Soccer 10',
#  'NBA 2K12',
#  'Style Savvy',
#  'Harry Potter and the Chamber of Secrets',
#  'Super Mario All-Stars: Limited Edition',
#  'FIFA Soccer 09',
#  'Ratchet & Clank Future: Tools of Destruction',
#  'NBA Live 2005',
#  'LittleBigPlanet',
#  'Killzone: Shadow Fall',
#  'Ghostbusters: The Video Game (DS Version)',
#  'Monster Hunter Freedom 2',
#  'WWE SmackDown vs. RAW 2007',
#  'Ratchet & Clank: Up Your Arsenal',
#  'Art Academy',
#  'Dragon Age: Origins',
#  'Madden NFL 08',
#  'Sonic Adventure 2 Battle',
#  'Madden NFL 13',
#  'Pokémon Colosseum',
#  'Deca Sports',
#  'Madden NFL 09',
#  'Crazy Taxi',
#  'Perfect Dark',
#  'Game Party',
#  'Tomb Raider (2013)',
#  'Marvel: Ultimate Alliance',
#  'PES 2009: Pro Evolution Soccer',
#  'Mario Party 2',
#  'Saints Row: The Third',
#  'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#  'LEGO Harry Potter: Years 1-4',
#  'Mortal Kombat: Deadly Alliance',
#  'Resistance 2',
#  'Pure',
#  'Tomb Raider: The Last Revelation',
#  'NBA 2K13',
#  'Rock Band',
#  'NBA 2K14',
#  'Mario Party 4',
#  'uDraw Studio',
#  'Midnight Club: Los Angeles',
#  'Final Fantasy Tactics',
#  'Twisted Metal 2',
#  'Halo: Combat Evolved Anniversary',
#  'Need for Speed Carbon: Own the City',
#  "The Sims: Bustin' Out",
#  "Tom Clancy's Rainbow Six: Vegas 2",
#  'Sonic Adventure',
#  'pro evolution soccer 2011',
#  'Dragon Ball Z: Budokai 2',
#  'ATV Offroad Fury',
#  'Dino Crisis',
#  'Need for Speed: ProStreet',
#  'Tetris Plus',
#  "Frogger's Adventures: Temple of the Frog",
#  'Need for Speed (2015)',
#  'Zumba Fitness',
#  'LEGO Indiana Jones: The Original Adventures',
#  'Batman: Arkham Origins',
#  'Dead Island',
#  'Guitar Hero',
#  'LEGO Star Wars: The Complete Saga',
#  'Kinect: Disneyland Adventures',
#  'WCW/nWo Revenge',
#  'Bloodborne',
#  'NBA 2K15',
#  'Madden NFL 11',
#  'Yu-Gi-Oh! The Duelists of the Roses',
#  'Madden NFL 08',
#  'The Incredibles',
#  "Tony Hawk's Underground 2",
#  'Madden NFL 10',
#  'Kinect Sports: Season Two',
#  'LEGO Harry Potter: Years 1-4',
#  'Midnight Club: Los Angeles',
#  'Skylanders SWAP Force',
#  'WWE SmackDown vs Raw 2008',
#  'My Fitness Coach',
#  'Resident Evil - Code: Veronica X',
#  'The Sims 3',
#  'Just Dance Kids',
#  'Mario Tennis',
#  'Grand Theft Auto',
#  'James Bond 007: Everything or Nothing',
#  'WarioWare Touched!',
#  'Need For Speed: High Stakes',
#  'Cool Boarders 3',
#  'LEGO Marvel Super Heroes',
#  'Pokemon Ranger: Shadows of Almia',
#  'Dead Island',
#  'God of War: Ascension',
#  'Need for Speed Underground 2',
#  'Pro Evolution Soccer 2010',
#  'Just Dance 2015',
#  'FIFA Soccer 09',
#  'Star Wars: The Force Unleashed',
#  'Borderlands 2',
#  'TOCA Touring Car Championship',
#  "Sonic's Ultimate Genesis Collection",
#  'Super Monkey Ball: Banana Blitz',
#  'Kirby: Nightmare in Dream Land',
#  'Wario Land 4',
#  'Guitar Hero III: Legends of Rock',
#  'Call of Duty 3',
#  'Resident Evil 4',
#  'Minecraft',
#  "Onimusha 2: Samurai's Destiny",
#  'Cool Boarders 2',
#  'Paper Mario: The Thousand-Year Door',
#  'Madden NFL 12',
#  'Monster Hunter Tri',
#  'Dissidia: Final Fantasy',
#  'Sonic Advance',
#  'Spyro: Season of Ice',
#  'LEGO Indiana Jones: The Original Adventures',
#  'Dance Dance Revolution X2',
#  'New Super Luigi U',
#  'Prince of Persia: The Sands of Time',
#  'Scribblenauts',
#  'Need for Speed: Hot Pursuit',
#  'BioShock 2',
#  "Devil May Cry 3: Dante's Awakening Special Edition",
#  'Rock Band 2',
#  'Guitar Hero II',
#  'Sonic Unleashed',
#  "High School Musical: Makin' the Cut!",
#  'Pro Evolution Soccer 2012',
#  'Saints Row',
#  'Star Wars: Knights of the Old Republic',
#  'Hitman: Absolution',
#  'ATV Offroad Fury 2',
#  'Madden NFL 25',
#  'Pokemon Ranger',
#  'Mario & Luigi: Superstar Saga',
#  'Final Fantasy XIII',
#  'Star Wars: Rogue Squadron',
#  'Your Shape featuring Jenny McCarthy',
#  'Syphon Filter 2',
#  "Tom Clancy's Rainbow Six: Siege",
#  'Call of Duty: Roads to Victory',
#  'Dance Dance Revolution Extreme',
#  'Tetris DS',
#  'Final Fantasy Tactics Advance',
#  'Far Cry: Primal',
#  'Toy Story 3: The Video Game',
#  'Final Fantasy III',
#  "Kirby's Epic Yarn",
#  'Project Gotham Racing',
#  'NBA 2K12',
#  'Borderlands',
#  "Tony Hawk's Pro Skater",
#  'PES 2009: Pro Evolution Soccer',
#  'Need for Speed: Hot Pursuit 2',
#  'Mario Sports Mix',
#  'Rock Band',
#  'Dynasty Warriors 4',
#  'Mortal Kombat',
#  'Parasite Eve',
#  'Scooby-Doo! Night of 100 Frights',
#  'Project Gotham Racing (JP weekly sales)',
#  'Need for Speed: Most Wanted 5-1-0',
#  'Portal 2',
#  "Devil May Cry 3: Dante's Awakening",
#  'Derby Stallion',
#  'Dead Rising',
#  'Finding Nemo',
#  'NBA 2K11',
#  'Wipeout: The Game',
#  'The Sims 2: Pets',
#  'Battlefield: Hardline',
#  'Metal Gear Solid: Peace Walker',
#  'Tetris Worlds',
#  'Need For Speed: Undercover',
#  'Dance Dance Revolution: Hottest Party',
#  'Mario Party 5',
#  'Ghostbusters: The Video Game (DS Version)',
#  'Skate 3',
#  'Spec Ops: Airborne Commando',
#  'Kingdom Hearts: Birth by Sleep',
#  'UFC 2009 Undisputed',
#  'Dark Souls',
#  'Yu-Gi-Oh! The Eternal Duelist Soul',
#  'Need for Speed: ProStreet',
#  'The Sims 3',
#  "Tom Clancy's Splinter Cell: Conviction",
#  'Pokemon Mystery Dungeon: Red/Blue Rescue Team',
#  'The Incredibles',
#  'R4: Ridge Racer Type 4',
#  'SoulCalibur II',
#  'Need for Speed: ProStreet',
#  'Carnival Games',
#  'NBA 2K14',
#  'Pokémon Mystery Dungeon: Blue Rescue Team',
#  'Sonic Mega Collection',
#  'Diablo III',
#  'PGR4 - Project Gotham Racing 4',
#  'Kingdom Hearts 358/2 Days',
#  'Dance Central 2',
#  'Rayman Raving Rabbids: TV Party',
#  'SOCOM: U.S. Navy SEALs: Combined Assault',
#  "Peter Jackson's King Kong: The Official Game of the Movie",
#  'Donkey Kong Country',
#  'Need for Speed: The Run',
#  'Madden NFL 15',
#  '1080°: TenEighty Snowboarding',
#  'Just Dance 3',
#  'NBA Live 2004',
#  'Dead Space',
#  'Call of Duty 2',
#  'Madden NFL 15',
#  'Forza Horizon',
#  'TouchMaster',
#  'LEGO Marvel Super Heroes',
#  'DriveClub',
#  'Mortal Kombat vs. DC Universe',
#  'Tenchu: Stealth Assassins',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Chamber of Secrets',
#  'Resident Evil 6',
#  'Dragon Age: Inquisition',
#  'Sonic Classic Collection',
#  'Spyro: Enter the Dragonfly',
#  'Call of Duty: World at War',
#  'Devil May Cry 2',
#  'Burnout Paradise',
#  'BioShock Infinite',
#  'Hot Shots Golf: Open Tee',
#  'Kirby Squeak Squad',
#  "Tom Clancy's Rainbow Six: Vegas",
#  'Destiny',
#  'Crash Nitro Kart',
#  'Grand Theft Auto: San Andreas',
#  'NBA Street Vol. 2',
#  'Def Jam Vendetta',
#  'FIFA Soccer 09',
#  'Scooby Doo and the Cyber Chase',
#  'Dragon Ball Z: Budokai 3',
#  'Jet Moto 2',
#  "Tom Clancy's Ghost Recon",
#  'X-Men Legends',
#  'Batman: Arkham Origins',
#  'Guitar Hero: World Tour',
#  'Mortal Kombat vs. DC Universe',
#  'Watch Dogs',
#  'Mario Super Sluggers',
#  'Tomb Raider (2013)',
#  'Need for Speed: Shift',
#  'Monopoly',
#  'Red Faction',
#  'MX Unleashed',
#  'PaRappa The Rapper',
#  'Toy Story Mania!',
#  'Mario Party 3',
#  'Star Wars: The Force Unleashed',
#  'Game Party 2',
#  'Destiny: The Taken King',
#  'LEGO Star Wars III: The Clone Wars',
#  'Star Wars Rogue Leader: Rogue Squadron II',
#  'Max Payne 3',
#  'Need for Speed Rivals',
#  'Madden NFL 09',
#  'Ratchet & Clank Future: A Crack in Time',
#  'Yu-Gi-Oh! Forbidden Memories',
#  'Mortal Kombat: Deception',
#  'Hot Shots Golf 2',
#  'Medal of Honor: European Assault (All Region sales)',
#  'WCW Nitro',
#  'High School Musical: Sing It!',
#  'Star Fox Adventures',
#  'FIFA 2000',
#  'Dynasty Warriors 3',
#  'Madden NFL 06',
#  'Shrek 2',
#  'The Legend of Dragoon',
#  'Turok 2: Seeds of Evil',
#  'SingStar',
#  'LittleBigPlanet 3',
#  'NBA Live 2002',
#  'Phineas and Ferb',
#  'Chrono Cross',
#  'GoldenEye 007 (2010)',
#  'Jak 3',
#  'Rayman Raving Rabbids 2',
#  'Kingdom Hearts: Chain of Memories',
#  'inFAMOUS 2',
#  'Gran Turismo Concept 2001 Tokyo',
#  "Demon's Souls",
#  'NCAA Football 06',
#  'Hey You, Pikachu!',
#  '2 Games in 1: Sonic Advance & ChuChu Rocket!',
#  'Jet Moto',
#  'Just Cause 3',
#  'The Orange Box',
#  'Air Combat',
#  'Namco Museum',
#  'Metroid Prime 3: Corruption',
#  'Dragon Quest VI: Realms of Revelation',
#  'The Evil Within',
#  'DDRMAX2: Dance Dance Revolution',
#  'Crazy Taxi',
#  'Virtua Fighter 4',
#  'Sly 2: Band of Thieves',
#  'Guitar Hero: World Tour',
#  'Sonic Advance 2',
#  'Madden NFL 07',
#  'NBA 2K11',
#  'NFL GameDay 2000',
#  'Call of Duty: Black Ops 3',
#  'Beyond: Two Souls',
#  'Kinect Star Wars',
#  'Midnight Club II',
#  'Dragon Quest Monsters: Joker',
#  'SpongeBob SquarePants: SuperSponge',
#  'The Getaway: Black Monday',
#  'Just Cause 2',
#  "Dragon's Dogma",
#  'The Legend of Zelda: The Wind Waker',
#  '50 Cent: Bulletproof',
#  'High School Musical: Sing It!',
#  'Wii Party U',
#  'Madden NFL 25',
#  'Kirby 64: The Crystal Shards',
#  'Dead or Alive 3',
#  'UFC 2009 Undisputed',
#  'WWF Attitude',
#  'The SpongeBob SquarePants Movie',
#  'Golden Sun',
#  'Def Jam: Fight for NY',
#  "Tom Clancy's Ghost Recon",
#  'State of Emergency',
#  'BioShock Infinite',
#  'Hitman: Absolution',
#  '2 Games in 1 Double Pack: The Incredibles / Finding Nemo: The Continuing Adventures',
#  'Call of Duty: Black Ops 3',
#  'The Urbz: Sims in the City',
#  'FIFA Soccer 08',
#  'Star Wars: Starfighter',
#  'Madden NFL 2000',
#  'Kingdom Hearts',
#  'Star Wars: Battlefront',
#  'Pro Evolution Soccer',
#  'Crackdown',
#  'Cooking Mama 3: Shop & Chop',
#  'Dance Dance Revolution X',
#  '2 Games in 1: Disney Princess & The Lion King',
#  'Star Wars Episode I: The Phantom Menace',
#  'Xenosaga Episode I: Der Wille zur Macht',
#  'Portal 2',
#  'The Beatles: Rock Band',
#  'Sonic Colors',
#  "Cruis'n USA",
#  'Madden NFL 99',
#  'Diablo III',
#  'Uncharted: Golden Abyss',
#  'Destiny',
#  'SSX Tricky',
#  'Overwatch',
#  'Twisted Metal III',
#  'Disney Infinity',
#  'Crash Bandicoot: The Huge Adventure',
#  'Dishonored',
#  'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#  'The Order: 1886',
#  'The Elder Scrolls Online',
#  'Call of Duty: World at War Final Fronts',
#  'Imagine: Teacher',
#  'Madden NFL 2005',
#  'Star Ocean: Till The End of Time',
#  'Game Party 3',
#  'Toy Story 2: Buzz Lightyear to the Rescue!',
#  'Deal or No Deal',
#  'Ace Combat 5: The Unsung War',
#  'Need for Speed Underground',
#  'Kanshuu Nippon Joushikiryoku Kentei Kyoukai: Imasara Hito ni wa Kikenai Otona no Joushikiryoku Training DS',
#  'Tetris Worlds',
#  "Cabela's Big Game Hunter 2010",
#  'The Crew',
#  'FIFA Soccer 10',
#  'We Ski',
#  'Personal Trainer: Math',
#  "Kirby's Return to Dreamland",
#  'Ben 10: Protector of Earth',
#  'NCAA Football 07',
#  'SOCOM 3: U.S. Navy SEALs',
#  'Saints Row 2',
#  'Saints Row IV',
#  "Jampack Winter '99",
#  'Dragon Age: Origins',
#  'FIFA 16',
#  'WCW vs. nWo: World Tour',
#  'WCW/NWO Thunder',
#  "Harry Potter and the Sorcerer's Stone",
#  'Need For Speed: Undercover',
#  'Dragon Ball Z: The Legacy of Goku',
#  'Resident Evil 4',
#  'Call of Duty Black Ops: Declassified',
#  'Star Wars Battlefront: Renegade Squadron',
#  'World Championship Poker: Featuring Howard Lederer - All In',
#  'NFL GameDay 98',
#  'LEGO Batman 2: DC Super Heroes',
#  'Time Crisis',
#  'Star Wars The Clone Wars: Lightsaber Duels',
#  'MySims',
#  'Metroid Fusion',
#  'Shaun White Snowboarding: Road Trip',
#  'SSX 3',
#  'Big Beach Sports',
#  'Madden NFL 2001',
#  'Fight Night Round 3',
#  'Knack',
#  'Star Wars: Battlefront II',
#  "Tony Hawk's Pro Skater 3",
#  'Monsters, Inc.',
#  'PGR: Project Gotham Racing 2',
#  'Spy Hunter',
#  'NCAA Football 2004',
#  'SpongeBob SquarePants: Battle for Bikini Bottom',
#  'Dying Light',
#  'Heavenly Sword',
#  'SSX',
#  'Max Payne 3',
#  'NBA Ballers',
#  'Need for Speed Carbon',
#  'NBA Live 2003',
#  'Dragon Ball Z: Budokai Tenkaichi',
#  'Mario Party 6',
#  'Go Vacation',
#  'Dragon Quest V: Tenkuu no Hanayome',
#  'Army of Two',
#  'Dragon Quest IV: Chapters of the Chosen',
#  'Kirby & the Amazing Mirror',
#  'LEGO Pirates of the Caribbean: The Video Game',
#  "Tom Clancy's Rainbow Six",
#  'Tiger Woods PGA Tour 2003',
#  'NBA Live 06 (All region sales)',
#  'Prince of Persia: Warrior Within',
#  'Kinectimals',
#  'Until Dawn',
#  'ESPN NFL 2K5',
#  'Viva Pinata',
#  'Pikmin',
#  'Sonic Generations',
#  'Tiger Woods PGA Tour 2004',
#  'Ape Escape',
#  'NBA 2K15',
#  'NCAA Football 2005',
#  'Just Cause 2',
#  'Rock Band',
#  "Tony Hawk's American Wasteland (Old all region sales)",
#  'Rage',
#  'Mario Hoops 3 on 3',
#  'Kirby Air Ride',
#  'Sled Storm',
#  'Pokemon Battle Revolution',
#  'NFL Street 2',
#  'Gears of War: Judgment',
#  'Super Mario Strikers',
#  'Buzz! The Music Quiz',
#  "SpongeBob's Atlantis SquarePantis",
#  'Dance Dance Revolution: Hottest Party 2',
#  'Moshi Monsters: Moshling Zoo',
#  'Dollar Dash',
#  'Far Cry 2',
#  'F-1 World Grand Prix',
#  'Silent Hill',
#  'Dragon Quest V: Hand of the Heavenly Bride',
#  "No Man's Sky",
#  'Sonic Heroes',
#  'ESPN NBA 2K5',
#  'The Legend of Zelda: Twilight Princess',
#  'Soul Edge',
#  'Devil May Cry 4',
#  'Pro Evolution Soccer 2008',
#  'SoulCalibur IV',
#  'LEGO Harry Potter: Years 1-4',
#  'NASCAR 2000',
#  'Wolfenstein: The New Order',
#  'Carnival Games: Mini Golf',
#  'Guitar Hero: On Tour Decades',
#  'MySims Kingdom',
#  'Jampack Summer 2K',
#  'Need for Speed: Most Wanted',
#  'Guitar Hero 5',
#  'High School Musical 3: Senior Year',
#  'Hannah Montana: Music Jam',
#  'Pokemon Mystery Dungeon: Explorers of Sky',
#  'Spyro 2: Season of Flame',
#  'Pro Evolution Soccer 2010',
#  'NCAA Football 2002',
#  'Conflict: Desert Storm',
#  'Mario Party 7',
#  'Pro Evolution Soccer 2013',
#  "Smuggler's Run",
#  'Fight Night Round 3',
#  'Twisted Metal',
#  'Dark Souls III',
#  'Pokemon Pinball: Ruby & Sapphire',
#  'LEGO Marvel Super Heroes',
#  'Mafia II',
#  'Dishonored',
#  'Stuntman',
#  "Tom Clancy's Rainbow Six 3",
#  'Active Life: Outdoor Challenge',
#  'BioShock 2',
#  '007: The World is not Enough',
#  'Spider-Man 2: Enter: Electro',
#  'Star Wars: The Force Unleashed II',
#  'Ni no Kuni: Wrath of the White Witch',
#  'LEGO Battles: Ninjago',
#  'Mario Party 10',
#  'Resident Evil: The Umbrella Chronicles',
#  'Dark Cloud',
#  "Tom Clancy's Ghost Recon Advanced Warfighter",
#  'Disney Fairies: Tinker Bell',
#  'MVP Baseball 2005',
#  'Die Hard Trilogy',
#  'Fight Night Round 4',
#  'MySims Kingdom',
#  'The Simpsons Game',
#  'NFL GameDay 99',
#  'Call of Duty: Modern Warfare: Reflex Edition',
#  'Mario Golf: Toadstool Tour',
#  'Tiger Woods 99 PGA Tour Golf',
#  'Donkey Kong Country: Tropical Freeze',
#  'Dead Space 2',
#  'Sonic Rivals 2',
#  ...]

# %%
# This worked pretty well, but I will alter the code further see if I can increase my scraping success to fail ratio

# %%
problem_games = []
abberant_side_detail_games = []
game_info_list = []
counter = 1

# zip the two 
zipped_list =list(zip(games_df["full_platform_name"].tolist(),games_df["Name"].tolist()))

for platform, name in zipped_list[6000:9000]:
    game_scores = {}
    x = re.compile("\.|:|;|\s|&")
    edited_game_title= re.sub(x,"-", name).lower().replace("---","-").replace("--","-").replace("'", "")
    # periods at the end of the url will show up as a dash. This conditional is to get rid of it.
    if edited_game_title[-1] == "-":
        edited_game_title = edited_game_title[:-1]
        print(f"\nGAME TITLE: {edited_game_title}")
    else:
        print(f"\nGAME TITLE: {edited_game_title}")
    browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
    # fill in my search term to the Metacritic Browser and us "\n" to press "enter" and initialize search
    
    game_scores["Name"]=name
    
    html= browser.html
    my_soup = soup(html, "lxml")
    # Grabbing the Metascore
    try:
        metascore = my_soup.find("a", class_="metascore_anchor").get_text()
        game_scores["metascore"]= metascore
    except:
        problem_games.append(name)
        print('THIS IS A PROBLEM CHILD')
        continue
    # Grabbing the Userscore
    try:
        userscore_first = my_soup.find("div", class_="details side_details")
        user_score = userscore_first.select("div.metascore_w")[0].get_text()
        game_scores["user_score"]= user_score
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing the release data
    try:
        product_data = my_soup.find("div",class_="product_data")
        release_data = product_data.find("li", class_="summary_detail release_data")
        release_date = release_data.find("span",class_="data").get_text()
        game_scores["release_date"]=release_date
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing the positive, mixed, and negative critic review numbers
    try:
        critic_reviews = []
        positive_scores = my_soup.find("div",class_="distribution_wrap")
        x = positive_scores.select("ol.score_counts.hover_none span.count")
        for i in x:
            critic_reviews.append(i.get_text())
        game_scores["positive_critics"] = critic_reviews[0]
        game_scores["neutral_critics"]=critic_reviews[1]
        game_scores["negative_critics"]=critic_reviews[2]
    except:
        problem_games.append(name)
        print('THIS IS A PROBLEM CHILD')
        continue
    # Grabbing the positive, mixed, and negative user review numbers
    try:
        user_reviews = []
        user_scores = my_soup.find("div",class_="user_reviews_module")
        drilling_down = user_scores.find("div",class_="distribution_wrap")
        ordered_list_html = drilling_down.select("ol.score_counts.hover_none span.count")
        for i in ordered_list_html:
            user_reviews.append(i.get_text())
        game_scores["positive_users"] = user_reviews[0]
        game_scores["neutral_users"]=user_reviews[1]
        game_scores["negative_users"]=user_reviews[2]
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing side details
    try:
        side_details = my_soup.find_all("div", class_="details side_details")[1]
        unordered_list = side_details.select("ul.summary_details li")
        developer = unordered_list[0].find("span", class_="data").get_text()
        game_scores["developer"]=developer
        number_players = unordered_list[2].find("span",class_="data").get_text()
        game_scores["number_players"]=number_players
        rating = unordered_list[4].find("span", class_="data").get_text()
        game_scores["rating"]=rating
        game_info_list.append(game_scores)
        print('SUCCESSFUL')
        print(f"This is the {counter}th game in the list.")
        counter+=1
    except:
        abberant_side_detail_games.append(game_scores)
        print("SUCCESS but no side details")
        continue
# Out:
# GAME TITLE: nascar-thunder-2004
# SUCCESSFUL
# This is the 1th game in the list.
#
# GAME TITLE: buffy-the-vampire-slayer
# SUCCESSFUL
# This is the 2th game in the list.
#
# GAME TITLE: lego-marvels-avengers
# SUCCESS but no side details
#
# GAME TITLE: star-wars-the-force-unleashed-ii
# SUCCESS but no side details
#
# GAME TITLE: harry-potter-and-the-goblet-of-fire
# SUCCESSFUL
# This is the 3th game in the list.
#
# GAME TITLE: saint-seiya-sanctuary-battle
# SUCCESS but no side details
#
# GAME TITLE: meteos
# SUCCESSFUL
# This is the 4th game in the list.
#
# GAME TITLE: virtua-tennis-4
# SUCCESSFUL
# This is the 5th game in the list.
#
# GAME TITLE: kung-fu-panda-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cross-edge
# SUCCESSFUL
# This is the 6th game in the list.
#
# GAME TITLE: hotel-for-dogs
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cabelas-big-game-hunter-2012
# SUCCESS but no side details
#
# GAME TITLE: pro-yakyuu-team-o-tsukurou!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: me-my-katamari
# SUCCESSFUL
# This is the 7th game in the list.
#
# GAME TITLE: asphalt-injection
# SUCCESS but no side details
#
# GAME TITLE: ssx-on-tour
# SUCCESSFUL
# This is the 8th game in the list.
#
# GAME TITLE: vancouver-2010-the-official-video-game-of-the-olympic-winter-games
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-series-baseball
# SUCCESSFUL
# This is the 9th game in the list.
#
# GAME TITLE: singstar-pop-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: test-drive-eve-of-destruction
# SUCCESSFUL
# This is the 10th game in the list.
#
# GAME TITLE: starsky-hutch
# SUCCESSFUL
# This is the 11th game in the list.
#
# GAME TITLE: dynasty-warriors-gundam-reborn
# SUCCESSFUL
# This is the 12th game in the list.
#
# GAME TITLE: hatsune-miku-project-diva-f
# SUCCESS but no side details
#
# GAME TITLE: the-club
# SUCCESSFUL
# This is the 13th game in the list.
#
# GAME TITLE: carnival-island
# SUCCESSFUL
# This is the 14th game in the list.
#
# GAME TITLE: jeremy-mcgrath-supercross-world
# SUCCESSFUL
# This is the 15th game in the list.
#
# GAME TITLE: m-ms-kart-racing
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rock-band-track-pack-classic-rock
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-scorpion-king-rise-of-the-akkadian
# SUCCESSFUL
# This is the 16th game in the list.
#
# GAME TITLE: lets-make-a-soccer-team!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: looney-tunes-acme-arsenal
# SUCCESSFUL
# This is the 17th game in the list.
#
# GAME TITLE: monster-hunter-g
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: all-star-baseball-2001
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pinball-hall-of-fame-the-gottlieb-collection
# SUCCESSFUL
# This is the 18th game in the list.
#
# GAME TITLE: sword-art-online-lost-song
# SUCCESSFUL
# This is the 19th game in the list.
#
# GAME TITLE: star-wars-jedi-knight-ii-jedi-outcast
# SUCCESSFUL
# This is the 20th game in the list.
#
# GAME TITLE: tom-clancys-splinter-cell
# SUCCESSFUL
# This is the 21th game in the list.
#
# GAME TITLE: pitfall-the-big-adventure
# SUCCESS but no side details
#
# GAME TITLE: rock-band-country-track-pack
# SUCCESS but no side details
#
# GAME TITLE: worms-battle-islands
# SUCCESSFUL
# This is the 22th game in the list.
#
# GAME TITLE: espn-nhl-hockey
# SUCCESSFUL
# This is the 23th game in the list.
#
# GAME TITLE: imagine-detective
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-incredible-hulk-ultimate-destruction
# SUCCESSFUL
# This is the 24th game in the list.
#
# GAME TITLE: hannah-montana-the-movie
# SUCCESSFUL
# This is the 25th game in the list.
#
# GAME TITLE: ncaa-gamebreaker-2003
# SUCCESSFUL
# This is the 26th game in the list.
#
# GAME TITLE: gundam-battle-assault
# SUCCESSFUL
# This is the 27th game in the list.
#
# GAME TITLE: rocket-power-beach-bandits
# SUCCESSFUL
# This is the 28th game in the list.
#
# GAME TITLE: shaun-white-snowboarding
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lego-the-hobbit
# SUCCESS but no side details
#
# GAME TITLE: ultimate-band
# SUCCESS but no side details
#
# GAME TITLE: nba-2k6
# SUCCESSFUL
# This is the 29th game in the list.
#
# GAME TITLE: age-of-empires-the-age-of-kings
# SUCCESSFUL
# This is the 30th game in the list.
#
# GAME TITLE: whats-cooking?-jamie-oliver
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tom-clancys-rainbow-six-rogue-spear
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-faceoff-2001
# SUCCESS but no side details
#
# GAME TITLE: ultimate-duck-hunting-hunting-retrieving-ducks
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: yu-gi-oh!-gx-duel-academy
# SUCCESSFUL
# This is the 31th game in the list.
#
# GAME TITLE: fifa-14
# SUCCESS but no side details
#
# GAME TITLE: tribes-aerial-assault
# SUCCESSFUL
# This is the 32th game in the list.
#
# GAME TITLE: colony-wars-vengeance
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: last-window-the-secret-of-cape-west
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: yu-gi-oh!-gx-tag-force-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dynasty-warriors-strikeforce
# SUCCESSFUL
# This is the 33th game in the list.
#
# GAME TITLE: naruto-shippuden-ultimate-ninja-storm-revolution
# SUCCESSFUL
# This is the 34th game in the list.
#
# GAME TITLE: i-love-horses
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: madden-nfl-06
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: karaoke-revolution-glee-2-road-to-regionals
# SUCCESSFUL
# This is the 35th game in the list.
#
# GAME TITLE: nascar-08
# SUCCESSFUL
# This is the 36th game in the list.
#
# GAME TITLE: perfect-weapon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: luminous-arc-2
# SUCCESSFUL
# This is the 37th game in the list.
#
# GAME TITLE: major-league-baseball-2k10
# SUCCESS but no side details
#
# GAME TITLE: mafia
# SUCCESSFUL
# This is the 38th game in the list.
#
# GAME TITLE: spider-man-edge-of-time
# SUCCESSFUL
# This is the 39th game in the list.
#
# GAME TITLE: deadly-creatures
# SUCCESSFUL
# This is the 40th game in the list.
#
# GAME TITLE: airblade
# SUCCESSFUL
# This is the 41th game in the list.
#
# GAME TITLE: cabelas-outdoor-adventures-(2009)
# SUCCESS but no side details
#
# GAME TITLE: mega-man-bass
# SUCCESSFUL
# This is the 42th game in the list.
#
# GAME TITLE: nba-live-15
# SUCCESSFUL
# This is the 43th game in the list.
#
# GAME TITLE: neopets-puzzle-adventure
# SUCCESSFUL
# This is the 44th game in the list.
#
# GAME TITLE: dragon-quest-heroes-ii-twin-kings-and-the-prophecys-end
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: puss-in-boots
# SUCCESSFUL
# This is the 45th game in the list.
#
# GAME TITLE: family-fest-presents-movie-games
# SUCCESS but no side details
#
# GAME TITLE: akb1/149-love-election
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tony-hawks-proving-ground
# SUCCESSFUL
# This is the 46th game in the list.
#
# GAME TITLE: pro-yakyuu-team-o-tsukurou!-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: musou-orochi-z
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-series-of-poker-2008-battle-for-the-bracelets
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: naruto-shippuden-ninja-council-4
# SUCCESSFUL
# This is the 47th game in the list.
#
# GAME TITLE: genji-dawn-of-the-samurai
# SUCCESSFUL
# This is the 48th game in the list.
#
# GAME TITLE: rocket-league
# SUCCESSFUL
# This is the 49th game in the list.
#
# GAME TITLE: the-idolm@ster-sp-wandering-star-/-perfect-sun-/-missing-moon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: critical-depth
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: barbie-as-the-island-princess
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: petz-rescue-wildlife-vet
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tales-of-vs
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: saka-tsuku-ds-touch-and-direct
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: super-swing-golf
# SUCCESSFUL
# This is the 50th game in the list.
#
# GAME TITLE: the-italian-job
# SUCCESSFUL
# This is the 51th game in the list.
#
# GAME TITLE: mega-man-battle-network-5-team-colonel-/-protoman
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: barbie-and-the-three-musketeers
# SUCCESS but no side details
#
# GAME TITLE: freedom-fighters
# SUCCESSFUL
# This is the 52th game in the list.
#
# GAME TITLE: naruto-ninja-council-2-european-version
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: soldier-of-fortune-ii-double-helix
# SUCCESSFUL
# This is the 53th game in the list.
#
# GAME TITLE: pro-evolution-soccer-2011
# SUCCESS but no side details
#
# GAME TITLE: disney-princess-enchanted-journey
# SUCCESSFUL
# This is the 54th game in the list.
#
# GAME TITLE: final-fantasy-xi-treasures-of-aht-urhgan
# SUCCESSFUL
# This is the 55th game in the list.
#
# GAME TITLE: alundra
# SUCCESSFUL
# This is the 56th game in the list.
#
# GAME TITLE: world-soccer-winning-eleven-2010-aoki-samurai-no-chousen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bratz-girlz-really-rock
# SUCCESSFUL
# This is the 57th game in the list.
#
# GAME TITLE: rampage-2-universal-tour
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: super-robot-taisen-f-kanketsuhen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour-2003
# SUCCESSFUL
# This is the 58th game in the list.
#
# GAME TITLE: blowout
# SUCCESSFUL
# This is the 59th game in the list.
#
# GAME TITLE: nfl-blitz-pro
# SUCCESSFUL
# This is the 60th game in the list.
#
# GAME TITLE: mysims-party
# SUCCESSFUL
# This is the 61th game in the list.
#
# GAME TITLE: tron-evolution-battle-grids
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-raiden-project
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hooked!-real-motion-fishing
# SUCCESSFUL
# This is the 62th game in the list.
#
# GAME TITLE: pocket-fighter
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bicycle-casino-2005
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: valhalla-knights-2
# SUCCESSFUL
# This is the 63th game in the list.
#
# GAME TITLE: -hack//g-u-vol-2//reminisce
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disgaea-afternoon-of-darkness
# SUCCESSFUL
# This is the 64th game in the list.
#
# GAME TITLE: ratchet-clank-full-frontal-assault
# SUCCESS but no side details
#
# GAME TITLE: ncaa-football-09
# SUCCESS but no side details
#
# GAME TITLE: family-party-30-great-games-winter-fun
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ncaa-gamebreaker-2004
# SUCCESSFUL
# This is the 65th game in the list.
#
# GAME TITLE: 101-in-1-party-megamix-wii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-polar-express
# SUCCESSFUL
# This is the 66th game in the list.
#
# GAME TITLE: dinosaur-king
# SUCCESSFUL
# This is the 67th game in the list.
#
# GAME TITLE: buzz!-junior-robojam
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: child-of-eden
# SUCCESSFUL
# This is the 68th game in the list.
#
# GAME TITLE: all-star-karate
# SUCCESS but no side details
#
# GAME TITLE: ac/dc-live-rock-band-track-pack
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-shootout-2003
# SUCCESSFUL
# This is the 69th game in the list.
#
# GAME TITLE: the-magic-school-bus-oceans
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shin-nippon-pro-wrestling-toukon-retsuden-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: senran-kagura-estival-versus
# SUCCESSFUL
# This is the 70th game in the list.
#
# GAME TITLE: digimon-world-ds-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-faceoff-2003
# SUCCESSFUL
# This is the 71th game in the list.
#
# GAME TITLE: jersey-devil
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rogue-ops
# SUCCESSFUL
# This is the 72th game in the list.
#
# GAME TITLE: nba-street-showdown
# SUCCESSFUL
# This is the 73th game in the list.
#
# GAME TITLE: 3rd-super-robot-wars-z-jigoku-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: petz-monkeyz-house
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: legion-the-legend-of-excalibur
# SUCCESSFUL
# This is the 74th game in the list.
#
# GAME TITLE: facebreaker-k-o-party
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: justice-league-heroes
# SUCCESSFUL
# This is the 75th game in the list.
#
# GAME TITLE: gekijouban-macross-f-sayonara-no-tsubasa-hybrid-pack
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tna-impact!
# SUCCESSFUL
# This is the 76th game in the list.
#
# GAME TITLE: yu-gi-oh!-gx-spirit-caller-(american-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: def-jam-fight-for-ny
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sword-art-online-infinity-moment
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spartan-total-warrior
# SUCCESSFUL
# This is the 77th game in the list.
#
# GAME TITLE: killer-is-dead
# SUCCESSFUL
# This is the 78th game in the list.
#
# GAME TITLE: ex-monopoly
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: star-trek-the-game
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: 64-de-hakken!-tamagotchi-minna-de-tamagotchi-world
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mary-kate-and-ashley-sweet-16-licenced-to-drive
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ys-seven
# SUCCESSFUL
# This is the 79th game in the list.
#
# GAME TITLE: marvel-super-hero-squad-the-infinity-gauntlet
# SUCCESS but no side details
#
# GAME TITLE: gundam-battle-chronicle
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: g-force
# SUCCESS but no side details
#
# GAME TITLE: danball-senki-boost
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kidz-bop-dance-party!-the-video-game
# SUCCESS but no side details
#
# GAME TITLE: conflict-vietnam
# SUCCESSFUL
# This is the 80th game in the list.
#
# GAME TITLE: whirl-tour
# SUCCESSFUL
# This is the 81th game in the list.
#
# GAME TITLE: time-crisis-crisis-zone
# SUCCESSFUL
# This is the 82th game in the list.
#
# GAME TITLE: momotarou-dentetsu-15
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: discovery-kids-dolphin-discovery
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ben-10-ultimate-alien-cosmic-destruction
# SUCCESS but no side details
#
# GAME TITLE: skies-of-arcadia-legends
# SUCCESSFUL
# This is the 83th game in the list.
#
# GAME TITLE: cloudy-with-a-chance-of-meatballs
# SUCCESS but no side details
#
# GAME TITLE: motogp-08
# SUCCESS but no side details
#
# GAME TITLE: madden-nfl-12
# SUCCESS but no side details
#
# GAME TITLE: sengoku-basara-3-utage
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: breath-of-fire
# SUCCESSFUL
# This is the 84th game in the list.
#
# GAME TITLE: ragnarok-ds
# SUCCESSFUL
# This is the 85th game in the list.
#
# GAME TITLE: ford-vs-chevy
# SUCCESSFUL
# This is the 86th game in the list.
#
# GAME TITLE: ncaa-football-2005
# SUCCESSFUL
# This is the 87th game in the list.
#
# GAME TITLE: hamtaro-ham-ham-games
# SUCCESSFUL
# This is the 88th game in the list.
#
# GAME TITLE: danny-phantom-the-ultimate-enemy
# SUCCESSFUL
# This is the 89th game in the list.
#
# GAME TITLE: petz-rescue-endangered-paradise
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: motogp-09/10
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rune-factory-tides-of-destiny
# SUCCESSFUL
# This is the 90th game in the list.
#
# GAME TITLE: a-boy-and-his-blob
# SUCCESSFUL
# This is the 91th game in the list.
#
# GAME TITLE: battleborn
# SUCCESSFUL
# This is the 92th game in the list.
#
# GAME TITLE: move-fitness
# SUCCESSFUL
# This is the 93th game in the list.
#
# GAME TITLE: atelier-escha-logy-alchemists-of-the-dusk-sky
# SUCCESSFUL
# This is the 94th game in the list.
#
# GAME TITLE: hidden-mysteries-buckingham-palace
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bust-a-move-4
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-legend-of-spyro-the-eternal-night
# SUCCESSFUL
# This is the 95th game in the list.
#
# GAME TITLE: nfl-quarterback-club-97
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rampage-total-destruction
# SUCCESSFUL
# This is the 96th game in the list.
#
# GAME TITLE: galactic-wrestling-featuring-ultimate-muscle
# SUCCESSFUL
# This is the 97th game in the list.
#
# GAME TITLE: petz-horse-club
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dino-stalker
# SUCCESSFUL
# This is the 98th game in the list.
#
# GAME TITLE: rapalas-fishing-frenzy
# SUCCESSFUL
# This is the 99th game in the list.
#
# GAME TITLE: mobile-suit-gundam-seed
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: puss-in-boots
# SUCCESS but no side details
#
# GAME TITLE: tony-hawks-downhill-jam
# SUCCESSFUL
# This is the 100th game in the list.
#
# GAME TITLE: mega-man-zero-3
# SUCCESSFUL
# This is the 101th game in the list.
#
# GAME TITLE: hitman-hd-trilogy
# SUCCESSFUL
# This is the 102th game in the list.
#
# GAME TITLE: aliens-vs-predator-requiem
# SUCCESSFUL
# This is the 103th game in the list.
#
# GAME TITLE: castlevania-lords-of-shadow-2
# SUCCESSFUL
# This is the 104th game in the list.
#
# GAME TITLE: barbie-groom-and-glam-pups
# SUCCESSFUL
# This is the 105th game in the list.
#
# GAME TITLE: korg-ds-10-synthesizer
# SUCCESS but no side details
#
# GAME TITLE: tenchu-shadow-assassins
# SUCCESSFUL
# This is the 106th game in the list.
#
# GAME TITLE: barbie-super-sports
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: csi-fatal-conspiracy
# SUCCESSFUL
# This is the 107th game in the list.
#
# GAME TITLE: nicktoons-collection-game-boy-advance-video-volume-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jackass-the-game
# SUCCESSFUL
# This is the 108th game in the list.
#
# GAME TITLE: the-legend-of-heroes-trails-of-cold-steel
# SUCCESSFUL
# This is the 109th game in the list.
#
# GAME TITLE: dungeon-hunter-alliance
# SUCCESSFUL
# This is the 110th game in the list.
#
# GAME TITLE: duel-masters-kaijudo-showdown
# SUCCESSFUL
# This is the 111th game in the list.
#
# GAME TITLE: imagine-boutique-owner
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-walking-dead-season-two
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-lord-of-the-rings-the-third-age
# SUCCESSFUL
# This is the 112th game in the list.
#
# GAME TITLE: cursed-mountain
# SUCCESS but no side details
#
# GAME TITLE: the-suffering
# SUCCESSFUL
# This is the 113th game in the list.
#
# GAME TITLE: dragon-quest-builders-revive-alefgard
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tetris-worlds
# SUCCESSFUL
# This is the 114th game in the list.
#
# GAME TITLE: teenage-mutant-ninja-turtles-danger-of-the-ooze
# SUCCESS but no side details
#
# GAME TITLE: ecw-hardcore-revolution
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mega-man-64
# SUCCESS but no side details
#
# GAME TITLE: chou-kuukan-night-pro-yakyuu-king(higher-jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rampage-2-universal-tour
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ms-pac-man-maze-madness
# SUCCESS but no side details
#
# GAME TITLE: tales-of-graces
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: age-of-empires-mythologies
# SUCCESSFUL
# This is the 115th game in the list.
#
# GAME TITLE: viewtiful-joe-2
# SUCCESSFUL
# This is the 116th game in the list.
#
# GAME TITLE: wheres-waldo?-the-fantastic-journey
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: atv-quad-kings
# SUCCESS but no side details
#
# GAME TITLE: mary-kate-and-ashley-sweet-16-licenced-to-drive
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jewel-quest-expeditions
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-jam-extreme
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-origins-(jp-incomplete-us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: touch-the-dead
# SUCCESSFUL
# This is the 117th game in the list.
#
# GAME TITLE: tropico-3
# SUCCESSFUL
# This is the 118th game in the list.
#
# GAME TITLE: nickelodeon-party-blast
# SUCCESSFUL
# This is the 119th game in the list.
#
# GAME TITLE: ben-10-alien-force-vilgax-attacks
# SUCCESSFUL
# This is the 120th game in the list.
#
# GAME TITLE: nhl-championship-2000
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: g-i-joe-the-rise-of-cobra
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shellshock-nam-67
# SUCCESSFUL
# This is the 121th game in the list.
#
# GAME TITLE: hunted-the-demons-forge
# SUCCESSFUL
# This is the 122th game in the list.
#
# GAME TITLE: kartia-the-word-of-fate
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tales-of-berseria
# SUCCESSFUL
# This is the 123th game in the list.
#
# GAME TITLE: all-star-baseball-2002
# SUCCESS but no side details
#
# GAME TITLE: magna-carta-tears-of-blood
# SUCCESSFUL
# This is the 124th game in the list.
#
# GAME TITLE: lethal-skies-elite-pilot-team-sw
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: capcom-vs-snk
# SUCCESS but no side details
#
# GAME TITLE: nba-live-09-all-play
# SUCCESSFUL
# This is the 125th game in the list.
#
# GAME TITLE: infinite-space
# SUCCESS but no side details
#
# GAME TITLE: yoostar2
# SUCCESSFUL
# This is the 126th game in the list.
#
# GAME TITLE: transformers-devastation
# SUCCESSFUL
# This is the 127th game in the list.
#
# GAME TITLE: tamagotchi-no-kirakira-omisecchi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: from-russia-with-love
# SUCCESSFUL
# This is the 128th game in the list.
#
# GAME TITLE: you-dont-know-jack
# SUCCESS but no side details
#
# GAME TITLE: just-dance-2016
# SUCCESSFUL
# This is the 129th game in the list.
#
# GAME TITLE: pinball-hall-of-fame-the-williams-collection
# SUCCESSFUL
# This is the 130th game in the list.
#
# GAME TITLE: guitar-hero-smash-hits
# SUCCESS but no side details
#
# GAME TITLE: nfl-quarterback-club-2002
# SUCCESSFUL
# This is the 131th game in the list.
#
# GAME TITLE: ncaa-basketball-09
# SUCCESSFUL
# This is the 132th game in the list.
#
# GAME TITLE: full-auto
# SUCCESSFUL
# This is the 133th game in the list.
#
# GAME TITLE: growlanser-heritage-of-war
# SUCCESSFUL
# This is the 134th game in the list.
#
# GAME TITLE: hasbro-family-game-night
# SUCCESS but no side details
#
# GAME TITLE: shin-megami-tensei-x-fire-emblem
# SUCCESSFUL
# This is the 135th game in the list.
#
# GAME TITLE: rugby-2004
# SUCCESSFUL
# This is the 136th game in the list.
#
# GAME TITLE: disneys-magical-quest-starring-mickey-and-minnie
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-06
# SUCCESSFUL
# This is the 137th game in the list.
#
# GAME TITLE: naruto-ninja-council
# SUCCESSFUL
# This is the 138th game in the list.
#
# GAME TITLE: shin-megami-tensei-persona
# SUCCESSFUL
# This is the 139th game in the list.
#
# GAME TITLE: ds-nishimura-kyotaro-suspense-shin-tantei-series-kyoto-atami-zekkai-no-kotou-satsui-no-wana
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wreckless-the-yakuza-missions
# SUCCESSFUL
# This is the 140th game in the list.
#
# GAME TITLE: madden-nfl-07
# SUCCESSFUL
# This is the 141th game in the list.
#
# GAME TITLE: jikkyou-powerful-major-league
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nfl-2k3
# SUCCESSFUL
# This is the 142th game in the list.
#
# GAME TITLE: darksiders-ii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: saltwater-sportfishing
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: yoshi-touch-go-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: samurai-jack-the-amulet-of-time
# SUCCESSFUL
# This is the 143th game in the list.
#
# GAME TITLE: pass-the-pigs
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: j-league-winning-eleven-2008-club-championship
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jackie-chan-stuntmaster
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sports-car-gt
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lost-planet-3
# SUCCESSFUL
# This is the 144th game in the list.
#
# GAME TITLE: order-up!
# SUCCESSFUL
# This is the 145th game in the list.
#
# GAME TITLE: sbk-x-superbike-world-championship
# SUCCESS but no side details
#
# GAME TITLE: nba-live-14
# SUCCESSFUL
# This is the 146th game in the list.
#
# GAME TITLE: scooby-doo!-mystery-mayhem
# SUCCESSFUL
# This is the 147th game in the list.
#
# GAME TITLE: american-idol
# SUCCESSFUL
# This is the 148th game in the list.
#
# GAME TITLE: summer-athletics-the-ultimate-challenge-(others-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: britneys-dance-beat
# SUCCESSFUL
# This is the 149th game in the list.
#
# GAME TITLE: shrek-superslam
# SUCCESSFUL
# This is the 150th game in the list.
#
# GAME TITLE: sniper-ghost-warrior-2
# SUCCESSFUL
# This is the 151th game in the list.
#
# GAME TITLE: over-g-fighters
# SUCCESSFUL
# This is the 152th game in the list.
#
# GAME TITLE: apache-air-assault
# SUCCESSFUL
# This is the 153th game in the list.
#
# GAME TITLE: one-piece-pirate-warriors-3
# SUCCESSFUL
# This is the 154th game in the list.
#
# GAME TITLE: herdy-gerdy
# SUCCESSFUL
# This is the 155th game in the list.
#
# GAME TITLE: armored-core-v
# SUCCESSFUL
# This is the 156th game in the list.
#
# GAME TITLE: digimon-world-re-digitize
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ninja-gaiden-dragon-sword
# SUCCESSFUL
# This is the 157th game in the list.
#
# GAME TITLE: ride
# SUCCESSFUL
# This is the 158th game in the list.
#
# GAME TITLE: blue-dragon-plus
# SUCCESSFUL
# This is the 159th game in the list.
#
# GAME TITLE: nba-in-the-zone-2000
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dark-summit
# SUCCESSFUL
# This is the 160th game in the list.
#
# GAME TITLE: afrika
# SUCCESSFUL
# This is the 161th game in the list.
#
# GAME TITLE: cabelas-big-game-hunter-ultimate-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-legend-of-heroes-trails-in-the-sky-first-chapter
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: are-you-smarter-than-a-5th-grader?-back-to-school
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: steins-gate
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-dukes-of-hazzard-return-of-the-general-lee
# SUCCESSFUL
# This is the 162th game in the list.
#
# GAME TITLE: pandemonium!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: singstar-back-to-the-80s
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: namco-museum-50th-anniversary
# SUCCESSFUL
# This is the 163th game in the list.
#
# GAME TITLE: crash-n-burn
# SUCCESSFUL
# This is the 164th game in the list.
#
# GAME TITLE: nba
# SUCCESSFUL
# This is the 165th game in the list.
#
# GAME TITLE: teenage-mutant-ninja-turtles-smash-up
# SUCCESSFUL
# This is the 166th game in the list.
#
# GAME TITLE: final-fantasy-fables-chocobos-dungeon
# SUCCESSFUL
# This is the 167th game in the list.
#
# GAME TITLE: dorabase-ds-dramatic-stadium
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disaster-report
# SUCCESSFUL
# This is the 168th game in the list.
#
# GAME TITLE: we-sing-robbie-williams
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: backyard-nfl-football-09
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pro-evolution-soccer-2012
# SUCCESS but no side details
#
# GAME TITLE: akibas-trip-undead-undressed
# SUCCESSFUL
# This is the 169th game in the list.
#
# GAME TITLE: speed-racer-the-videogame
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: college-hoops-2k7
# SUCCESSFUL
# This is the 170th game in the list.
#
# GAME TITLE: big-league-sports
# SUCCESS but no side details
#
# GAME TITLE: bratz-forever-diamondz
# SUCCESSFUL
# This is the 171th game in the list.
#
# GAME TITLE: wcw-backstage-assault
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ufc-undisputed-2010
# SUCCESSFUL
# This is the 172th game in the list.
#
# GAME TITLE: baja-edge-of-control
# SUCCESS but no side details
#
# GAME TITLE: wild-wild-racing
# SUCCESSFUL
# This is the 173th game in the list.
#
# GAME TITLE: the-bards-tale
# SUCCESSFUL
# This is the 174th game in the list.
#
# GAME TITLE: ncaa-march-madness-08
# SUCCESSFUL
# This is the 175th game in the list.
#
# GAME TITLE: momotarou-dentetsu-16
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: robotech-the-macross-saga
# SUCCESSFUL
# This is the 176th game in the list.
#
# GAME TITLE: yu-yu-hakusho-dark-tournament
# SUCCESSFUL
# This is the 177th game in the list.
#
# GAME TITLE: mtv-celebrity-deathmatch
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gekijouban-macross-f-itsuwarino-utahime-hybrid-pack
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: conflict-zone
# SUCCESSFUL
# This is the 178th game in the list.
#
# GAME TITLE: tony-hawks-american-sk8land
# SUCCESSFUL
# This is the 179th game in the list.
#
# GAME TITLE: de-blob-2
# SUCCESS but no side details
#
# GAME TITLE: the-bigs-2
# SUCCESSFUL
# This is the 180th game in the list.
#
# GAME TITLE: bloodrayne
# SUCCESSFUL
# This is the 181th game in the list.
#
# GAME TITLE: hannah-montana-the-movie
# SUCCESSFUL
# This is the 182th game in the list.
#
# GAME TITLE: 50-cent-blood-on-the-sand
# SUCCESSFUL
# This is the 183th game in the list.
#
# GAME TITLE: bratz-girlz-really-rock
# SUCCESSFUL
# This is the 184th game in the list.
#
# GAME TITLE: nhl-2k6
# SUCCESSFUL
# This is the 185th game in the list.
#
# GAME TITLE: tenchu-return-from-darkness
# SUCCESSFUL
# This is the 186th game in the list.
#
# GAME TITLE: world-poker-tour
# SUCCESSFUL
# This is the 187th game in the list.
#
# GAME TITLE: prison-break-the-conspiracy
# SUCCESSFUL
# This is the 188th game in the list.
#
# GAME TITLE: neo-contra
# SUCCESSFUL
# This is the 189th game in the list.
#
# GAME TITLE: mvp-baseball
# SUCCESSFUL
# This is the 190th game in the list.
#
# GAME TITLE: grid-autosport
# SUCCESSFUL
# This is the 191th game in the list.
#
# GAME TITLE: now!-thats-what-i-call-music-dance-sing
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: yu-gi-oh!-5ds-world-championship-2011-over-the-nexus
# SUCCESSFUL
# This is the 192th game in the list.
#
# GAME TITLE: metal-gear-solid-v-the-phantom-pain
# SUCCESS but no side details
#
# GAME TITLE: hasbro-family-game-night-3
# SUCCESS but no side details
#
# GAME TITLE: g-i-joe-the-rise-of-cobra
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rayman-raving-rabbids
# SUCCESSFUL
# This is the 193th game in the list.
#
# GAME TITLE: viewtiful-joe-2
# SUCCESSFUL
# This is the 194th game in the list.
#
# GAME TITLE: quake-iii-revolution
# SUCCESSFUL
# This is the 195th game in the list.
#
# GAME TITLE: pac-man-world-3
# SUCCESSFUL
# This is the 196th game in the list.
#
# GAME TITLE: naruto-clash-of-ninja-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: robotech-battlecry
# SUCCESSFUL
# This is the 197th game in the list.
#
# GAME TITLE: noël-not-digital
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: transformer-rise-of-the-dark-spark
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hidden-mysteries-titanic-secrets-of-the-fateful-voyage
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: marvel-super-hero-squad
# SUCCESS but no side details
#
# GAME TITLE: the-chronicles-of-narnia-prince-caspian
# SUCCESS but no side details
#
# GAME TITLE: champion-jockey-g1-jockey-gallop-racer
# SUCCESSFUL
# This is the 198th game in the list.
#
# GAME TITLE: hbo-boxing
# SUCCESS but no side details
#
# GAME TITLE: yoga-wii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: darkwatch
# SUCCESSFUL
# This is the 199th game in the list.
#
# GAME TITLE: cabelas-survival-shadows-of-katmai
# SUCCESS but no side details
#
# GAME TITLE: prince-of-persia-revelations
# SUCCESSFUL
# This is the 200th game in the list.
#
# GAME TITLE: bass-pro-shops-the-strike
# SUCCESS but no side details
#
# GAME TITLE: front-mission-5-scars-of-the-war
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: maximo-vs-army-of-zin
# SUCCESSFUL
# This is the 201th game in the list.
#
# GAME TITLE: the-fairly-oddparents-breakin-da-rules
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: namco-museum-megamix
# SUCCESS but no side details
#
# GAME TITLE: wedding-dash
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hot-shots-tennis-get-a-grip
# SUCCESSFUL
# This is the 202th game in the list.
#
# GAME TITLE: summoner-2
# SUCCESSFUL
# This is the 203th game in the list.
#
# GAME TITLE: the-land-before-time-big-water-adventure
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shadow-of-destiny
# SUCCESSFUL
# This is the 204th game in the list.
#
# GAME TITLE: valkyria-chronicles-iii-unrecorded-chronicles
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cabelas-deer-hunt-2004-season
# SUCCESSFUL
# This is the 205th game in the list.
#
# GAME TITLE: disneys-planes
# SUCCESS but no side details
#
# GAME TITLE: brunswick-pro-bowling
# SUCCESSFUL
# This is the 206th game in the list.
#
# GAME TITLE: world-series-of-poker
# SUCCESSFUL
# This is the 207th game in the list.
#
# GAME TITLE: clayfighter-63-1/3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monopoly
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wcw-nitro
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cruisn-exotica
# SUCCESS but no side details
#
# GAME TITLE: gex-3-deep-cover-gecko
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: winback-covert-operations
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wipeout-3-the-game
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bastard!!-utsuro-naru-kamigami-no-utsuwa
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sbk-superbike-world-championship
# SUCCESS but no side details
#
# GAME TITLE: bionicle
# SUCCESSFUL
# This is the 208th game in the list.
#
# GAME TITLE: wrc-fia-world-rally-championship
# SUCCESS but no side details
#
# GAME TITLE: angel-blade-neo-tokyo-guardians
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: threads-of-fate
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: popolocrois-monogatari-ii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: famicom-mini-ganbare-goemon!-karakuri-douchuu
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: vampire-rain
# SUCCESSFUL
# This is the 209th game in the list.
#
# GAME TITLE: way-of-the-samurai-3
# SUCCESSFUL
# This is the 210th game in the list.
#
# GAME TITLE: deus-ex-the-conspiracy
# SUCCESSFUL
# This is the 211th game in the list.
#
# GAME TITLE: unreal-ii-the-awakening
# SUCCESSFUL
# This is the 212th game in the list.
#
# GAME TITLE: rumble-racing
# SUCCESSFUL
# This is the 213th game in the list.
#
# GAME TITLE: spider-man-web-of-shadows
# SUCCESS but no side details
#
# GAME TITLE: disgaea-d2-a-brighter-darkness
# SUCCESSFUL
# This is the 214th game in the list.
#
# GAME TITLE: batman-begins
# SUCCESSFUL
# This is the 215th game in the list.
#
# GAME TITLE: just-dance-greatest-hits
# SUCCESS but no side details
#
# GAME TITLE: j-league-winning-eleven-10-+-europa-league-06-07
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shrek-reekin-havoc
# SUCCESSFUL
# This is the 216th game in the list.
#
# GAME TITLE: solatorobo-red-the-hunter
# SUCCESS but no side details
#
# GAME TITLE: tales-of-phantasia-narikiri-dungeon-x
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jsrf-jet-set-radio-future
# SUCCESSFUL
# This is the 217th game in the list.
#
# GAME TITLE: nhl-hitz-20-02
# SUCCESSFUL
# This is the 218th game in the list.
#
# GAME TITLE: the-last-airbender
# SUCCESS but no side details
#
# GAME TITLE: ncaa-football-2003
# SUCCESSFUL
# This is the 219th game in the list.
#
# GAME TITLE: stoked
# SUCCESSFUL
# This is the 220th game in the list.
#
# GAME TITLE: rollcage
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: espn-winter-x-games-snowboarding-2002
# SUCCESSFUL
# This is the 221th game in the list.
#
# GAME TITLE: project-snowblind
# SUCCESSFUL
# This is the 222th game in the list.
#
# GAME TITLE: tony-hawks-motion
# SUCCESS but no side details
#
# GAME TITLE: super-robot-taisen-k
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mortal-kombat-special-forces
# SUCCESSFUL
# This is the 223th game in the list.
#
# GAME TITLE: lego-the-hobbit
# SUCCESS but no side details
#
# GAME TITLE: rayman-legends
# SUCCESSFUL
# This is the 224th game in the list.
#
# GAME TITLE: dragon-ball-z-harukanaru-densetsu
# SUCCESSFUL
# This is the 225th game in the list.
#
# GAME TITLE: wacky-races-crash-dash
# SUCCESSFUL
# This is the 226th game in the list.
#
# GAME TITLE: i-spy-castle
# SUCCESS but no side details
#
# GAME TITLE: shin-megami-tensei-persona-3-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: greg-hastings-paintball-2
# SUCCESS but no side details
#
# GAME TITLE: evil-dead-regeneration
# SUCCESSFUL
# This is the 227th game in the list.
#
# GAME TITLE: dead-to-rights-retribution
# SUCCESSFUL
# This is the 228th game in the list.
#
# GAME TITLE: ncaa-march-madness-07
# SUCCESSFUL
# This is the 229th game in the list.
#
# GAME TITLE: nhl-2003
# SUCCESSFUL
# This is the 230th game in the list.
#
# GAME TITLE: marvel-super-hero-squad-comic-combat
# SUCCESS but no side details
#
# GAME TITLE: barbie-fashion-show-an-eye-for-style
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour
# SUCCESSFUL
# This is the 231th game in the list.
#
# GAME TITLE: yarudora-series-vol-2-kisetsu-wo-dakishimete
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-2k3
# SUCCESSFUL
# This is the 232th game in the list.
#
# GAME TITLE: heisei-kyouiku-linkai-ds
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spongebob-squarepants-game-boy-advance-video-volume-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pro-yaky?-spirits-2010
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-naked-brothers-band-the-video-game
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: final-fight-one
# SUCCESSFUL
# This is the 233th game in the list.
#
# GAME TITLE: rune-factory-tides-of-destiny
# SUCCESSFUL
# This is the 234th game in the list.
#
# GAME TITLE: the-amazing-spider-man-(console-version)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ncaa-football-10
# SUCCESSFUL
# This is the 235th game in the list.
#
# GAME TITLE: gallop-racer-2003-a-new-breed
# SUCCESSFUL
# This is the 236th game in the list.
#
# GAME TITLE: dawn-of-discovery
# SUCCESSFUL
# This is the 237th game in the list.
#
# GAME TITLE: beyblade-vforce-super-tournament-battle
# SUCCESSFUL
# This is the 238th game in the list.
#
# GAME TITLE: outlaw-golf-2
# SUCCESSFUL
# This is the 239th game in the list.
#
# GAME TITLE: anarchy-reigns
# SUCCESSFUL
# This is the 240th game in the list.
#
# GAME TITLE: csi-deadly-intent
# SUCCESSFUL
# This is the 241th game in the list.
#
# GAME TITLE: j-league-pro-soccer-club-o-tsukurou!-7-euro-plus
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bugs-bunny-taz-time-busters
# SUCCESS but no side details
#
# GAME TITLE: need-for-speed-carbon-own-the-city
# SUCCESSFUL
# This is the 242th game in the list.
#
# GAME TITLE: dragon-ball-z-sagas
# SUCCESSFUL
# This is the 243th game in the list.
#
# GAME TITLE: kung-fu-rider
# SUCCESSFUL
# This is the 244th game in the list.
#
# GAME TITLE: jikkyou-powerful-pro-yakyuu-2012
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: x2-wolverines-revenge
# SUCCESSFUL
# This is the 245th game in the list.
#
# GAME TITLE: power-rangers-wild-force
# SUCCESS but no side details
#
# GAME TITLE: the-wolf-among-us
# SUCCESS but no side details
#
# GAME TITLE: thrillville
# SUCCESSFUL
# This is the 246th game in the list.
#
# GAME TITLE: battle-of-giants-dinosaurs-strike
# SUCCESS but no side details
#
# GAME TITLE: attack-on-titan-(koei)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: discovery-kids-pony-paradise
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mary-kate-and-ashley-girls-night-out
# SUCCESS but no side details
#
# GAME TITLE: cabelas-north-american-adventures
# SUCCESS but no side details
#
# GAME TITLE: enchanted-arms
# SUCCESSFUL
# This is the 247th game in the list.
#
# GAME TITLE: beyblade-g-revolution
# SUCCESS but no side details
#
# GAME TITLE: wwe-all-stars
# SUCCESS but no side details
#
# GAME TITLE: world-championship-cards
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: you-dont-know-jack
# SUCCESSFUL
# This is the 248th game in the list.
#
# GAME TITLE: chronicles-of-mystery-curse-of-the-ancient-temple
# SUCCESS but no side details
#
# GAME TITLE: capcom-fighting-evolution
# SUCCESSFUL
# This is the 249th game in the list.
#
# GAME TITLE: backyard-nfl-football-2006
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nascar-heat-2002
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: planet-51
# SUCCESSFUL
# This is the 250th game in the list.
#
# GAME TITLE: sloane-to-machale-no-nazo-no-monogatari
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: darkstar-one-broken-alliance
# SUCCESS but no side details
#
# GAME TITLE: my-fitness-coach-2-exercise-and-nutrition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sengoku-basara-2-heroes
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: buzz!-the-schools-quiz
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: suikoden-tactics
# SUCCESSFUL
# This is the 251th game in the list.
#
# GAME TITLE: ncaa-march-madness-06
# SUCCESSFUL
# This is the 252th game in the list.
#
# GAME TITLE: major-league-baseball-2k11
# SUCCESS but no side details
#
# GAME TITLE: mobile-suit-gundam-crossfire
# SUCCESSFUL
# This is the 253th game in the list.
#
# GAME TITLE: phantasy-star-online
# SUCCESS but no side details
#
# GAME TITLE: crazy-taxi-3-high-roller
# SUCCESSFUL
# This is the 254th game in the list.
#
# GAME TITLE: dark-messiah-of-might-and-magic-elements
# SUCCESSFUL
# This is the 255th game in the list.
#
# GAME TITLE: just-dance-2-extra-songs
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: midnight-club-3-dub-edition-remix
# SUCCESSFUL
# This is the 256th game in the list.
#
# GAME TITLE: international-superstar-soccer-2000
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: candyland-/-chutes-ladders-/-memory
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-bible-game
# SUCCESSFUL
# This is the 257th game in the list.
#
# GAME TITLE: shining-blade
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fairy-fencer-f
# SUCCESSFUL
# This is the 258th game in the list.
#
# GAME TITLE: atelier-shallie-alchemists-of-the-dusk-sea
# SUCCESSFUL
# This is the 259th game in the list.
#
# GAME TITLE: the-ultimate-red-ball-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pbr-out-of-the-chute
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-king-of-fighters-collection-the-orochi-saga
# SUCCESS but no side details
#
# GAME TITLE: jikkyou-powerful-pro-yakyuu-10-chou-ketteiban-2003-memorial
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: arcana-heart-3
# SUCCESSFUL
# This is the 260th game in the list.
#
# GAME TITLE: deal-or-no-deal-the-banker-is-back!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jillian-michaels-fitness-adventure
# SUCCESSFUL
# This is the 261th game in the list.
#
# GAME TITLE: mlb-10-the-show
# SUCCESS but no side details
#
# GAME TITLE: ashes-cricket-2009
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: saturday-night-speedway
# SUCCESSFUL
# This is the 262th game in the list.
#
# GAME TITLE: bratz-rock-angelz
# SUCCESSFUL
# This is the 263th game in the list.
#
# GAME TITLE: mlb-slugfest-20-03
# SUCCESSFUL
# This is the 264th game in the list.
#
# GAME TITLE: dragon-ball-revenge-of-king-piccolo
# SUCCESS but no side details
#
# GAME TITLE: spectrobes-origins
# SUCCESS but no side details
#
# GAME TITLE: earth-defense-force-insect-armageddon
# SUCCESSFUL
# This is the 265th game in the list.
#
# GAME TITLE: pitfall-the-lost-expedition
# SUCCESSFUL
# This is the 266th game in the list.
#
# GAME TITLE: marvel-ultimate-alliance-2
# SUCCESSFUL
# This is the 267th game in the list.
#
# GAME TITLE: from-tv-animation-one-piece-grand-battle!-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rocket-power-zero-gravity-zone
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: le-mans-24-hours
# SUCCESSFUL
# This is the 268th game in the list.
#
# GAME TITLE: international-cricket-2010
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: espn-mlb-baseball
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: neighborhood-games
# SUCCESS but no side details
#
# GAME TITLE: all-star-pro-wrestling
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: way-of-the-samurai-4
# SUCCESSFUL
# This is the 269th game in the list.
#
# GAME TITLE: clive-barkers-jericho
# SUCCESSFUL
# This is the 270th game in the list.
#
# GAME TITLE: harvest-moon-more-friends-of-mineral-town
# SUCCESSFUL
# This is the 271th game in the list.
#
# GAME TITLE: captain-america-super-soldier
# SUCCESSFUL
# This is the 272th game in the list.
#
# GAME TITLE: mlb-12-the-show
# SUCCESS but no side details
#
# GAME TITLE: the-fairly-odd-parents-shadow-showdown
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-17
# SUCCESSFUL
# This is the 273th game in the list.
#
# GAME TITLE: camping-mama-outdoor-adventures
# SUCCESSFUL
# This is the 274th game in the list.
#
# GAME TITLE: kurohyou-2-ryu-ga-gotoku-ashura-hen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-2k2
# SUCCESSFUL
# This is the 275th game in the list.
#
# GAME TITLE: x2-wolverines-revenge
# SUCCESSFUL
# This is the 276th game in the list.
#
# GAME TITLE: 7th-dragon-2020
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cars
# SUCCESSFUL
# This is the 277th game in the list.
#
# GAME TITLE: taiko-no-tatsujin-waku-waku-anime-matsuri
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: imagine-babyz-fashion
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spy-hunter
# SUCCESSFUL
# This is the 278th game in the list.
#
# GAME TITLE: warriors-orochi
# SUCCESSFUL
# This is the 279th game in the list.
#
# GAME TITLE: dead-to-rights-ii
# SUCCESSFUL
# This is the 280th game in the list.
#
# GAME TITLE: super-dodge-ball-advance
# SUCCESS but no side details
#
# GAME TITLE: ogre-battle-saga-episode-five-the-march-of-the-black-queen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ridge-racer-6
# SUCCESSFUL
# This is the 281th game in the list.
#
# GAME TITLE: angry-birds-star-wars
# SUCCESS but no side details
#
# GAME TITLE: ni-hao,-kai-lan-new-years-celebration
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: press-your-luck-2010-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: treasure-world
# SUCCESS but no side details
#
# GAME TITLE: front-mission-evolved
# SUCCESSFUL
# This is the 282th game in the list.
#
# GAME TITLE: body-and-brain-connection
# SUCCESSFUL
# This is the 283th game in the list.
#
# GAME TITLE: mdk
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-jam
# SUCCESSFUL
# This is the 284th game in the list.
#
# GAME TITLE: afro-samurai
# SUCCESSFUL
# This is the 285th game in the list.
#
# GAME TITLE: rock-band-track-pack-classic-rock
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: zone-of-the-enders-hd-collection
# SUCCESSFUL
# This is the 286th game in the list.
#
# GAME TITLE: ty-the-tasmanian-tiger-2-bush-rescue
# SUCCESSFUL
# This is the 287th game in the list.
#
# GAME TITLE: speed-punks
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-legend-of-heroes-vii-the-trail-of-blue
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: no-more-heroes-heroes-paradise
# SUCCESSFUL
# This is the 288th game in the list.
#
# GAME TITLE: mahjongg-mysteries-ancient-egypt
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: injustice-gods-among-us
# SUCCESSFUL
# This is the 289th game in the list.
#
# GAME TITLE: mvp-baseball-2003
# SUCCESSFUL
# This is the 290th game in the list.
#
# GAME TITLE: csi-unsolved!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ncaa-final-four-2004
# SUCCESSFUL
# This is the 291th game in the list.
#
# GAME TITLE: the-chronicles-of-narnia-the-lion,-the-witch-and-the-wardrobe
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiggers-honey-hunt
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: famista-64
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: roadsters-99
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: magical-tetris-challenge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: twisted-edge-extreme-snowboarding
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disneys-tarzan
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: south-park-rally
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: body-harvest
# SUCCESSFUL
# This is the 292th game in the list.
#
# GAME TITLE: san-francisco-rush-2049
# SUCCESS but no side details
#
# GAME TITLE: super-robot-taisen-64
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: snowboard-kids
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-07
# SUCCESSFUL
# This is the 293th game in the list.
#
# GAME TITLE: ihra-drag-racing-2004
# SUCCESSFUL
# This is the 294th game in the list.
#
# GAME TITLE: shining-hearts
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: magical-zhuzhu-princess-carriages-castles
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tomb-raider-underworld
# SUCCESSFUL
# This is the 295th game in the list.
#
# GAME TITLE: the-con
# SUCCESSFUL
# This is the 296th game in the list.
#
# GAME TITLE: tony-hawks-pro-skater-5
# SUCCESSFUL
# This is the 297th game in the list.
#
# GAME TITLE: jissen-pachi-slot-hisshouhou!-aladdin-a
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: namco-museum-50th-anniversary
# SUCCESSFUL
# This is the 298th game in the list.
#
# GAME TITLE: ford-racing-off-road
# SUCCESS but no side details
#
# GAME TITLE: the-witch-and-the-hundred-knight
# SUCCESSFUL
# This is the 299th game in the list.
#
# GAME TITLE: nobunaga-no-yabou-reppuuden
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hot-wheels-track-attack
# SUCCESS but no side details
#
# GAME TITLE: schlag-den-raab
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ufc-personal-trainer-the-ultimate-fitness-system
# SUCCESSFUL
# This is the 300th game in the list.
#
# GAME TITLE: the-bigs-2
# SUCCESS but no side details
#
# GAME TITLE: mat-hoffmans-pro-bmx-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: untold-legends-dark-kingdom
# SUCCESSFUL
# This is the 301th game in the list.
#
# GAME TITLE: from-russia-with-love
# SUCCESSFUL
# This is the 302th game in the list.
#
# GAME TITLE: pro-yaky?-spirits-2013
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: we-wish-you-a-merry-christmas
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bioshock-the-collection
# SUCCESSFUL
# This is the 303th game in the list.
#
# GAME TITLE: dancedancerevolution
# SUCCESSFUL
# This is the 304th game in the list.
#
# GAME TITLE: cabelas-big-game-hunter-(2008)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: grandia-ii
# SUCCESS but no side details
#
# GAME TITLE: namco-museum-vol-4
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-cheetah-girls-passport-to-stardom
# SUCCESS but no side details
#
# GAME TITLE: ufc-personal-trainer-the-ultimate-fitness-system
# SUCCESS but no side details
#
# GAME TITLE: how-to-train-your-dragon-2
# SUCCESSFUL
# This is the 305th game in the list.
#
# GAME TITLE: shark-tale
# SUCCESSFUL
# This is the 306th game in the list.
#
# GAME TITLE: nfl-street-2
# SUCCESSFUL
# This is the 307th game in the list.
#
# GAME TITLE: pro-yaky?-spirits-2013
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: teenage-mutant-ninja-turtles-3-mutant-nightmare
# SUCCESSFUL
# This is the 308th game in the list.
#
# GAME TITLE: my-secret-world-by-imagine
# SUCCESS but no side details
#
# GAME TITLE: soldier-of-fortune-payback
# SUCCESSFUL
# This is the 309th game in the list.
#
# GAME TITLE: ridge-racer
# SUCCESS but no side details
#
# GAME TITLE: bleach-the-3rd-phantom
# SUCCESS but no side details
#
# GAME TITLE: gladius
# SUCCESSFUL
# This is the 310th game in the list.
#
# GAME TITLE: family-feud-2012-edition
# SUCCESS but no side details
#
# GAME TITLE: dave-mirra-freestyle-bmx-2
# SUCCESSFUL
# This is the 311th game in the list.
#
# GAME TITLE: spore-hero-arena
# SUCCESS but no side details
#
# GAME TITLE: pro-yaky?-spirits-2012
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spongebob-squarepants-revenge-of-the-flying-dutchman
# SUCCESS but no side details
#
# GAME TITLE: record-of-agarest-war
# SUCCESSFUL
# This is the 312th game in the list.
#
# GAME TITLE: baja-edge-of-control
# SUCCESSFUL
# This is the 313th game in the list.
#
# GAME TITLE: sid-meiers-pirates!
# SUCCESSFUL
# This is the 314th game in the list.
#
# GAME TITLE: taiko-no-tatsujin-go!-go!-godaime
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: taiko-drum-master
# SUCCESSFUL
# This is the 315th game in the list.
#
# GAME TITLE: high-school-musical-3-senior-year-dance!
# SUCCESS but no side details
#
# GAME TITLE: harry-potter-and-the-goblet-of-fire
# SUCCESSFUL
# This is the 316th game in the list.
#
# GAME TITLE: bust-a-move-2-arcade-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tom-clancys-splinter-cell-essentials
# SUCCESSFUL
# This is the 317th game in the list.
#
# GAME TITLE: tetris-worlds-(online-edition)
# SUCCESSFUL
# This is the 318th game in the list.
#
# GAME TITLE: armored-core-4
# SUCCESSFUL
# This is the 319th game in the list.
#
# GAME TITLE: forgotten-realms-demon-stone
# SUCCESSFUL
# This is the 320th game in the list.
#
# GAME TITLE: barbie-horse-adventures-riding-camp
# SUCCESS but no side details
#
# GAME TITLE: resident-evil-revelations
# SUCCESSFUL
# This is the 321th game in the list.
#
# GAME TITLE: go-play-lumberjacks
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: looney-tunes-space-race
# SUCCESSFUL
# This is the 322th game in the list.
#
# GAME TITLE: puzzle-challenge-crosswords-and-more!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nascar-unleashed
# SUCCESS but no side details
#
# GAME TITLE: backyard-hockey
# SUCCESSFUL
# This is the 323th game in the list.
#
# GAME TITLE: playboy-the-mansion
# SUCCESSFUL
# This is the 324th game in the list.
#
# GAME TITLE: jikkyou-powerful-pro-yakyuu-2010
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shiren-the-wanderer
# SUCCESSFUL
# This is the 325th game in the list.
#
# GAME TITLE: ore-no-shikabane-o-koete-yuke
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shaman-king-spirit-of-shamans
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4ef320619985> in <module>
#      17     else:
#      18         print(f"\nGAME TITLE: {edited_game_title}")
# ---> 19     browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
#      20     # fill in my search term to the Metacritic Browser and us "\n" to press "enter" and initialize search
#      21
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py in visit(self, url)
#     285
#     286     def visit(self, url):
# --> 287         self.driver.get(url)
#     288
#     289     def back(self):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/remote_connection.py in patch_request(self, *args, **kwargs)
#      21     for _ in range(3):
#      22         try:
# ---> 23             return old_request(self, *args, **kwargs)
#      24         except (socket.error, HTTPException, IOError, OSError, MaxRetryError) as exc:
#      25             exception = exc
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
game_info_list

# %%
#scraping_df = pd.DataFrame(game_info_list)
#scraping_df.to_csv("../Resources/scraped_ratings2")

# %%
# get developer, genre, number_players, rating, release_date

# %%
len(problem_games)

# %%
#problem_ratings = pd.DataFrame(problem_games)
#problem_ratings.to_csv("../Resources/problem_ratings2")

# %%
#'& III ! Pokémon

# %%
len(abberant_side_detail_games)
