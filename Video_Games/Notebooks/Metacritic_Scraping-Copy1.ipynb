# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as soup
import lxml
from bs4 import NavigableString
import re

# Must gather rating data for all the games without data in the ratings_df in the exploratory analysis notebook.
# Must gather positive, neutral, and negative ratings numbers for both users and critics as well as the
# metascore and userscore

no_rating_df = pd.read_csv("../Resources/games_to_get_ratings.csv")

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
browser = Browser("chrome", executable_path="/usr/local/bin/chromedriver", headless=True)

# %%
games_df = pd.read_csv("../Resources/vgsales.csv.zip")
list_of_games = games_df["Name"].values.tolist()

# %%
## Navigating to the correct page via the search bar using splinter is too slow. I will rewrite the code to manually 
# write in the url using string interpolation. 
# I will need to interpolate the correct console name as well into the url. Metacritics url structure is:
# "https://www.metacritic.com/game/{console}/{game}"

# %%
# must change game names into the proper format to be interpolated into the URL.

game_conversions= {
    "PSV":"playstation-vita",
    "DC":"dreamcast",
    "WiiU":"wii-u",
    "GC":"gamecube",
    "N64":"nintendo-64",
    "XB":"xbox",
    "PSP":"psp",
    "PS4":"playstation-4",
    "PS": "playstation",
    "Wii":"wii",
    "PS3": "playstation-3",
    "PS2":"playstation-2",
    "GBA":"game-boy-advance",
    "DS":"ds",
    "XB":"xbox",
    "X360":"xbox-360"
}

def convert_to_name(platform_abb):
    if platform_abb in game_conversions:
        full_platform= game_conversions[platform_abb]
    else:
        full_platform="other"
    return full_platform

# %%
# This actually shows that the vast majority of our data belongs to the consoles listed on metacritic, these "legacy consoles"
# Get rid of those games which fall into the "other" category under full_platform_name
games_df["full_platform_name"]= games_df["Platform"].map(convert_to_name)
games_df = games_df.loc[games_df["full_platform_name"]!="other"]

# %%
games_df["Name"].tolist()
# Out:
# ['Wii Sports',
#  'Mario Kart Wii',
#  'Wii Sports Resort',
#  'New Super Mario Bros.',
#  'Wii Play',
#  'New Super Mario Bros. Wii',
#  'Nintendogs',
#  'Mario Kart DS',
#  'Wii Fit',
#  'Wii Fit Plus',
#  'Kinect Adventures!',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: San Andreas',
#  'Brain Age: Train Your Brain in Minutes a Day',
#  'Pokemon Diamond/Pokemon Pearl',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: Vice City',
#  'Pokemon Ruby/Pokemon Sapphire',
#  'Pokemon Black/Pokemon White',
#  'Brain Age 2: More Training in Minutes a Day',
#  'Gran Turismo 3: A-Spec',
#  'Call of Duty: Modern Warfare 3',
#  'Call of Duty: Black Ops',
#  'Call of Duty: Black Ops 3',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Modern Warfare 2',
#  'Call of Duty: Modern Warfare 3',
#  'Grand Theft Auto III',
#  'Super Smash Bros. Brawl',
#  'Call of Duty: Black Ops',
#  'Animal Crossing: Wild World',
#  'Halo 3',
#  'Grand Theft Auto V',
#  'Pokemon HeartGold/Pokemon SoulSilver',
#  'Super Mario 64',
#  'Gran Turismo 4',
#  'Super Mario Galaxy',
#  'Grand Theft Auto IV',
#  'Gran Turismo',
#  'Gran Turismo 5',
#  'Call of Duty: Modern Warfare 2',
#  'Grand Theft Auto IV',
#  'Pokemon FireRed/Pokemon LeafGreen',
#  'Super Mario 64',
#  'Just Dance 3',
#  'Call of Duty: Ghosts',
#  'Halo: Reach',
#  'Mario Kart 64',
#  'Halo 4',
#  'Final Fantasy VII',
#  'Call of Duty: Ghosts',
#  'Just Dance 2',
#  'Gran Turismo 2',
#  'Call of Duty 4: Modern Warfare',
#  'Minecraft',
#  'Mario Party DS',
#  'The Elder Scrolls V: Skyrim',
#  'FIFA 16',
#  'Wii Party',
#  'Halo 2',
#  'Mario Party 8',
#  'Pokemon Black 2/Pokemon White 2',
#  'FIFA Soccer 13',
#  'GoldenEye 007',
#  'Mario & Sonic at the Olympic Games',
#  'Final Fantasy X',
#  'Final Fantasy VIII',
#  'Pokémon Platinum Version',
#  'Grand Theft Auto: Liberty City Stories',
#  'Super Mario Galaxy 2',
#  'Star Wars Battlefront (2015)',
#  'Call of Duty: Advanced Warfare',
#  'The Legend of Zelda: Ocarina of Time',
#  'Crash Bandicoot 2: Cortex Strikes Back',
#  'Call of Duty: World at War',
#  'Battlefield 3',
#  'The Legend of Zelda: Twilight Princess',
#  'Just Dance',
#  'Battlefield 3',
#  'Need for Speed Underground',
#  'Tekken 3',
#  'Crash Bandicoot 3: Warped',
#  'Super Smash Bros. Melee',
#  'Mario Kart 8',
#  'Fallout 4',
#  'Mario Kart: Double Dash!!',
#  'Just Dance 4',
#  'FIFA 14',
#  'Need for Speed Underground 2',
#  'Medal of Honor: Frontline',
#  "Uncharted 3: Drake's Deception",
#  'Crash Bandicoot',
#  'Zumba Fitness',
#  'Gears of War 2',
#  'Uncharted 2: Among Thieves',
#  'Call of Duty 4: Modern Warfare',
#  'FIFA 12',
#  'Big Brain Academy',
#  'Red Dead Redemption',
#  'FIFA 15',
#  'Donkey Kong Country Returns',
#  'The Elder Scrolls V: Skyrim',
#  "Assassin's Creed III",
#  'Halo: Combat Evolved',
#  'Pokémon Emerald Version',
#  'Kingdom Hearts',
#  'Halo 3: ODST',
#  'Red Dead Redemption',
#  'Super Mario Sunshine',
#  'Driver',
#  'Kinect Sports',
#  'Gears of War 3',
#  'Gears of War',
#  'Metal Gear Solid 2: Sons of Liberty',
#  'Metal Gear Solid 4: Guns of the Patriots',
#  'Metal Gear Solid',
#  'The Last of Us',
#  'Final Fantasy XII',
#  'LittleBigPlanet',
#  'Dragon Quest IX: Sentinels of the Starry Skies',
#  'LEGO Star Wars: The Complete Saga',
#  'Resident Evil 2',
#  'Tekken 2',
#  'Cooking Mama',
#  'Destiny',
#  "Assassin's Creed II",
#  'Super Smash Bros.',
#  "Assassin's Creed",
#  'Batman: Arkham City',
#  'Forza Motorsport 3',
#  'Monster Hunter Freedom Unite',
#  'Super Mario Advance',
#  'Mario Kart: Super Circuit',
#  'Super Mario World',
#  'Pokemon Stadium',
#  'Call of Duty: World at War',
#  'Crash Bandicoot: The Wrath of Cortex',
#  'Minecraft',
#  'Final Fantasy XIII',
#  "Assassin's Creed III",
#  'Final Fantasy IX',
#  'Final Fantasy X-2',
#  'Donkey Kong 64',
#  "Assassin's Creed II",
#  'Professor Layton and the Curious Village',
#  'Tomb Raider II',
#  'Madden NFL 2004',
#  'Dragon Quest VIII: Journey of the Cursed King',
#  'Super Mario Bros. 3',
#  'New Super Mario Bros. U',
#  'FIFA Soccer 13',
#  'The Legend of Zelda: Phantom Hourglass',
#  'Mario & Sonic at the Olympic Games',
#  'Medal of Honor: Rising Sun',
#  'Fable III',
#  'Guitar Hero II',
#  'Resident Evil 5',
#  'Grand Theft Auto: Vice City Stories',
#  'FIFA Soccer 11',
#  'Resident Evil',
#  "Tony Hawk's Pro Skater",
#  'Super Smash Bros. for Wii U and 3DS',
#  'Warzone 2100',
#  'Spyro the Dragon',
#  "Link's Crossbow Training",
#  'Guitar Hero III: Legends of Rock',
#  'Fallout 3',
#  'Pokemon Mystery Dungeon: Explorers of Time/Explorers of Darkness',
#  "Uncharted: Drake's Fortune",
#  'Madden NFL 06',
#  'LEGO Star Wars: The Complete Saga',
#  'Diddy Kong Racing',
#  'Monster Hunter Freedom 3',
#  'God of War III',
#  "Assassin's Creed",
#  'FIFA 15',
#  'Crash Team Racing',
#  'FIFA 17',
#  'Batman: Arkham City',
#  'Driver 2',
#  'The Simpsons: Hit & Run',
#  "Tony Hawk's Pro Skater 2",
#  'Animal Crossing: City Folk',
#  'The Lord of the Rings: The Two Towers',
#  'Forza Motorsport 4',
#  'Tomb Raider',
#  'Guitar Hero III: Legends of Rock',
#  'The Legend of Zelda: The Wind Waker',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Splatoon',
#  'The Last of Us',
#  'Guitar Hero III: Legends of Rock',
#  'Madden NFL 2005',
#  'Madden NFL 07',
#  'Spider-Man: The Movie',
#  'Dragon Quest VII: Warriors of Eden',
#  'Uncharted: The Nathan Drake Collection',
#  'Call of Duty: Advanced Warfare',
#  'God of War',
#  'Nintendo Land',
#  'Michael Jackson: The Experience',
#  "Tony Hawk's Pro Skater 3",
#  'Winning Eleven: Pro Evolution Soccer 2007',
#  'The Elder Scrolls IV: Oblivion',
#  'Need for Speed: Most Wanted',
#  'Resistance: Fall of Man',
#  'Kingdom Hearts II',
#  'FIFA 14',
#  'Call of Duty: Advanced Warfare',
#  'Fable II',
#  'Super Mario 3D World',
#  'Batman: Arkham Asylum',
#  "Assassin's Creed: Revelations",
#  'Namco Museum',
#  'Metal Gear Solid 3: Snake Eater',
#  'Daxter',
#  'FIFA Soccer 06',
#  'EyeToy Play',
#  "Uncharted 4: A Thief's End",
#  'Gran Turismo 5 Prologue',
#  "Assassin's Creed: Revelations",
#  'Street Fighter IV',
#  'FIFA 12',
#  'Frogger',
#  'Madden NFL 2003',
#  'Watch Dogs',
#  'FIFA Soccer 07',
#  'The Legend of Zelda: Skyward Sword',
#  'Carnival Games',
#  'Fallout: New Vegas',
#  'God of War II',
#  'Forza Motorsport 2',
#  'World Soccer Winning Eleven 9',
#  'Namco Museum Vol.3',
#  'Tekken Tag Tournament',
#  'Far Cry 4',
#  'Star Fox 64',
#  'Minecraft',
#  'Fallout 3',
#  'Professor Layton and the Diabolical Box',
#  'Left 4 Dead 2',
#  'Namco Museum: 50th Anniversary',
#  'EA Sports Active',
#  "Assassin's Creed: Unity",
#  "Tony Hawk's Underground",
#  "Assassin's Creed IV: Black Flag",
#  'MotorStorm',
#  'Tekken 5',
#  'Sports Champions',
#  'NBA 2K16',
#  'World Soccer Winning Eleven 8 International',
#  'Flash Focus: Vision Training in Minutes a Day',
#  'Namco Museum Vol.1',
#  "Mario & Luigi: Bowser's Inside Story",
#  'Big Brain Academy: Wii Degree',
#  'Batman: Arkham Knight',
#  'Mario & Sonic at the London 2012 Olympic Games',
#  'LEGO Indiana Jones: The Original Adventures',
#  "Resident Evil Director's Cut",
#  'Ratchet & Clank: Size Matters',
#  'Just Dance 2014',
#  'Super Paper Mario',
#  "Harry Potter and the Sorcerer's Stone",
#  'The Witcher 3: Wild Hunt',
#  'Resident Evil 3: Nemesis',
#  'Spyro: Year of the Dragon',
#  'FIFA Soccer 2005',
#  'Battlefield 4',
#  'MySims',
#  'Friend Collection',
#  "Tony Hawk's Pro Skater 4",
#  'Midnight Club 3: DUB Edition',
#  'Banjo-Kazooie',
#  'SOCOM: U.S. Navy SEALs',
#  'Guitar Hero: World Tour',
#  'Gran Turismo 6',
#  'Jak and Daxter: The Precursor Legacy',
#  'Pokemon Snap',
#  'FIFA Soccer 10',
#  'Pro Evolution Soccer 2008',
#  'Call of Duty: Ghosts',
#  'Resident Evil 4',
#  "Tom Clancy's The Division",
#  'Star Wars: Battlefront',
#  'The Simpsons: Road Rage',
#  'Cooking Mama 2: Dinner With Friends',
#  "Luigi's Mansion",
#  'Star Wars: Battlefront II',
#  'WWF SmackDown!',
#  'Croc: Legend of the Gobbos',
#  'Grand Theft Auto: Liberty City Stories',
#  'The Getaway',
#  'Tomb Raider III: Adventures of Lara Croft',
#  'James Bond 007: Agent Under Fire',
#  'LEGO Star Wars: The Video Game',
#  'Battlefield 4',
#  'FIFA Soccer 11',
#  'Rugrats in Paris: The Movie',
#  "Spyro 2: Ripto's Rage!",
#  'Left 4 Dead',
#  'Mario & Sonic at the Olympic Winter Games',
#  'Resident Evil 5',
#  "Assassin's Creed: Brotherhood",
#  'Batman: Arkham Asylum',
#  'Clubhouse Games',
#  'FIFA Soccer 2004',
#  'Battlefield: Bad Company 2',
#  'Guitar Hero: On Tour',
#  'Far Cry 3',
#  'Borderlands',
#  'Tekken 4',
#  'Battlefield 4',
#  'LittleBigPlanet 2',
#  'Grand Theft Auto 2',
#  'Spider-Man 2',
#  'FIFA Soccer 2003',
#  'Crash Bash',
#  'LEGO Batman: The Videogame',
#  'Metal Gear Solid V: The Phantom Pain',
#  'The Legend of Zelda: Spirit Tracks',
#  'WWF War Zone',
#  "The Legend of Zelda: Majora's Mask",
#  'Professor Layton and the Unwound Future',
#  'Rugrats: Search For Reptar',
#  "Assassin's Creed IV: Black Flag",
#  'English Training: Have Fun Improving Your Skills!',
#  'James Bond 007: Nightfire',
#  'Ratchet & Clank',
#  'Mario Party 9',
#  'Star Wars Episode III: Revenge of the Sith',
#  'Max Payne',
#  'The Lord of the Rings: The Return of the King',
#  "Assassin's Creed Syndicate",
#  'True Crime: Streets of LA',
#  'Wii Music',
#  'Gran Turismo (PSP)',
#  'Tekken',
#  'L.A. Noire',
#  'Madden NFL 16',
#  '007: Tomorrow Never Dies',
#  'WWF SmackDown! 2: Know Your Role',
#  'Crisis Core: Final Fantasy VII',
#  'God of War: Chains of Olympus',
#  'Dance Central',
#  'Enter the Matrix',
#  'Super Mario Maker',
#  'Fallout: New Vegas',
#  'LEGO Batman: The Videogame',
#  'Rhythm Heaven',
#  'Ace Combat 04: Shattered Skies',
#  'Club Penguin: Elite Penguin Force',
#  'Animal Crossing',
#  'LEGO Batman: The Videogame',
#  'Sonic Rush',
#  'Resident Evil 6',
#  'FIFA Soccer 08',
#  'Spider-Man',
#  'Need for Speed III: Hot Pursuit',
#  'Star Wars Episode I Racer',
#  'Personal Trainer: Cooking',
#  'The Elder Scrolls IV: Oblivion',
#  'Heavy Rain',
#  'Mass Effect 2',
#  'FIFA 15',
#  'Dragon Ball Z: Budokai',
#  'Madden NFL 2002',
#  'Borderlands 2',
#  'Mass Effect 3',
#  'Kung Fu Panda',
#  'Far Cry 3',
#  'Epic Mickey',
#  'Saints Row 2',
#  'Rayman',
#  'Killzone 2',
#  "Tom Clancy's Splinter Cell",
#  'WWE SmackDown! Shut Your Mouth',
#  'NBA 2K13',
#  'Dragon Ball Z: Budokai Tenkaichi 3',
#  'wwe Smackdown vs. Raw 2006',
#  'Middle-Earth: Shadow of Mordor',
#  'World Soccer Winning Eleven 6 International',
#  'Devil May Cry',
#  'Battlefield: Bad Company 2',
#  'Sonic Heroes',
#  'Kirby Super Star Ultra',
#  'Hitman 2: Silent Assassin',
#  'Street Fighter IV',
#  'Wave Race 64',
#  'SOCOM II: U.S. Navy SEALs',
#  'WWE SmackDown! vs. RAW 2006',
#  'inFAMOUS',
#  'Pac-Man Collection',
#  'Mass Effect',
#  'WarioWare: Smooth Moves',
#  'Cooking Mama: Cook Off',
#  "Super Mario World 2: Yoshi's Island",
#  'FIFA 14',
#  'Sonic Mega Collection Plus',
#  'Sega Superstars Tennis',
#  'World Soccer Winning Eleven 7 International',
#  'Need for Speed: Most Wanted',
#  'Hot Shots Golf 3',
#  'Call of Duty: Finest Hour',
#  'Zumba Fitness 2',
#  'Syphon Filter',
#  'Imagine: Babyz',
#  'Colin McRae Rally',
#  'Madden NFL 13',
#  'The Elder Scrolls III: Morrowind',
#  'Mortal Kombat',
#  "Yoshi's Story",
#  "Skylanders: Spyro's Adventure",
#  'FIFA 16',
#  "Assassin's Creed: Brotherhood",
#  'BioShock',
#  'Madden NFL 10',
#  'Medal of Honor',
#  'WWE SmackDown! vs. Raw',
#  'Metroid Prime',
#  'Finding Nemo',
#  'Need for Speed: Hot Pursuit',
#  'Imagine: Fashion Designer',
#  'WWE SmackDown! Here Comes the Pain',
#  'Star Wars: The Force Unleashed',
#  "Yoshi's Island DS",
#  'Hot Shots Golf',
#  'Killzone 3',
#  "A Bug's Life",
#  'WWF SmackDown! Just Bring It',
#  'Mortal Kombat Trilogy',
#  'NBA Street',
#  'Professor Layton and the Last Specter',
#  'Jak II',
#  'inFAMOUS: Second Son',
#  'Ratchet & Clank: Going Commando',
#  'Tekken 6',
#  'The Sims',
#  'Sonic and the Secret Rings',
#  'Saints Row: The Third',
#  "Assassin's Creed IV: Black Flag",
#  'Pokémon Stadium 2',
#  'L.A. Noire',
#  'Call of Duty 3',
#  'The Legend of Zelda: A Link to the Past',
#  'Onimusha: Warlords',
#  'Mortal Kombat X',
#  'Mario Party',
#  'Madden NFL 12',
#  'LEGO Star Wars II: The Original Trilogy',
#  'Madden NFL 11',
#  'Mario vs. Donkey Kong: Mini-Land Mayhem!',
#  'Skate 3',
#  'Burnout 3: Takedown',
#  'Need for Speed: Shift',
#  'Final Fantasy XIII-2',
#  'Call Of Duty 2: Big Red One',
#  'Guitar Hero: World Tour',
#  'Medal of Honor',
#  'Fable',
#  'Hannah Montana',
#  "Tom Clancy's Splinter Cell",
#  'Skylanders Giants',
#  'Medal of Honor Heroes',
#  'Star Wars: Shadows of the Empire',
#  'LEGO Star Wars: The Complete Saga',
#  'Midnight Club: Street Racing',
#  'Pac-Man: Adventures in Time',
#  'Halo Wars',
#  'God of War Collection',
#  'ESPN NFL 2K5',
#  'Mario Strikers Charged',
#  'Medal of Honor',
#  'FIFA Soccer 10',
#  'NBA 2K12',
#  'Style Savvy',
#  'Harry Potter and the Chamber of Secrets',
#  'Super Mario All-Stars: Limited Edition',
#  'FIFA Soccer 09',
#  'Ratchet & Clank Future: Tools of Destruction',
#  'NBA Live 2005',
#  'LittleBigPlanet',
#  'Killzone: Shadow Fall',
#  'Ghostbusters: The Video Game (DS Version)',
#  'Monster Hunter Freedom 2',
#  'WWE SmackDown vs. RAW 2007',
#  'Ratchet & Clank: Up Your Arsenal',
#  'Art Academy',
#  'Dragon Age: Origins',
#  'Madden NFL 08',
#  'Sonic Adventure 2 Battle',
#  'Madden NFL 13',
#  'Pokémon Colosseum',
#  'Deca Sports',
#  'Madden NFL 09',
#  'Crazy Taxi',
#  'Perfect Dark',
#  'Game Party',
#  'Tomb Raider (2013)',
#  'Marvel: Ultimate Alliance',
#  'PES 2009: Pro Evolution Soccer',
#  'Mario Party 2',
#  'Saints Row: The Third',
#  'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#  'LEGO Harry Potter: Years 1-4',
#  'Mortal Kombat: Deadly Alliance',
#  'Resistance 2',
#  'Pure',
#  'Tomb Raider: The Last Revelation',
#  'NBA 2K13',
#  'Rock Band',
#  'NBA 2K14',
#  'Mario Party 4',
#  'uDraw Studio',
#  'Midnight Club: Los Angeles',
#  'Final Fantasy Tactics',
#  'Twisted Metal 2',
#  'Halo: Combat Evolved Anniversary',
#  'Need for Speed Carbon: Own the City',
#  "The Sims: Bustin' Out",
#  "Tom Clancy's Rainbow Six: Vegas 2",
#  'Sonic Adventure',
#  'pro evolution soccer 2011',
#  'Dragon Ball Z: Budokai 2',
#  'ATV Offroad Fury',
#  'Dino Crisis',
#  'Need for Speed: ProStreet',
#  'Tetris Plus',
#  "Frogger's Adventures: Temple of the Frog",
#  'Need for Speed (2015)',
#  'Zumba Fitness',
#  'LEGO Indiana Jones: The Original Adventures',
#  'Batman: Arkham Origins',
#  'Dead Island',
#  'Guitar Hero',
#  'LEGO Star Wars: The Complete Saga',
#  'Kinect: Disneyland Adventures',
#  'WCW/nWo Revenge',
#  'Bloodborne',
#  'NBA 2K15',
#  'Madden NFL 11',
#  'Yu-Gi-Oh! The Duelists of the Roses',
#  'Madden NFL 08',
#  'The Incredibles',
#  "Tony Hawk's Underground 2",
#  'Madden NFL 10',
#  'Kinect Sports: Season Two',
#  'LEGO Harry Potter: Years 1-4',
#  'Midnight Club: Los Angeles',
#  'Skylanders SWAP Force',
#  'WWE SmackDown vs Raw 2008',
#  'My Fitness Coach',
#  'Resident Evil - Code: Veronica X',
#  'The Sims 3',
#  'Just Dance Kids',
#  'Mario Tennis',
#  'Grand Theft Auto',
#  'James Bond 007: Everything or Nothing',
#  'WarioWare Touched!',
#  'Need For Speed: High Stakes',
#  'Cool Boarders 3',
#  'LEGO Marvel Super Heroes',
#  'Pokemon Ranger: Shadows of Almia',
#  'Dead Island',
#  'God of War: Ascension',
#  'Need for Speed Underground 2',
#  'Pro Evolution Soccer 2010',
#  'Just Dance 2015',
#  'FIFA Soccer 09',
#  'Star Wars: The Force Unleashed',
#  'Borderlands 2',
#  'TOCA Touring Car Championship',
#  "Sonic's Ultimate Genesis Collection",
#  'Super Monkey Ball: Banana Blitz',
#  'Kirby: Nightmare in Dream Land',
#  'Wario Land 4',
#  'Guitar Hero III: Legends of Rock',
#  'Call of Duty 3',
#  'Resident Evil 4',
#  'Minecraft',
#  "Onimusha 2: Samurai's Destiny",
#  'Cool Boarders 2',
#  'Paper Mario: The Thousand-Year Door',
#  'Madden NFL 12',
#  'Monster Hunter Tri',
#  'Dissidia: Final Fantasy',
#  'Sonic Advance',
#  'Spyro: Season of Ice',
#  'LEGO Indiana Jones: The Original Adventures',
#  'Dance Dance Revolution X2',
#  'New Super Luigi U',
#  'Prince of Persia: The Sands of Time',
#  'Scribblenauts',
#  'Need for Speed: Hot Pursuit',
#  'BioShock 2',
#  "Devil May Cry 3: Dante's Awakening Special Edition",
#  'Rock Band 2',
#  'Guitar Hero II',
#  'Sonic Unleashed',
#  "High School Musical: Makin' the Cut!",
#  'Pro Evolution Soccer 2012',
#  'Saints Row',
#  'Star Wars: Knights of the Old Republic',
#  'Hitman: Absolution',
#  'ATV Offroad Fury 2',
#  'Madden NFL 25',
#  'Pokemon Ranger',
#  'Mario & Luigi: Superstar Saga',
#  'Final Fantasy XIII',
#  'Star Wars: Rogue Squadron',
#  'Your Shape featuring Jenny McCarthy',
#  'Syphon Filter 2',
#  "Tom Clancy's Rainbow Six: Siege",
#  'Call of Duty: Roads to Victory',
#  'Dance Dance Revolution Extreme',
#  'Tetris DS',
#  'Final Fantasy Tactics Advance',
#  'Far Cry: Primal',
#  'Toy Story 3: The Video Game',
#  'Final Fantasy III',
#  "Kirby's Epic Yarn",
#  'Project Gotham Racing',
#  'NBA 2K12',
#  'Borderlands',
#  "Tony Hawk's Pro Skater",
#  'PES 2009: Pro Evolution Soccer',
#  'Need for Speed: Hot Pursuit 2',
#  'Mario Sports Mix',
#  'Rock Band',
#  'Dynasty Warriors 4',
#  'Mortal Kombat',
#  'Parasite Eve',
#  'Scooby-Doo! Night of 100 Frights',
#  'Project Gotham Racing (JP weekly sales)',
#  'Need for Speed: Most Wanted 5-1-0',
#  'Portal 2',
#  "Devil May Cry 3: Dante's Awakening",
#  'Derby Stallion',
#  'Dead Rising',
#  'Finding Nemo',
#  'NBA 2K11',
#  'Wipeout: The Game',
#  'The Sims 2: Pets',
#  'Battlefield: Hardline',
#  'Metal Gear Solid: Peace Walker',
#  'Tetris Worlds',
#  'Need For Speed: Undercover',
#  'Dance Dance Revolution: Hottest Party',
#  'Mario Party 5',
#  'Ghostbusters: The Video Game (DS Version)',
#  'Skate 3',
#  'Spec Ops: Airborne Commando',
#  'Kingdom Hearts: Birth by Sleep',
#  'UFC 2009 Undisputed',
#  'Dark Souls',
#  'Yu-Gi-Oh! The Eternal Duelist Soul',
#  'Need for Speed: ProStreet',
#  'The Sims 3',
#  "Tom Clancy's Splinter Cell: Conviction",
#  'Pokemon Mystery Dungeon: Red/Blue Rescue Team',
#  'The Incredibles',
#  'R4: Ridge Racer Type 4',
#  'SoulCalibur II',
#  'Need for Speed: ProStreet',
#  'Carnival Games',
#  'NBA 2K14',
#  'Pokémon Mystery Dungeon: Blue Rescue Team',
#  'Sonic Mega Collection',
#  'Diablo III',
#  'PGR4 - Project Gotham Racing 4',
#  'Kingdom Hearts 358/2 Days',
#  'Dance Central 2',
#  'Rayman Raving Rabbids: TV Party',
#  'SOCOM: U.S. Navy SEALs: Combined Assault',
#  "Peter Jackson's King Kong: The Official Game of the Movie",
#  'Donkey Kong Country',
#  'Need for Speed: The Run',
#  'Madden NFL 15',
#  '1080°: TenEighty Snowboarding',
#  'Just Dance 3',
#  'NBA Live 2004',
#  'Dead Space',
#  'Call of Duty 2',
#  'Madden NFL 15',
#  'Forza Horizon',
#  'TouchMaster',
#  'LEGO Marvel Super Heroes',
#  'DriveClub',
#  'Mortal Kombat vs. DC Universe',
#  'Tenchu: Stealth Assassins',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Chamber of Secrets',
#  'Resident Evil 6',
#  'Dragon Age: Inquisition',
#  'Sonic Classic Collection',
#  'Spyro: Enter the Dragonfly',
#  'Call of Duty: World at War',
#  'Devil May Cry 2',
#  'Burnout Paradise',
#  'BioShock Infinite',
#  'Hot Shots Golf: Open Tee',
#  'Kirby Squeak Squad',
#  "Tom Clancy's Rainbow Six: Vegas",
#  'Destiny',
#  'Crash Nitro Kart',
#  'Grand Theft Auto: San Andreas',
#  'NBA Street Vol. 2',
#  'Def Jam Vendetta',
#  'FIFA Soccer 09',
#  'Scooby Doo and the Cyber Chase',
#  'Dragon Ball Z: Budokai 3',
#  'Jet Moto 2',
#  "Tom Clancy's Ghost Recon",
#  'X-Men Legends',
#  'Batman: Arkham Origins',
#  'Guitar Hero: World Tour',
#  'Mortal Kombat vs. DC Universe',
#  'Watch Dogs',
#  'Mario Super Sluggers',
#  'Tomb Raider (2013)',
#  'Need for Speed: Shift',
#  'Monopoly',
#  'Red Faction',
#  'MX Unleashed',
#  'PaRappa The Rapper',
#  'Toy Story Mania!',
#  'Mario Party 3',
#  'Star Wars: The Force Unleashed',
#  'Game Party 2',
#  'Destiny: The Taken King',
#  'LEGO Star Wars III: The Clone Wars',
#  'Star Wars Rogue Leader: Rogue Squadron II',
#  'Max Payne 3',
#  'Need for Speed Rivals',
#  'Madden NFL 09',
#  'Ratchet & Clank Future: A Crack in Time',
#  'Yu-Gi-Oh! Forbidden Memories',
#  'Mortal Kombat: Deception',
#  'Hot Shots Golf 2',
#  'Medal of Honor: European Assault (All Region sales)',
#  'WCW Nitro',
#  'High School Musical: Sing It!',
#  'Star Fox Adventures',
#  'FIFA 2000',
#  'Dynasty Warriors 3',
#  'Madden NFL 06',
#  'Shrek 2',
#  'The Legend of Dragoon',
#  'Turok 2: Seeds of Evil',
#  'SingStar',
#  'LittleBigPlanet 3',
#  'NBA Live 2002',
#  'Phineas and Ferb',
#  'Chrono Cross',
#  'GoldenEye 007 (2010)',
#  'Jak 3',
#  'Rayman Raving Rabbids 2',
#  'Kingdom Hearts: Chain of Memories',
#  'inFAMOUS 2',
#  'Gran Turismo Concept 2001 Tokyo',
#  "Demon's Souls",
#  'NCAA Football 06',
#  'Hey You, Pikachu!',
#  '2 Games in 1: Sonic Advance & ChuChu Rocket!',
#  'Jet Moto',
#  'Just Cause 3',
#  'The Orange Box',
#  'Air Combat',
#  'Namco Museum',
#  'Metroid Prime 3: Corruption',
#  'Dragon Quest VI: Realms of Revelation',
#  'The Evil Within',
#  'DDRMAX2: Dance Dance Revolution',
#  'Crazy Taxi',
#  'Virtua Fighter 4',
#  'Sly 2: Band of Thieves',
#  'Guitar Hero: World Tour',
#  'Sonic Advance 2',
#  'Madden NFL 07',
#  'NBA 2K11',
#  'NFL GameDay 2000',
#  'Call of Duty: Black Ops 3',
#  'Beyond: Two Souls',
#  'Kinect Star Wars',
#  'Midnight Club II',
#  'Dragon Quest Monsters: Joker',
#  'SpongeBob SquarePants: SuperSponge',
#  'The Getaway: Black Monday',
#  'Just Cause 2',
#  "Dragon's Dogma",
#  'The Legend of Zelda: The Wind Waker',
#  '50 Cent: Bulletproof',
#  'High School Musical: Sing It!',
#  'Wii Party U',
#  'Madden NFL 25',
#  'Kirby 64: The Crystal Shards',
#  'Dead or Alive 3',
#  'UFC 2009 Undisputed',
#  'WWF Attitude',
#  'The SpongeBob SquarePants Movie',
#  'Golden Sun',
#  'Def Jam: Fight for NY',
#  "Tom Clancy's Ghost Recon",
#  'State of Emergency',
#  'BioShock Infinite',
#  'Hitman: Absolution',
#  '2 Games in 1 Double Pack: The Incredibles / Finding Nemo: The Continuing Adventures',
#  'Call of Duty: Black Ops 3',
#  'The Urbz: Sims in the City',
#  'FIFA Soccer 08',
#  'Star Wars: Starfighter',
#  'Madden NFL 2000',
#  'Kingdom Hearts',
#  'Star Wars: Battlefront',
#  'Pro Evolution Soccer',
#  'Crackdown',
#  'Cooking Mama 3: Shop & Chop',
#  'Dance Dance Revolution X',
#  '2 Games in 1: Disney Princess & The Lion King',
#  'Star Wars Episode I: The Phantom Menace',
#  'Xenosaga Episode I: Der Wille zur Macht',
#  'Portal 2',
#  'The Beatles: Rock Band',
#  'Sonic Colors',
#  "Cruis'n USA",
#  'Madden NFL 99',
#  'Diablo III',
#  'Uncharted: Golden Abyss',
#  'Destiny',
#  'SSX Tricky',
#  'Overwatch',
#  'Twisted Metal III',
#  'Disney Infinity',
#  'Crash Bandicoot: The Huge Adventure',
#  'Dishonored',
#  'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#  'The Order: 1886',
#  'The Elder Scrolls Online',
#  'Call of Duty: World at War Final Fronts',
#  'Imagine: Teacher',
#  'Madden NFL 2005',
#  'Star Ocean: Till The End of Time',
#  'Game Party 3',
#  'Toy Story 2: Buzz Lightyear to the Rescue!',
#  'Deal or No Deal',
#  'Ace Combat 5: The Unsung War',
#  'Need for Speed Underground',
#  'Kanshuu Nippon Joushikiryoku Kentei Kyoukai: Imasara Hito ni wa Kikenai Otona no Joushikiryoku Training DS',
#  'Tetris Worlds',
#  "Cabela's Big Game Hunter 2010",
#  'The Crew',
#  'FIFA Soccer 10',
#  'We Ski',
#  'Personal Trainer: Math',
#  "Kirby's Return to Dreamland",
#  'Ben 10: Protector of Earth',
#  'NCAA Football 07',
#  'SOCOM 3: U.S. Navy SEALs',
#  'Saints Row 2',
#  'Saints Row IV',
#  "Jampack Winter '99",
#  'Dragon Age: Origins',
#  'FIFA 16',
#  'WCW vs. nWo: World Tour',
#  'WCW/NWO Thunder',
#  "Harry Potter and the Sorcerer's Stone",
#  'Need For Speed: Undercover',
#  'Dragon Ball Z: The Legacy of Goku',
#  'Resident Evil 4',
#  'Call of Duty Black Ops: Declassified',
#  'Star Wars Battlefront: Renegade Squadron',
#  'World Championship Poker: Featuring Howard Lederer - All In',
#  'NFL GameDay 98',
#  'LEGO Batman 2: DC Super Heroes',
#  'Time Crisis',
#  'Star Wars The Clone Wars: Lightsaber Duels',
#  'MySims',
#  'Metroid Fusion',
#  'Shaun White Snowboarding: Road Trip',
#  'SSX 3',
#  'Big Beach Sports',
#  'Madden NFL 2001',
#  'Fight Night Round 3',
#  'Knack',
#  'Star Wars: Battlefront II',
#  "Tony Hawk's Pro Skater 3",
#  'Monsters, Inc.',
#  'PGR: Project Gotham Racing 2',
#  'Spy Hunter',
#  'NCAA Football 2004',
#  'SpongeBob SquarePants: Battle for Bikini Bottom',
#  'Dying Light',
#  'Heavenly Sword',
#  'SSX',
#  'Max Payne 3',
#  'NBA Ballers',
#  'Need for Speed Carbon',
#  'NBA Live 2003',
#  'Dragon Ball Z: Budokai Tenkaichi',
#  'Mario Party 6',
#  'Go Vacation',
#  'Dragon Quest V: Tenkuu no Hanayome',
#  'Army of Two',
#  'Dragon Quest IV: Chapters of the Chosen',
#  'Kirby & the Amazing Mirror',
#  'LEGO Pirates of the Caribbean: The Video Game',
#  "Tom Clancy's Rainbow Six",
#  'Tiger Woods PGA Tour 2003',
#  'NBA Live 06 (All region sales)',
#  'Prince of Persia: Warrior Within',
#  'Kinectimals',
#  'Until Dawn',
#  'ESPN NFL 2K5',
#  'Viva Pinata',
#  'Pikmin',
#  'Sonic Generations',
#  'Tiger Woods PGA Tour 2004',
#  'Ape Escape',
#  'NBA 2K15',
#  'NCAA Football 2005',
#  'Just Cause 2',
#  'Rock Band',
#  "Tony Hawk's American Wasteland (Old all region sales)",
#  'Rage',
#  'Mario Hoops 3 on 3',
#  'Kirby Air Ride',
#  'Sled Storm',
#  'Pokemon Battle Revolution',
#  'NFL Street 2',
#  'Gears of War: Judgment',
#  'Super Mario Strikers',
#  'Buzz! The Music Quiz',
#  "SpongeBob's Atlantis SquarePantis",
#  'Dance Dance Revolution: Hottest Party 2',
#  'Moshi Monsters: Moshling Zoo',
#  'Dollar Dash',
#  'Far Cry 2',
#  'F-1 World Grand Prix',
#  'Silent Hill',
#  'Dragon Quest V: Hand of the Heavenly Bride',
#  "No Man's Sky",
#  'Sonic Heroes',
#  'ESPN NBA 2K5',
#  'The Legend of Zelda: Twilight Princess',
#  'Soul Edge',
#  'Devil May Cry 4',
#  'Pro Evolution Soccer 2008',
#  'SoulCalibur IV',
#  'LEGO Harry Potter: Years 1-4',
#  'NASCAR 2000',
#  'Wolfenstein: The New Order',
#  'Carnival Games: Mini Golf',
#  'Guitar Hero: On Tour Decades',
#  'MySims Kingdom',
#  'Jampack Summer 2K',
#  'Need for Speed: Most Wanted',
#  'Guitar Hero 5',
#  'High School Musical 3: Senior Year',
#  'Hannah Montana: Music Jam',
#  'Pokemon Mystery Dungeon: Explorers of Sky',
#  'Spyro 2: Season of Flame',
#  'Pro Evolution Soccer 2010',
#  'NCAA Football 2002',
#  'Conflict: Desert Storm',
#  'Mario Party 7',
#  'Pro Evolution Soccer 2013',
#  "Smuggler's Run",
#  'Fight Night Round 3',
#  'Twisted Metal',
#  'Dark Souls III',
#  'Pokemon Pinball: Ruby & Sapphire',
#  'LEGO Marvel Super Heroes',
#  'Mafia II',
#  'Dishonored',
#  'Stuntman',
#  "Tom Clancy's Rainbow Six 3",
#  'Active Life: Outdoor Challenge',
#  'BioShock 2',
#  '007: The World is not Enough',
#  'Spider-Man 2: Enter: Electro',
#  'Star Wars: The Force Unleashed II',
#  'Ni no Kuni: Wrath of the White Witch',
#  'LEGO Battles: Ninjago',
#  'Mario Party 10',
#  'Resident Evil: The Umbrella Chronicles',
#  'Dark Cloud',
#  "Tom Clancy's Ghost Recon Advanced Warfighter",
#  'Disney Fairies: Tinker Bell',
#  'MVP Baseball 2005',
#  'Die Hard Trilogy',
#  'Fight Night Round 4',
#  'MySims Kingdom',
#  'The Simpsons Game',
#  'NFL GameDay 99',
#  'Call of Duty: Modern Warfare: Reflex Edition',
#  'Mario Golf: Toadstool Tour',
#  'Tiger Woods 99 PGA Tour Golf',
#  'Donkey Kong Country: Tropical Freeze',
#  'Dead Space 2',
#  'Sonic Rivals 2',
#  ...]

# %%
# This worked pretty well, but I will alter the code further see if I can increase my scraping success to fail ratio

# %%
side_details = []
problem_games = []
abberant_side_detail_games = []
game_info_list = []
counter = 1

# zip the two 
zipped_list =list(zip(games_df["full_platform_name"].tolist(),games_df["Name"].tolist()))

for platform, name in zipped_list[3000:6000]:
    game_scores = {}
    x = re.compile("\.|:|;|\s|&")
    edited_game_title= re.sub(x,"-", name).lower().replace("---","-").replace("--","-").replace("'", "")
    # periods at the end of the url will show up as a dash. This conditional is to get rid of it.
    if edited_game_title[-1] == "-":
        edited_game_title = edited_game_title[:-1]
        print(f"\nGAME TITLE: {edited_game_title}")
    else:
        print(f"\nGAME TITLE: {edited_game_title}")
    browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
    # fill in my search term to the Metacritic Browser and us "\n" to press "enter" and initialize search
    
    game_scores["Name"]=name
    
    html= browser.html
    my_soup = soup(html, "lxml")
    # Grabbing the Metascore
    try:
        metascore = my_soup.find("a", class_="metascore_anchor").get_text()
        game_scores["metascore"]= metascore
    except:
        problem_games.append(name)
        print('THIS IS A PROBLEM CHILD')
        continue
    # Grabbing the Userscore
    try:
        userscore_first = my_soup.find("div", class_="details side_details")
        user_score = userscore_first.select("div.metascore_w")[0].get_text()
        game_scores["user_score"]= user_score
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing the release data
    try:
        product_data = my_soup.find("div",class_="product_data")
        release_data = product_data.find("li", class_="summary_detail release_data")
        release_date = release_data.find("span",class_="data").get_text()
        game_scores["release_date"]=release_date
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing the positive, mixed, and negative critic review numbers
    try:
        critic_reviews = []
        positive_scores = my_soup.find("div",class_="distribution_wrap")
        x = positive_scores.select("ol.score_counts.hover_none span.count")
        for i in x:
            critic_reviews.append(i.get_text())
        game_scores["positive_critics"] = critic_reviews[0]
        game_scores["neutral_critics"]=critic_reviews[1]
        game_scores["negative_critics"]=critic_reviews[2]
    except:
        problem_games.append(name)
        print('THIS IS A PROBLEM CHILD')
        continue
    # Grabbing the positive, mixed, and negative user review numbers
    try:
        user_reviews = []
        user_scores = my_soup.find("div",class_="user_reviews_module")
        drilling_down = user_scores.find("div",class_="distribution_wrap")
        ordered_list_html = drilling_down.select("ol.score_counts.hover_none span.count")
        for i in ordered_list_html:
            user_reviews.append(i.get_text())
        game_scores["positive_users"] = user_reviews[0]
        game_scores["neutral_users"]=user_reviews[1]
        game_scores["negative_users"]=user_reviews[2]
    except:
        problem_games.append(name)
        print("THIS IS A PROBLEM CHILD")
        continue
    # Grabbing side details
    try:
        side_details = my_soup.find_all("div", class_="details side_details")[1]
        unordered_list = side_details.select("ul.summary_details li")
        developer = unordered_list[0].find("span", class_="data").get_text()
        game_scores["developer"]=developer
        number_players = unordered_list[2].find("span",class_="data").get_text()
        game_scores["number_players"]=number_players
        rating = unordered_list[4].find("span", class_="data").get_text()
        game_scores["rating"]=rating
        game_info_list.append(game_scores)
        print('SUCCESSFUL')
        print(f"This is the {counter}th game in the list.")
        counter+=1
    except:
        abberant_side_detail_games.append(game_scores)
        print("SUCCESS but no side details")
        continue
# Out:
# GAME TITLE: bob-the-builder-can-we-fix-it?
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: xiii
# SUCCESSFUL
# This is the 1th game in the list.
#
# GAME TITLE: nhl-14
# SUCCESSFUL
# This is the 2th game in the list.
#
# GAME TITLE: lego-rock-band
# SUCCESS but no side details
#
# GAME TITLE: bolt
# SUCCESSFUL
# This is the 3th game in the list.
#
# GAME TITLE: top-spin-3
# SUCCESSFUL
# This is the 4th game in the list.
#
# GAME TITLE: tom-clancys-hawx
# SUCCESS but no side details
#
# GAME TITLE: lego-dimensions
# SUCCESS but no side details
#
# GAME TITLE: breath-of-fire-iv
# SUCCESSFUL
# This is the 5th game in the list.
#
# GAME TITLE: true-crime-streets-of-la
# SUCCESSFUL
# This is the 6th game in the list.
#
# GAME TITLE: odin-sphere
# SUCCESSFUL
# This is the 7th game in the list.
#
# GAME TITLE: donkey-kong-jungle-climber
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-incredible-hulk
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ms-pac-man-maze-madness
# SUCCESSFUL
# This is the 8th game in the list.
#
# GAME TITLE: arena-football
# SUCCESSFUL
# This is the 9th game in the list.
#
# GAME TITLE: the-lord-of-the-rings-the-return-of-the-king
# SUCCESSFUL
# This is the 10th game in the list.
#
# GAME TITLE: nhl-hitz-20-02
# SUCCESSFUL
# This is the 11th game in the list.
#
# GAME TITLE: classic-nes-series-dr-mario
# SUCCESSFUL
# This is the 12th game in the list.
#
# GAME TITLE: the-sims-bustin-out
# SUCCESSFUL
# This is the 13th game in the list.
#
# GAME TITLE: ncaa-march-madness-07
# SUCCESSFUL
# This is the 14th game in the list.
#
# GAME TITLE: monsters,-inc-scream-team
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: harry-potter-collection
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tony-hawks-project-8
# SUCCESSFUL
# This is the 15th game in the list.
#
# GAME TITLE: yu-gi-oh!-world-championship-tournament-2004
# SUCCESSFUL
# This is the 16th game in the list.
#
# GAME TITLE: cabelas-big-game-hunter-2005-adventures
# SUCCESSFUL
# This is the 17th game in the list.
#
# GAME TITLE: hotel-dusk-room-215
# SUCCESSFUL
# This is the 18th game in the list.
#
# GAME TITLE: knockout-kings-2001
# SUCCESSFUL
# This is the 19th game in the list.
#
# GAME TITLE: army-men-sarges-heroes
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: phineas-and-ferb-across-the-2nd-dimension
# SUCCESSFUL
# This is the 20th game in the list.
#
# GAME TITLE: petz-dogz-2
# SUCCESSFUL
# This is the 21th game in the list.
#
# GAME TITLE: battlefield-2-modern-combat
# SUCCESSFUL
# This is the 22th game in the list.
#
# GAME TITLE: wolfenstein
# SUCCESSFUL
# This is the 23th game in the list.
#
# GAME TITLE: all-star-baseball-2002
# SUCCESSFUL
# This is the 24th game in the list.
#
# GAME TITLE: backyard-nfl-football
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: need-for-speed-most-wanted
# SUCCESSFUL
# This is the 25th game in the list.
#
# GAME TITLE: nascar-rumble
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tony-hawk-shred
# SUCCESS but no side details
#
# GAME TITLE: tony-hawks-proving-ground
# SUCCESSFUL
# This is the 26th game in the list.
#
# GAME TITLE: wwe-raw-2
# SUCCESSFUL
# This is the 27th game in the list.
#
# GAME TITLE: resident-evil-2
# SUCCESSFUL
# This is the 28th game in the list.
#
# GAME TITLE: manhunt-2
# SUCCESSFUL
# This is the 29th game in the list.
#
# GAME TITLE: fullmetal-alchemist-and-the-broken-angel
# SUCCESSFUL
# This is the 30th game in the list.
#
# GAME TITLE: monster-high-ghoul-spirit
# SUCCESS but no side details
#
# GAME TITLE: final-fantasy-iv-the-complete-collection
# SUCCESSFUL
# This is the 31th game in the list.
#
# GAME TITLE: frontlines-fuel-of-war
# SUCCESSFUL
# This is the 32th game in the list.
#
# GAME TITLE: lips-number-one-hits
# SUCCESSFUL
# This is the 33th game in the list.
#
# GAME TITLE: batman-begins
# SUCCESSFUL
# This is the 34th game in the list.
#
# GAME TITLE: viva-pinata-pocket-paradise
# SUCCESSFUL
# This is the 35th game in the list.
#
# GAME TITLE: dr-seuss-the-cat-in-the-hat
# SUCCESSFUL
# This is the 36th game in the list.
#
# GAME TITLE: barbie-groovy-games
# SUCCESS but no side details
#
# GAME TITLE: yu-gi-oh!-reshef-of-destruction
# SUCCESSFUL
# This is the 37th game in the list.
#
# GAME TITLE: blinx-the-time-sweeper
# SUCCESSFUL
# This is the 38th game in the list.
#
# GAME TITLE: madagascar-escape-2-africa
# SUCCESSFUL
# This is the 39th game in the list.
#
# GAME TITLE: archer-macleans-mercury
# SUCCESSFUL
# This is the 40th game in the list.
#
# GAME TITLE: espn-nfl-football
# SUCCESSFUL
# This is the 41th game in the list.
#
# GAME TITLE: catz
# SUCCESSFUL
# This is the 42th game in the list.
#
# GAME TITLE: major-league-baseball-2k5
# SUCCESSFUL
# This is the 43th game in the list.
#
# GAME TITLE: ds-bimoji-training
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: petz-catz-clan
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: soul-sacrifice
# SUCCESS but no side details
#
# GAME TITLE: g-force
# SUCCESS but no side details
#
# GAME TITLE: tiger-woods-pga-tour-11
# SUCCESS but no side details
#
# GAME TITLE: soldier-of-fortune-gold-edition
# SUCCESSFUL
# This is the 44th game in the list.
#
# GAME TITLE: rune-factory-a-fantasy-harvest-moon
# SUCCESSFUL
# This is the 45th game in the list.
#
# GAME TITLE: monster-jam-path-of-destruction
# SUCCESS but no side details
#
# GAME TITLE: rapala-tournament-fishing!
# SUCCESSFUL
# This is the 46th game in the list.
#
# GAME TITLE: mx-2002-featuring-ricky-carmichael
# SUCCESSFUL
# This is the 47th game in the list.
#
# GAME TITLE: purr-pals
# SUCCESS but no side details
#
# GAME TITLE: ncaa-football-07
# SUCCESSFUL
# This is the 48th game in the list.
#
# GAME TITLE: god-of-war-origins-collection
# SUCCESSFUL
# This is the 49th game in the list.
#
# GAME TITLE: mx-vs-atv-alive
# SUCCESSFUL
# This is the 50th game in the list.
#
# GAME TITLE: lunar-silver-star-story-complete
# SUCCESSFUL
# This is the 51th game in the list.
#
# GAME TITLE: dragon-ball-xenoverse
# SUCCESSFUL
# This is the 52th game in the list.
#
# GAME TITLE: nba-showtime-nba-on-nbc
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: zhuzhu-pets-2-featuring-the-wild-bunch
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-age-inquisition
# SUCCESSFUL
# This is the 53th game in the list.
#
# GAME TITLE: soul-reaver-2
# SUCCESSFUL
# This is the 54th game in the list.
#
# GAME TITLE: metal-gear-solid-3-subsistence
# SUCCESSFUL
# This is the 55th game in the list.
#
# GAME TITLE: sly-cooper-thieves-in-time
# SUCCESSFUL
# This is the 56th game in the list.
#
# GAME TITLE: the-godfather-(old-us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: harry-potter-and-the-deathly-hallows-part-1
# SUCCESS but no side details
#
# GAME TITLE: tiger-woods-pga-tour-13
# SUCCESSFUL
# This is the 57th game in the list.
#
# GAME TITLE: wwf-raw
# SUCCESSFUL
# This is the 58th game in the list.
#
# GAME TITLE: shin-super-robot-taisen
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jump-super-stars
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: legends-of-wrestlemania
# SUCCESS but no side details
#
# GAME TITLE: simple-1500-series-vol-73-the-invaders-~space-invaders-1500~
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: 50-classic-games
# SUCCESSFUL
# This is the 59th game in the list.
#
# GAME TITLE: fighting-force-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: extermination
# SUCCESSFUL
# This is the 60th game in the list.
#
# GAME TITLE: batman-vengeance
# SUCCESSFUL
# This is the 61th game in the list.
#
# GAME TITLE: unit-13
# SUCCESSFUL
# This is the 62th game in the list.
#
# GAME TITLE: tatsunoko-vs-capcom-ultimate-all-stars
# SUCCESS but no side details
#
# GAME TITLE: tmnt
# SUCCESSFUL
# This is the 63th game in the list.
#
# GAME TITLE: f-e-a-r
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: secret-agent-clank(us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: derby-stallion-04
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-2k8
# SUCCESSFUL
# This is the 64th game in the list.
#
# GAME TITLE: barbie-horse-adventures-riding-camp
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: crosswords
# SUCCESSFUL
# This is the 65th game in the list.
#
# GAME TITLE: tony-hawks-pro-skater-3
# SUCCESSFUL
# This is the 66th game in the list.
#
# GAME TITLE: mega-man-zero
# SUCCESSFUL
# This is the 67th game in the list.
#
# GAME TITLE: contender-2
# SUCCESSFUL
# This is the 68th game in the list.
#
# GAME TITLE: the-amazing-spider-man-2-(2014)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: star-wars-dark-forces
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sd-gundam-g-generation-zero
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shrek-2
# SUCCESSFUL
# This is the 69th game in the list.
#
# GAME TITLE: soccer-tsuku-2002-j-league-pro-soccer-club-o-tsukurou!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: time-crisis-razing-storm
# SUCCESSFUL
# This is the 70th game in the list.
#
# GAME TITLE: spongebob-squarepants-supersponge
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: enslaved-odyssey-to-the-west
# SUCCESSFUL
# This is the 71th game in the list.
#
# GAME TITLE: summer-sports-paradise-island
# SUCCESSFUL
# This is the 72th game in the list.
#
# GAME TITLE: tak-and-the-power-of-juju
# SUCCESSFUL
# This is the 73th game in the list.
#
# GAME TITLE: dynasty-warriors-gundam-3
# SUCCESSFUL
# This is the 74th game in the list.
#
# GAME TITLE: mortal-kombat-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: turok-evolution
# SUCCESSFUL
# This is the 75th game in the list.
#
# GAME TITLE: jak-x-combat-racing
# SUCCESSFUL
# This is the 76th game in the list.
#
# GAME TITLE: metro-2033
# SUCCESSFUL
# This is the 77th game in the list.
#
# GAME TITLE: are-you-smarter-than-a-5th-grader?-make-the-grade
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: american-idol
# SUCCESSFUL
# This is the 78th game in the list.
#
# GAME TITLE: top-gun-fire-at-will!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: red-dead-revolver
# SUCCESSFUL
# This is the 79th game in the list.
#
# GAME TITLE: dragon-ball-z-shin-budokai
# SUCCESSFUL
# This is the 80th game in the list.
#
# GAME TITLE: lego-the-hobbit
# SUCCESSFUL
# This is the 81th game in the list.
#
# GAME TITLE: iron-man
# SUCCESSFUL
# This is the 82th game in the list.
#
# GAME TITLE: singstar-summer-party
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour-08
# SUCCESSFUL
# This is the 83th game in the list.
#
# GAME TITLE: nba-live-10
# SUCCESS but no side details
#
# GAME TITLE: the-spongebob-squarepants-movie
# SUCCESSFUL
# This is the 84th game in the list.
#
# GAME TITLE: fifa-soccer-07
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gekikuukan-pro-yakyuu-at-the-end-of-the-century-1999
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: excite-truck
# SUCCESSFUL
# This is the 85th game in the list.
#
# GAME TITLE: sacred-2-fallen-angel
# SUCCESSFUL
# This is the 86th game in the list.
#
# GAME TITLE: system-3-presents-ferrari-challenge-trofeo-pirelli
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dance-dance-revolution-ultramix
# SUCCESSFUL
# This is the 87th game in the list.
#
# GAME TITLE: modnation-racers
# SUCCESSFUL
# This is the 88th game in the list.
#
# GAME TITLE: crash-tag-team-racing
# SUCCESSFUL
# This is the 89th game in the list.
#
# GAME TITLE: two-worlds-ii
# SUCCESSFUL
# This is the 90th game in the list.
#
# GAME TITLE: sonic-all-stars-racing-transformed
# SUCCESSFUL
# This is the 91th game in the list.
#
# GAME TITLE: michael-jackson-the-experience
# SUCCESSFUL
# This is the 92th game in the list.
#
# GAME TITLE: front-mission-4
# SUCCESSFUL
# This is the 93th game in the list.
#
# GAME TITLE: the-fairly-odd-parents-breakin-da-rules
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lego-dimensions
# SUCCESSFUL
# This is the 94th game in the list.
#
# GAME TITLE: inazuma-eleven
# SUCCESS but no side details
#
# GAME TITLE: ninokuni-shikkoku-no-madoushi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: resident-evil-revelations-2
# SUCCESSFUL
# This is the 95th game in the list.
#
# GAME TITLE: manhunt-2
# SUCCESSFUL
# This is the 96th game in the list.
#
# GAME TITLE: srs-street-racing-syndicate
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: despicable-me-the-game-minion-mayhem
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: def-jam-fight-for-ny
# SUCCESSFUL
# This is the 97th game in the list.
#
# GAME TITLE: gauntlet-legends
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fifa-99
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kidou-senshi-gundam-extreme-vs
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-z-ultimate-tenkaichi
# SUCCESSFUL
# This is the 98th game in the list.
#
# GAME TITLE: tales-of-symphonia
# SUCCESSFUL
# This is the 99th game in the list.
#
# GAME TITLE: bust-a-groove
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fire-emblem-path-of-radiance
# SUCCESSFUL
# This is the 100th game in the list.
#
# GAME TITLE: dragon-quest-characters-torneko-no-daibouken-3-fushigi-no-dungeon
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lets-draw!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pachi-slot-aruze-oukoku-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-14
# SUCCESSFUL
# This is the 101th game in the list.
#
# GAME TITLE: valkyria-chronicles-ii
# SUCCESSFUL
# This is the 102th game in the list.
#
# GAME TITLE: middle-earth-shadow-of-mordor
# SUCCESS but no side details
#
# GAME TITLE: madden-nfl-13
# SUCCESS but no side details
#
# GAME TITLE: rune-factory-2-a-fantasy-harvest-moon
# SUCCESSFUL
# This is the 103th game in the list.
#
# GAME TITLE: terminator-salvation
# SUCCESSFUL
# This is the 104th game in the list.
#
# GAME TITLE: cars-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bratz-rock-angelz
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: how-to-train-your-dragon
# SUCCESS but no side details
#
# GAME TITLE: ssx-tricky
# SUCCESSFUL
# This is the 105th game in the list.
#
# GAME TITLE: wwe-smackdown-vs-raw-2010
# SUCCESS but no side details
#
# GAME TITLE: greg-hastings-tournament-paintball
# SUCCESSFUL
# This is the 106th game in the list.
#
# GAME TITLE: hello-kitty-big-city-dreams
# SUCCESS but no side details
#
# GAME TITLE: star-fox-command
# SUCCESSFUL
# This is the 107th game in the list.
#
# GAME TITLE: world-soccer-winning-eleven-7-international-(jp-version)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: espn-nba-basketball
# SUCCESSFUL
# This is the 108th game in the list.
#
# GAME TITLE: over-the-hedge
# SUCCESSFUL
# This is the 109th game in the list.
#
# GAME TITLE: mat-hoffmans-pro-bmx
# SUCCESSFUL
# This is the 110th game in the list.
#
# GAME TITLE: lego-star-wars-the-force-awakens
# SUCCESSFUL
# This is the 111th game in the list.
#
# GAME TITLE: epic-mickey-2-the-power-of-two
# SUCCESS but no side details
#
# GAME TITLE: magicians-quest-mysterious-times
# SUCCESSFUL
# This is the 112th game in the list.
#
# GAME TITLE: the-hobbit
# SUCCESSFUL
# This is the 113th game in the list.
#
# GAME TITLE: war-of-the-monsters
# SUCCESSFUL
# This is the 114th game in the list.
#
# GAME TITLE: tales-of-symphonia-dawn-of-the-new-world
# SUCCESSFUL
# This is the 115th game in the list.
#
# GAME TITLE: nba-street-vol-2
# SUCCESSFUL
# This is the 116th game in the list.
#
# GAME TITLE: the-incredible-hulk-ultimate-destruction
# SUCCESSFUL
# This is the 117th game in the list.
#
# GAME TITLE: jewel-master-egypt
# SUCCESS but no side details
#
# GAME TITLE: time-crisis-ii
# SUCCESSFUL
# This is the 118th game in the list.
#
# GAME TITLE: clock-tower
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ncaa-march-madness-06
# SUCCESSFUL
# This is the 119th game in the list.
#
# GAME TITLE: spongebob-squarepants-featuring-nicktoons-globs-of-doom
# SUCCESSFUL
# This is the 120th game in the list.
#
# GAME TITLE: jampack-volume-11
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragons-crown
# SUCCESSFUL
# This is the 121th game in the list.
#
# GAME TITLE: tactics-ogre-let-us-cling-together
# SUCCESSFUL
# This is the 122th game in the list.
#
# GAME TITLE: legacy-of-kain-defiance
# SUCCESS but no side details
#
# GAME TITLE: spongebob-squarepants-game-boy-advance-video-volume-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ncaa-march-madness-2005
# SUCCESSFUL
# This is the 123th game in the list.
#
# GAME TITLE: 007-racing
# SUCCESS but no side details
#
# GAME TITLE: conflict-vietnam
# SUCCESSFUL
# This is the 124th game in the list.
#
# GAME TITLE: 2-in-1-combo-pack-sonic-heroes-/-super-monkey-ball-deluxe
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mystery-dungeon-shiren-the-wanderer
# SUCCESSFUL
# This is the 125th game in the list.
#
# GAME TITLE: simanimals
# SUCCESS but no side details
#
# GAME TITLE: mlb-slugfest-20-04
# SUCCESSFUL
# This is the 126th game in the list.
#
# GAME TITLE: gex-3-deep-cover-gecko
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nascar-09
# SUCCESS but no side details
#
# GAME TITLE: blitz-the-league
# SUCCESSFUL
# This is the 127th game in the list.
#
# GAME TITLE: jampack-vol-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lego-jurassic-world
# SUCCESSFUL
# This is the 128th game in the list.
#
# GAME TITLE: sesame-street-once-upon-a-monster
# SUCCESSFUL
# This is the 129th game in the list.
#
# GAME TITLE: peter-jacksons-king-kong-the-official-game-of-the-movie
# SUCCESSFUL
# This is the 130th game in the list.
#
# GAME TITLE: singstar-dance
# SUCCESSFUL
# This is the 131th game in the list.
#
# GAME TITLE: kirby-and-the-rainbow-curse
# SUCCESSFUL
# This is the 132th game in the list.
#
# GAME TITLE: burnout-revenge
# SUCCESSFUL
# This is the 133th game in the list.
#
# GAME TITLE: fifa-12
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: medal-of-honor-european-assault
# SUCCESSFUL
# This is the 134th game in the list.
#
# GAME TITLE: ty-the-tasmanian-tiger-2-bush-rescue
# SUCCESSFUL
# This is the 135th game in the list.
#
# GAME TITLE: the-lord-of-the-rings-the-fellowship-of-the-ring
# SUCCESSFUL
# This is the 136th game in the list.
#
# GAME TITLE: nba-06
# SUCCESSFUL
# This is the 137th game in the list.
#
# GAME TITLE: sonic-all-stars-racing-transformed
# SUCCESSFUL
# This is the 138th game in the list.
#
# GAME TITLE: spider-man
# SUCCESS but no side details
#
# GAME TITLE: we-cheer
# SUCCESSFUL
# This is the 139th game in the list.
#
# GAME TITLE: tom-clancys-ghost-recon-advanced-warfighter-2
# SUCCESSFUL
# This is the 140th game in the list.
#
# GAME TITLE: x-men-legends
# SUCCESSFUL
# This is the 141th game in the list.
#
# GAME TITLE: alice-in-wonderland
# SUCCESSFUL
# This is the 142th game in the list.
#
# GAME TITLE: littlest-pet-shop-3-biggest-stars-blue-/-pink-/-purple-team
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: front-mission-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bulletstorm
# SUCCESSFUL
# This is the 143th game in the list.
#
# GAME TITLE: f-e-a-r-2-project-origin
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour-11
# SUCCESSFUL
# This is the 144th game in the list.
#
# GAME TITLE: stuntman-ignition
# SUCCESSFUL
# This is the 145th game in the list.
#
# GAME TITLE: are-you-smarter-than-a-5th-grader?
# SUCCESS but no side details
#
# GAME TITLE: f1-2009
# SUCCESSFUL
# This is the 146th game in the list.
#
# GAME TITLE: oni
# SUCCESSFUL
# This is the 147th game in the list.
#
# GAME TITLE: the-lord-of-the-rings-the-two-towers
# SUCCESSFUL
# This is the 148th game in the list.
#
# GAME TITLE: juiced
# SUCCESSFUL
# This is the 149th game in the list.
#
# GAME TITLE: the-warriors
# SUCCESSFUL
# This is the 150th game in the list.
#
# GAME TITLE: batman-arkham-origins-blackgate
# SUCCESSFUL
# This is the 151th game in the list.
#
# GAME TITLE: go-diego-go!-safari-rescue
# SUCCESS but no side details
#
# GAME TITLE: the-walking-dead-survival-instinct
# SUCCESS but no side details
#
# GAME TITLE: picross-3d
# SUCCESSFUL
# This is the 152th game in the list.
#
# GAME TITLE: silent-hill-origins
# SUCCESSFUL
# This is the 153th game in the list.
#
# GAME TITLE: nascar-2000
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: wayne-gretzkys-3d-hockey
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pachi-slot-aruze-oukoku-4
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: return-to-castle-wolfenstein-operation-resurrection
# SUCCESSFUL
# This is the 154th game in the list.
#
# GAME TITLE: mario-tennis-power-tour
# SUCCESSFUL
# This is the 155th game in the list.
#
# GAME TITLE: seaman
# SUCCESS but no side details
#
# GAME TITLE: guinness-world-records-the-videogame
# SUCCESS but no side details
#
# GAME TITLE: the-grinch
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gt-pro-series
# SUCCESSFUL
# This is the 156th game in the list.
#
# GAME TITLE: tales-of-destiny
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spectrobes-beyond-the-portals
# SUCCESSFUL
# This is the 157th game in the list.
#
# GAME TITLE: classic-word-games
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: naruto-shippuden-clash-of-ninja-revolution-3
# SUCCESS but no side details
#
# GAME TITLE: fight-night-round-3
# SUCCESSFUL
# This is the 158th game in the list.
#
# GAME TITLE: the-golden-compass
# SUCCESSFUL
# This is the 159th game in the list.
#
# GAME TITLE: final-fantasy-chronicles
# SUCCESSFUL
# This is the 160th game in the list.
#
# GAME TITLE: nba-live-08
# SUCCESSFUL
# This is the 161th game in the list.
#
# GAME TITLE: syphon-filter-3
# SUCCESSFUL
# This is the 162th game in the list.
#
# GAME TITLE: star-wars-battlefront-elite-squadron
# SUCCESSFUL
# This is the 163th game in the list.
#
# GAME TITLE: metal-gear-solid-2-substance
# SUCCESSFUL
# This is the 164th game in the list.
#
# GAME TITLE: we-love-katamari
# SUCCESSFUL
# This is the 165th game in the list.
#
# GAME TITLE: ncaa-football-2003
# SUCCESSFUL
# This is the 166th game in the list.
#
# GAME TITLE: way-of-the-samurai-3
# SUCCESS but no side details
#
# GAME TITLE: nba-live-09
# SUCCESSFUL
# This is the 167th game in the list.
#
# GAME TITLE: dc-universe-online
# SUCCESSFUL
# This is the 168th game in the list.
#
# GAME TITLE: ready-2-rumble-boxing-round-2
# SUCCESS but no side details
#
# GAME TITLE: mission-impossible
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rival-schools-united-by-fate
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bully-scholarship-edition
# SUCCESSFUL
# This is the 169th game in the list.
#
# GAME TITLE: il-2-sturmovik-birds-of-prey
# SUCCESSFUL
# This is the 170th game in the list.
#
# GAME TITLE: playstation-all-stars-battle-royale
# SUCCESSFUL
# This is the 171th game in the list.
#
# GAME TITLE: ratatouille
# SUCCESSFUL
# This is the 172th game in the list.
#
# GAME TITLE: cars-toon-maters-tall-tales
# SUCCESS but no side details
#
# GAME TITLE: kung-fu-panda
# SUCCESSFUL
# This is the 173th game in the list.
#
# GAME TITLE: swing-away-golf
# SUCCESSFUL
# This is the 174th game in the list.
#
# GAME TITLE: j-league-pro-soccer-club-o-tsukurou!-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tomb-raider-legend
# SUCCESSFUL
# This is the 175th game in the list.
#
# GAME TITLE: ratatouille
# SUCCESSFUL
# This is the 176th game in the list.
#
# GAME TITLE: freedom-fighters
# SUCCESSFUL
# This is the 177th game in the list.
#
# GAME TITLE: gun
# SUCCESSFUL
# This is the 178th game in the list.
#
# GAME TITLE: thats-so-raven-2-supernatural-style
# SUCCESS but no side details
#
# GAME TITLE: lair
# SUCCESSFUL
# This is the 179th game in the list.
#
# GAME TITLE: madden-nfl-07
# SUCCESSFUL
# This is the 180th game in the list.
#
# GAME TITLE: the-punisher
# SUCCESSFUL
# This is the 181th game in the list.
#
# GAME TITLE: front-mission-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kenkou-ouen-recipe-1000-ds-kondate-zenshuu
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ssx-on-tour
# SUCCESSFUL
# This is the 182th game in the list.
#
# GAME TITLE: tony-hawks-pro-skater-3
# SUCCESS but no side details
#
# GAME TITLE: harry-potter-and-the-prisoner-of-azkaban
# SUCCESSFUL
# This is the 183th game in the list.
#
# GAME TITLE: petz-hamsterz-life-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: omega-boost
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: iron-man
# SUCCESSFUL
# This is the 184th game in the list.
#
# GAME TITLE: nfl-2k3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-live-2002
# SUCCESSFUL
# This is the 185th game in the list.
#
# GAME TITLE: jampack-winter-2002
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: my-word-coach
# SUCCESSFUL
# This is the 186th game in the list.
#
# GAME TITLE: way-of-the-samurai
# SUCCESSFUL
# This is the 187th game in the list.
#
# GAME TITLE: naruto-shippuden-ultimate-ninja-storm-3
# SUCCESSFUL
# This is the 188th game in the list.
#
# GAME TITLE: pac-man-fever
# SUCCESSFUL
# This is the 189th game in the list.
#
# GAME TITLE: the-3rd-birthday
# SUCCESSFUL
# This is the 190th game in the list.
#
# GAME TITLE: prince-of-persia-trilogy
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: international-track-field
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: 100-all-time-favorites
# SUCCESS but no side details
#
# GAME TITLE: hsx-hypersonic-xtreme
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour-13
# SUCCESSFUL
# This is the 191th game in the list.
#
# GAME TITLE: soulcalibur-broken-destiny
# SUCCESSFUL
# This is the 192th game in the list.
#
# GAME TITLE: the-saboteur
# SUCCESS but no side details
#
# GAME TITLE: lords-of-the-fallen
# SUCCESSFUL
# This is the 193th game in the list.
#
# GAME TITLE: pro-evolution-soccer-2010
# SUCCESS but no side details
#
# GAME TITLE: goldeneye-007-reloaded
# SUCCESSFUL
# This is the 194th game in the list.
#
# GAME TITLE: jam-with-the-band
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: madden-nfl-2004
# SUCCESSFUL
# This is the 195th game in the list.
#
# GAME TITLE: jikkyou-powerful-pro-yakyuu-10
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: summoner
# SUCCESSFUL
# This is the 196th game in the list.
#
# GAME TITLE: virtual-pool
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-live-07
# SUCCESSFUL
# This is the 197th game in the list.
#
# GAME TITLE: sega-bass-fishing
# SUCCESSFUL
# This is the 198th game in the list.
#
# GAME TITLE: fire-emblem-radiant-dawn
# SUCCESSFUL
# This is the 199th game in the list.
#
# GAME TITLE: dynasty-warriors
# SUCCESSFUL
# This is the 200th game in the list.
#
# GAME TITLE: spongebob-squarepants-lights,-camera,-pants!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-raging-blast
# SUCCESS but no side details
#
# GAME TITLE: rugrats-scavenger-hunt
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: international-superstar-soccer-2000-(all-region-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: major-league-baseball-2k10
# SUCCESS but no side details
#
# GAME TITLE: monsters-vs-aliens
# SUCCESS but no side details
#
# GAME TITLE: transformers-war-for-cybertron-(xbox-360,-ps3,-pc-versions)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spongebob-squarepants-creature-from-the-krusty-krab
# SUCCESSFUL
# This is the 201th game in the list.
#
# GAME TITLE: lost-via-domus
# SUCCESSFUL
# This is the 202th game in the list.
#
# GAME TITLE: nba-live-2004
# SUCCESSFUL
# This is the 203th game in the list.
#
# GAME TITLE: dai-4-ji-super-robot-taisen-s
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disneys-kim-possible-revenge-of-monkey-fist
# SUCCESSFUL
# This is the 204th game in the list.
#
# GAME TITLE: wwe-smackdown-vs-raw-2007
# SUCCESSFUL
# This is the 205th game in the list.
#
# GAME TITLE: ace-combat-zero-the-belkan-war
# SUCCESSFUL
# This is the 206th game in the list.
#
# GAME TITLE: r-u-s-e
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disgaea-3-absence-of-justice
# SUCCESSFUL
# This is the 207th game in the list.
#
# GAME TITLE: test-drive-unlimited
# SUCCESSFUL
# This is the 208th game in the list.
#
# GAME TITLE: lego-dimensions
# SUCCESSFUL
# This is the 209th game in the list.
#
# GAME TITLE: picross-ds
# SUCCESSFUL
# This is the 210th game in the list.
#
# GAME TITLE: final-fantasy-ii-anniversary-edition
# SUCCESSFUL
# This is the 211th game in the list.
#
# GAME TITLE: nhl-07
# SUCCESSFUL
# This is the 212th game in the list.
#
# GAME TITLE: harry-potter-and-the-half-blood-prince
# SUCCESS but no side details
#
# GAME TITLE: nba-2k11
# SUCCESS but no side details
#
# GAME TITLE: world-championship-poker
# SUCCESSFUL
# This is the 213th game in the list.
#
# GAME TITLE: the-bigs
# SUCCESSFUL
# This is the 214th game in the list.
#
# GAME TITLE: burnout-revenge
# SUCCESSFUL
# This is the 215th game in the list.
#
# GAME TITLE: rory-mcilroy-pga-tour
# SUCCESSFUL
# This is the 216th game in the list.
#
# GAME TITLE: dragon-ball-z-supersonic-warriors
# SUCCESSFUL
# This is the 217th game in the list.
#
# GAME TITLE: paws-claws-dogs-cats-best-friends
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-ballers
# SUCCESSFUL
# This is the 218th game in the list.
#
# GAME TITLE: silent-hill-4-the-room
# SUCCESSFUL
# This is the 219th game in the list.
#
# GAME TITLE: capcom-classics-collection
# SUCCESSFUL
# This is the 220th game in the list.
#
# GAME TITLE: wolfenstein-the-new-order
# SUCCESS but no side details
#
# GAME TITLE: monopoly-party
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: hidden-mysteries-titanic-secrets-of-the-fateful-voyage
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nhl-faceoff-98
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-adventures-of-jimmy-neutron-boy-genius-attack-of-the-twonkies
# SUCCESS but no side details
#
# GAME TITLE: f1-2012
# SUCCESS but no side details
#
# GAME TITLE: nhl-09
# SUCCESS but no side details
#
# GAME TITLE: sonic-riders
# SUCCESSFUL
# This is the 221th game in the list.
#
# GAME TITLE: looney-tunes-back-in-action
# SUCCESSFUL
# This is the 222th game in the list.
#
# GAME TITLE: wet
# SUCCESSFUL
# This is the 223th game in the list.
#
# GAME TITLE: alice-madness-returns
# SUCCESSFUL
# This is the 224th game in the list.
#
# GAME TITLE: pro-evolution-soccer-2012
# SUCCESSFUL
# This is the 225th game in the list.
#
# GAME TITLE: tiger-woods-pga-tour-07
# SUCCESSFUL
# This is the 226th game in the list.
#
# GAME TITLE: midnight-club-ii
# SUCCESSFUL
# This is the 227th game in the list.
#
# GAME TITLE: atelier-rorona-alchemist-of-arland
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: monster-hunter-freedom-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-z-supersonic-warriors-2
# SUCCESSFUL
# This is the 228th game in the list.
#
# GAME TITLE: avatar-the-last-airbender
# SUCCESSFUL
# This is the 229th game in the list.
#
# GAME TITLE: blues-clues-blues-big-musical
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-mummy-returns
# SUCCESSFUL
# This is the 230th game in the list.
#
# GAME TITLE: hitman-blood-money
# SUCCESSFUL
# This is the 231th game in the list.
#
# GAME TITLE: disney-sing-it
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: activision-anthology
# SUCCESSFUL
# This is the 232th game in the list.
#
# GAME TITLE: crash-mind-over-mutant
# SUCCESS but no side details
#
# GAME TITLE: wwe-2k16
# SUCCESS but no side details
#
# GAME TITLE: lego-the-hobbit
# SUCCESSFUL
# This is the 233th game in the list.
#
# GAME TITLE: babysitting-mama
# SUCCESS but no side details
#
# GAME TITLE: boogie
# SUCCESSFUL
# This is the 234th game in the list.
#
# GAME TITLE: bleach-soul-resurreccion
# SUCCESSFUL
# This is the 235th game in the list.
#
# GAME TITLE: madden-nfl-07
# SUCCESSFUL
# This is the 236th game in the list.
#
# GAME TITLE: rugrats-in-paris-the-movie
# SUCCESS but no side details
#
# GAME TITLE: dance-dance-revolution-universe-2
# SUCCESSFUL
# This is the 237th game in the list.
#
# GAME TITLE: star-wars-jedi-starfighter
# SUCCESSFUL
# This is the 238th game in the list.
#
# GAME TITLE: tactics-ogre-the-knight-of-lodis
# SUCCESSFUL
# This is the 239th game in the list.
#
# GAME TITLE: fortune-street
# SUCCESS but no side details
#
# GAME TITLE: super-robot-taisen-mx
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: alice-in-wonderland
# SUCCESS but no side details
#
# GAME TITLE: nba-street-homecourt
# SUCCESSFUL
# This is the 240th game in the list.
#
# GAME TITLE: spider-man-2
# SUCCESSFUL
# This is the 241th game in the list.
#
# GAME TITLE: bases-loaded-96-double-header
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dead-or-alive-ultimate
# SUCCESSFUL
# This is the 242th game in the list.
#
# GAME TITLE: rpg-maker
# SUCCESSFUL
# This is the 243th game in the list.
#
# GAME TITLE: fifa-14
# SUCCESSFUL
# This is the 244th game in the list.
#
# GAME TITLE: star-wars-clone-wars
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: the-saboteur
# SUCCESSFUL
# This is the 245th game in the list.
#
# GAME TITLE: the-adventures-of-jimmy-neutron-boy-genius-attack-of-the-twonkies
# SUCCESSFUL
# This is the 246th game in the list.
#
# GAME TITLE: metal-gear-rising-revengeance
# SUCCESSFUL
# This is the 247th game in the list.
#
# GAME TITLE: madden-nfl-11
# SUCCESS but no side details
#
# GAME TITLE: major-league-baseball-2k12
# SUCCESS but no side details
#
# GAME TITLE: the-price-is-right
# SUCCESSFUL
# This is the 248th game in the list.
#
# GAME TITLE: monster-hunter
# SUCCESSFUL
# This is the 249th game in the list.
#
# GAME TITLE: cars-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dreamworks-madagascar-kartz
# SUCCESSFUL
# This is the 250th game in the list.
#
# GAME TITLE: tony-hawks-underground-2
# SUCCESSFUL
# This is the 251th game in the list.
#
# GAME TITLE: splashdown-rides-gone-wild
# SUCCESSFUL
# This is the 252th game in the list.
#
# GAME TITLE: dynasty-warriors-gundam-2
# SUCCESS but no side details
#
# GAME TITLE: shrek-superslam
# SUCCESSFUL
# This is the 253th game in the list.
#
# GAME TITLE: rayman-advance
# SUCCESS but no side details
#
# GAME TITLE: super-robot-taisen-z
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: popolocrois-monogatari
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tomb-raider-anniversary
# SUCCESSFUL
# This is the 254th game in the list.
#
# GAME TITLE: fantastic-4
# SUCCESSFUL
# This is the 255th game in the list.
#
# GAME TITLE: epic-mickey-2-the-power-of-two
# SUCCESS but no side details
#
# GAME TITLE: men-in-black-ii-alien-escape
# SUCCESSFUL
# This is the 256th game in the list.
#
# GAME TITLE: the-evil-within
# SUCCESSFUL
# This is the 257th game in the list.
#
# GAME TITLE: nicktoons-attack-of-the-toybots
# SUCCESS but no side details
#
# GAME TITLE: cars-mater-national-championship
# SUCCESSFUL
# This is the 258th game in the list.
#
# GAME TITLE: ace-combat-assault-horizon
# SUCCESSFUL
# This is the 259th game in the list.
#
# GAME TITLE: tony-hawks-project-8
# SUCCESSFUL
# This is the 260th game in the list.
#
# GAME TITLE: tony-hawks-underground-2
# SUCCESSFUL
# This is the 261th game in the list.
#
# GAME TITLE: motorstorm-apocalypse
# SUCCESSFUL
# This is the 262th game in the list.
#
# GAME TITLE: dragon-quest-heroes-the-worlds-tree-woe-and-the-blight-below
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lego-batman-3-beyond-gotham
# SUCCESS but no side details
#
# GAME TITLE: the-matrix-path-of-neo
# SUCCESS but no side details
#
# GAME TITLE: kane-lynch-2-dog-days
# SUCCESSFUL
# This is the 263th game in the list.
#
# GAME TITLE: lollipop-chainsaw
# SUCCESS but no side details
#
# GAME TITLE: wwe-wrestlemania-x8
# SUCCESSFUL
# This is the 264th game in the list.
#
# GAME TITLE: power-rangers-dino-thunder
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: goldeneye-rogue-agent
# SUCCESSFUL
# This is the 265th game in the list.
#
# GAME TITLE: ultimate-i-spy
# SUCCESS but no side details
#
# GAME TITLE: spongebob-squarepants-creature-from-the-krusty-krab
# SUCCESSFUL
# This is the 266th game in the list.
#
# GAME TITLE: the-sims
# SUCCESSFUL
# This is the 267th game in the list.
#
# GAME TITLE: grandia-iii
# SUCCESSFUL
# This is the 268th game in the list.
#
# GAME TITLE: fifa-soccer-09
# SUCCESS but no side details
#
# GAME TITLE: mobile-suit-gundam-seed-destiny-rengou-vs-z-a-f-t-ii-plus
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: scarface-the-world-is-yours
# SUCCESSFUL
# This is the 269th game in the list.
#
# GAME TITLE: transformers-revenge-of-the-fallen-(xbox-360,-ps3,-pc-versions)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: fifa-soccer-64
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-z-burst-limit
# SUCCESSFUL
# This is the 270th game in the list.
#
# GAME TITLE: bakugan-battle-brawlers-defenders-of-the-core
# SUCCESSFUL
# This is the 271th game in the list.
#
# GAME TITLE: doom-3-bfg-edition
# SUCCESSFUL
# This is the 272th game in the list.
#
# GAME TITLE: terraria
# SUCCESSFUL
# This is the 273th game in the list.
#
# GAME TITLE: backyard-baseball
# SUCCESSFUL
# This is the 274th game in the list.
#
# GAME TITLE: wipeout-pulse
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: barbie-horse-adventures-wild-horse-rescue
# SUCCESSFUL
# This is the 275th game in the list.
#
# GAME TITLE: lego-marvel-super-heroes
# SUCCESS but no side details
#
# GAME TITLE: taiko-no-tatsujin-appare-sandaime
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: alone-in-the-dark
# SUCCESSFUL
# This is the 276th game in the list.
#
# GAME TITLE: one-piece-grand-battle!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: transformers-revenge-of-the-fallen-(xbox-360,-ps3,-pc-versions)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: football-manager-handheld-2009
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: crazy-taxi
# SUCCESSFUL
# This is the 277th game in the list.
#
# GAME TITLE: spy-hunter-2
# SUCCESSFUL
# This is the 278th game in the list.
#
# GAME TITLE: f1-2014
# SUCCESSFUL
# This is the 279th game in the list.
#
# GAME TITLE: pac-man-world-2
# SUCCESSFUL
# This is the 280th game in the list.
#
# GAME TITLE: bass-pro-shops-the-strike
# SUCCESS but no side details
#
# GAME TITLE: die-hard-trilogy-2-viva-las-vegas
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jake-power-fireman
# SUCCESS but no side details
#
# GAME TITLE: momotarou-dentetsu-x-kyuushuu-hen-mo-arubai
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tales-of-legendia
# SUCCESSFUL
# This is the 281th game in the list.
#
# GAME TITLE: crash-of-the-titans
# SUCCESSFUL
# This is the 282th game in the list.
#
# GAME TITLE: battlefield-hardline
# SUCCESSFUL
# This is the 283th game in the list.
#
# GAME TITLE: harry-potter-and-the-order-of-the-phoenix
# SUCCESSFUL
# This is the 284th game in the list.
#
# GAME TITLE: rayman-raving-rabbids-tv-party
# SUCCESS but no side details
#
# GAME TITLE: f-e-a-r-2-project-origin
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sonic-all-stars-racing-transformed
# SUCCESSFUL
# This is the 285th game in the list.
#
# GAME TITLE: scene-it?-lights-camera-action
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dead-space-extraction
# SUCCESSFUL
# This is the 286th game in the list.
#
# GAME TITLE: scrabble-2007-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: shrek-the-third
# SUCCESSFUL
# This is the 287th game in the list.
#
# GAME TITLE: metal-gear-solid-hd-edition
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: children-of-mana
# SUCCESSFUL
# This is the 288th game in the list.
#
# GAME TITLE: madagascar-operation-penguin
# SUCCESS but no side details
#
# GAME TITLE: active-life-extreme-challenge
# SUCCESS but no side details
#
# GAME TITLE: the-sims-2-pets
# SUCCESSFUL
# This is the 289th game in the list.
#
# GAME TITLE: need-for-speed-porsche-unleashed
# SUCCESSFUL
# This is the 290th game in the list.
#
# GAME TITLE: yu-gi-oh!-forbidden-memories-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nfl-street-2
# SUCCESSFUL
# This is the 291th game in the list.
#
# GAME TITLE: silent-hill-shattered-memories
# SUCCESSFUL
# This is the 292th game in the list.
#
# GAME TITLE: youre-in-the-movies
# SUCCESSFUL
# This is the 293th game in the list.
#
# GAME TITLE: dark-sector
# SUCCESSFUL
# This is the 294th game in the list.
#
# GAME TITLE: james-bond-007-blood-stone
# SUCCESSFUL
# This is the 295th game in the list.
#
# GAME TITLE: jeopardy!
# SUCCESSFUL
# This is the 296th game in the list.
#
# GAME TITLE: destroy-all-humans!-2
# SUCCESSFUL
# This is the 297th game in the list.
#
# GAME TITLE: ecw-hardcore-revolution
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: pinball-hall-of-fame-the-williams-collection
# SUCCESSFUL
# This is the 298th game in the list.
#
# GAME TITLE: tiger-woods-pga-tour-07
# SUCCESSFUL
# This is the 299th game in the list.
#
# GAME TITLE: wu-tang-shaolin-style
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rock-band-unplugged
# SUCCESS but no side details
#
# GAME TITLE: okamiden
# SUCCESS but no side details
#
# GAME TITLE: crash-mind-over-mutant
# SUCCESSFUL
# This is the 300th game in the list.
#
# GAME TITLE: 2010-fifa-world-cup-south-africa
# SUCCESSFUL
# This is the 301th game in the list.
#
# GAME TITLE: secret-weapons-over-normandy
# SUCCESSFUL
# This is the 302th game in the list.
#
# GAME TITLE: go-diego-go!-great-dinosaur-rescue
# SUCCESS but no side details
#
# GAME TITLE: all-star-baseball-99
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: harvest-moon-64
# SUCCESSFUL
# This is the 303th game in the list.
#
# GAME TITLE: ncaa-football-09
# SUCCESS but no side details
#
# GAME TITLE: bratz-the-movie
# SUCCESS but no side details
#
# GAME TITLE: fifa-soccer-13
# SUCCESSFUL
# This is the 304th game in the list.
#
# GAME TITLE: harvest-moon-ds-(us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: vigilante-8-2nd-offense
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: two-worlds-ii
# SUCCESSFUL
# This is the 305th game in the list.
#
# GAME TITLE: theme-park-roller-coaster
# SUCCESSFUL
# This is the 306th game in the list.
#
# GAME TITLE: need-for-speed-hot-pursuit
# SUCCESS but no side details
#
# GAME TITLE: skylanders-superchargers
# SUCCESS but no side details
#
# GAME TITLE: viva-pinata-trouble-in-paradise
# SUCCESSFUL
# This is the 307th game in the list.
#
# GAME TITLE: nickelodeon-team-umizoomi
# SUCCESS but no side details
#
# GAME TITLE: flingsmash
# SUCCESS but no side details
#
# GAME TITLE: nfl-xtreme-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spider-man-3
# SUCCESSFUL
# This is the 308th game in the list.
#
# GAME TITLE: midnight-club-street-racing
# SUCCESSFUL
# This is the 309th game in the list.
#
# GAME TITLE: dynasty-warriors-gundam
# SUCCESSFUL
# This is the 310th game in the list.
#
# GAME TITLE: tomb-raider-underworld
# SUCCESSFUL
# This is the 311th game in the list.
#
# GAME TITLE: final-fantasy-crystal-chronicles-echoes-of-time
# SUCCESS but no side details
#
# GAME TITLE: fable
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tiger-woods-pga-tour-06
# SUCCESSFUL
# This is the 312th game in the list.
#
# GAME TITLE: fifa-world-cup-germany-2006
# SUCCESSFUL
# This is the 313th game in the list.
#
# GAME TITLE: up
# SUCCESS but no side details
#
# GAME TITLE: ford-racing-off-road
# SUCCESS but no side details
#
# GAME TITLE: simcity-creator
# SUCCESSFUL
# This is the 314th game in the list.
#
# GAME TITLE: world-of-outlaws-sprint-cars-2002
# SUCCESSFUL
# This is the 315th game in the list.
#
# GAME TITLE: cars-race-o-rama
# SUCCESS but no side details
#
# GAME TITLE: emergency-heroes
# SUCCESSFUL
# This is the 316th game in the list.
#
# GAME TITLE: sonic-the-hedgehog
# SUCCESSFUL
# This is the 317th game in the list.
#
# GAME TITLE: fantavision
# SUCCESSFUL
# This is the 318th game in the list.
#
# GAME TITLE: alien-trilogy
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: nba-live-99
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dark-sector
# SUCCESSFUL
# This is the 319th game in the list.
#
# GAME TITLE: unreal-tournament-iii
# SUCCESSFUL
# This is the 320th game in the list.
#
# GAME TITLE: x-men-next-dimension
# SUCCESSFUL
# This is the 321th game in the list.
#
# GAME TITLE: street-fighter-x-tekken
# SUCCESS but no side details
#
# GAME TITLE: the-godfather-(jp-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mysims-racing
# SUCCESSFUL
# This is the 322th game in the list.
#
# GAME TITLE: hamsterz-life
# SUCCESSFUL
# This is the 323th game in the list.
#
# GAME TITLE: dragon-age-origins-awakening
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: gauntlet-legends
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: castlevania-dawn-of-sorrow
# SUCCESSFUL
# This is the 324th game in the list.
#
# GAME TITLE: naruto-shippuden-ultimate-ninja-storm-revolution
# SUCCESSFUL
# This is the 325th game in the list.
#
# GAME TITLE: deadpool
# SUCCESSFUL
# This is the 326th game in the list.
#
# GAME TITLE: wipeout
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: ico
# SUCCESSFUL
# This is the 327th game in the list.
#
# GAME TITLE: silent-hill-downpour
# SUCCESSFUL
# This is the 328th game in the list.
#
# GAME TITLE: 2014-fifa-world-cup-brazil
# SUCCESS but no side details
#
# GAME TITLE: wwe-smackdown-vs-raw-2011
# SUCCESS but no side details
#
# GAME TITLE: dragon-quest-25-shuunen-kinin-famicom-super-famicom-dragon-quest-i-ii-iii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: victorious-boxers-ippos-road-to-glory
# SUCCESSFUL
# This is the 329th game in the list.
#
# GAME TITLE: petz-sports
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: lego-batman-3-beyond-gotham
# SUCCESSFUL
# This is the 330th game in the list.
#
# GAME TITLE: densetsu-no-stafi
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: valkyrie-profile-2-silmeria
# SUCCESSFUL
# This is the 331th game in the list.
#
# GAME TITLE: hot-wheels-velocity-x
# SUCCESSFUL
# This is the 332th game in the list.
#
# GAME TITLE: shadowrun
# SUCCESSFUL
# This is the 333th game in the list.
#
# GAME TITLE: fifa-soccer-13
# SUCCESSFUL
# This is the 334th game in the list.
#
# GAME TITLE: virtua-tennis-4-world-tour
# SUCCESSFUL
# This is the 335th game in the list.
#
# GAME TITLE: crazy-taxi-fare-wars
# SUCCESSFUL
# This is the 336th game in the list.
#
# GAME TITLE: clash-of-elementalists
# SUCCESS but no side details
#
# GAME TITLE: spider-man-3
# SUCCESSFUL
# This is the 337th game in the list.
#
# GAME TITLE: disney-infinity-3-0
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: l-a-rush
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bomberman-hero
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: automobili-lamborghini
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: quest-64
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: momotarou-dentetsu-v
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: doom-64
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: boom-blox-bash-party
# SUCCESS but no side details
#
# GAME TITLE: dead-or-alive-4
# SUCCESSFUL
# This is the 338th game in the list.
#
# GAME TITLE: rise-of-nightmares
# SUCCESSFUL
# This is the 339th game in the list.
#
# GAME TITLE: the-princess-and-the-frog
# SUCCESSFUL
# This is the 340th game in the list.
#
# GAME TITLE: nba-ballers-phenom
# SUCCESSFUL
# This is the 341th game in the list.
#
# GAME TITLE: need-for-speed-carbon
# SUCCESSFUL
# This is the 342th game in the list.
#
# GAME TITLE: tiger-woods-pga-tour-07
# SUCCESSFUL
# This is the 343th game in the list.
#
# GAME TITLE: mtv-music-generator
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: spider-man-friend-or-foe
# SUCCESSFUL
# This is the 344th game in the list.
#
# GAME TITLE: major-league-baseball-2k13
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: world-soccer-winning-eleven-8-liveware-evolution
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: cars-race-o-rama
# SUCCESS but no side details
#
# GAME TITLE: downhill-domination
# SUCCESSFUL
# This is the 345th game in the list.
#
# GAME TITLE: nhl-15
# SUCCESSFUL
# This is the 346th game in the list.
#
# GAME TITLE: pirates-of-the-caribbean-dead-mans-chest
# SUCCESSFUL
# This is the 347th game in the list.
#
# GAME TITLE: world-series-of-poker
# SUCCESSFUL
# This is the 348th game in the list.
#
# GAME TITLE: nhl-97
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: we-sing-encore
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: kong-the-8th-wonder-of-the-world
# SUCCESSFUL
# This is the 349th game in the list.
#
# GAME TITLE: mx-vs-atv-alive
# SUCCESSFUL
# This is the 350th game in the list.
#
# GAME TITLE: mega-man-star-force-3-black-ace-/-red-joker
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: crayola-treasure-adventures
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: godzilla-save-the-earth
# SUCCESSFUL
# This is the 351th game in the list.
#
# GAME TITLE: dance-dance-revolution-mario-mix
# SUCCESSFUL
# This is the 352th game in the list.
#
# GAME TITLE: metal-gear-solid-the-twin-snakes
# SUCCESSFUL
# This is the 353th game in the list.
#
# GAME TITLE: imagine-figure-skater-(us-sales)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: mat-hoffmans-pro-bmx-2
# SUCCESSFUL
# This is the 354th game in the list.
#
# GAME TITLE: metal-gear-solid-the-essential-collection
# SUCCESSFUL
# This is the 355th game in the list.
#
# GAME TITLE: the-legend-of-spyro-dawn-of-the-dragon
# SUCCESS but no side details
#
# GAME TITLE: iridion-3d
# SUCCESSFUL
# This is the 356th game in the list.
#
# GAME TITLE: mx-vs-atv-untamed
# SUCCESSFUL
# This is the 357th game in the list.
#
# GAME TITLE: classic-nes-series-pac-man
# SUCCESSFUL
# This is the 358th game in the list.
#
# GAME TITLE: destroy-all-humans!
# SUCCESS but no side details
#
# GAME TITLE: dragon-ball-z-collectible-card-game
# SUCCESSFUL
# This is the 359th game in the list.
#
# GAME TITLE: country-dance-2
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: razor-freestyle-scooter
# SUCCESS but no side details
#
# GAME TITLE: crash-of-the-titans
# SUCCESSFUL
# This is the 360th game in the list.
#
# GAME TITLE: f-e-a-r-3
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: disneys-kim-possible-3-team-possible
# SUCCESSFUL
# This is the 361th game in the list.
#
# GAME TITLE: rygar-the-legendary-adventure
# SUCCESSFUL
# This is the 362th game in the list.
#
# GAME TITLE: syphon-filter-logans-shadow
# SUCCESSFUL
# This is the 363th game in the list.
#
# GAME TITLE: kessen-ii
# SUCCESSFUL
# This is the 364th game in the list.
#
# GAME TITLE: stuart-little-2
# SUCCESSFUL
# This is the 365th game in the list.
#
# GAME TITLE: warhammer-40,000-space-marine
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: tak-2-the-staff-of-dreams
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: sid-meiers-civilization-revolution
# SUCCESS but no side details
#
# GAME TITLE: atv-offroad-fury-pro
# SUCCESSFUL
# This is the 366th game in the list.
#
# GAME TITLE: dora-the-explorer-dora-saves-the-snow-princess
# SUCCESS but no side details
#
# GAME TITLE: singstar-amped
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: brothers-in-arms-earned-in-blood
# SUCCESSFUL
# This is the 367th game in the list.
#
# GAME TITLE: walk-it-out!
# SUCCESSFUL
# This is the 368th game in the list.
#
# GAME TITLE: transformers-dark-of-the-moon-autobots/decepticons
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: dragon-ball-z-sagas
# SUCCESSFUL
# This is the 369th game in the list.
#
# GAME TITLE: scooby-doo
# SUCCESS but no side details
#
# GAME TITLE: the-legend-of-spyro-dawn-of-the-dragon
# SUCCESSFUL
# This is the 370th game in the list.
#
# GAME TITLE: hydro-thunder
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: brothers-in-arms-d-day
# SUCCESSFUL
# This is the 371th game in the list.
#
# GAME TITLE: american-girl-kit-mystery-challenge!
# SUCCESS but no side details
#
# GAME TITLE: nhl-faceoff-97
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: deadpool
# SUCCESSFUL
# This is the 372th game in the list.
#
# GAME TITLE: brothers-in-arms-road-to-hill-30
# SUCCESSFUL
# This is the 373th game in the list.
#
# GAME TITLE: virtua-tennis-4
# SUCCESSFUL
# This is the 374th game in the list.
#
# GAME TITLE: the-mark-of-kri
# SUCCESSFUL
# This is the 375th game in the list.
#
# GAME TITLE: jampack-winter-2003-(rp-m)
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: rugrats-castle-capers
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: crash-nitro-kart
# SUCCESSFUL
# This is the 376th game in the list.
#
# GAME TITLE: star-wars-the-clone-wars-republic-heroes
# SUCCESSFUL
# This is the 377th game in the list.
#
# GAME TITLE: farming-simulator-2015
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: bleach-the-blade-of-fate
# SUCCESSFUL
# This is the 378th game in the list.
#
# GAME TITLE: madden-nfl-12
# SUCCESS but no side details
#
# GAME TITLE: lego-rock-band
# SUCCESS but no side details
#
# GAME TITLE: barbie-jet,-set-style!
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: jak-and-daxter-the-lost-frontier
# SUCCESS but no side details
#
# GAME TITLE: momotarou-dentetsu-11
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: command-conquer-red-alert-3
# SUCCESSFUL
# This is the 379th game in the list.
#
# GAME TITLE: tomb-raider-legend
# SUCCESSFUL
# This is the 380th game in the list.
#
# GAME TITLE: skylanders-superchargers
# SUCCESS but no side details
#
# GAME TITLE: the-golden-compass
# SUCCESSFUL
# This is the 381th game in the list.
#
# GAME TITLE: star-wars-demolition
# SUCCESS but no side details
#
# GAME TITLE: scooby-doo!-and-the-spooky-swamp
# SUCCESSFUL
# This is the 382th game in the list.
#
# GAME TITLE: sword-art-online-lost-song
# SUCCESSFUL
# This is the 383th game in the list.
#
# GAME TITLE: bloody-roar-ii
# THIS IS A PROBLEM CHILD
#
# GAME TITLE: delta-force-black-hawk-down
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4525447671e8> in <module>
#      18     else:
#      19         print(f"\nGAME TITLE: {edited_game_title}")
# ---> 20     browser.visit(f"https://www.metacritic.com/game/{platform}/{edited_game_title}")
#      21     # fill in my search term to the Metacritic Browser and us "\n" to press "enter" and initialize search
#      22
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py in visit(self, url)
#     285
#     286     def visit(self, url):
# --> 287         self.driver.get(url)
#     288
#     289     def back(self):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/splinter/driver/webdriver/remote_connection.py in patch_request(self, *args, **kwargs)
#      21     for _ in range(3):
#      22         try:
# ---> 23             return old_request(self, *args, **kwargs)
#      24         except (socket.error, HTTPException, IOError, OSError, MaxRetryError) as exc:
#      25             exception = exc
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
game_info_list

# %%
#scraping_df = pd.DataFrame(game_info_list)
#scraping_df.to_csv("../Resources/scraped_ratings2")

# %%
# get developer, genre, number_players, rating, release_date

# %%
len(problem_games)

# %%
#problem_ratings = pd.DataFrame(problem_games)
#problem_ratings.to_csv("../Resources/problem_ratings2")

# %%
#'& III ! Pokémon

# %%
len(abberant_side_detail_games)
