# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../Resources/final_scrape.csv")
df
# Out:
#       Unnamed: 0                           Name metascore user_score  \
# 0              0                     Wii Sports    \n76\n        8.0
# 1              1                 Mario Kart Wii    \n82\n        8.4
# 2              2              Wii Sports Resort    \n80\n        8.1
# 3              3          New Super Mario Bros.    \n89\n        8.5
# 4              4                       Wii Play    \n58\n        6.5
# ...          ...                            ...       ...        ...
# 8411        8411            Mini Desktop Racing   \n2.3\n        2.3
# 8412        8412              PGA European Tour    \n58\n        8.0
# 8413        8413                Planet Monsters    \n67\n        tbd
# 8414        8414               Bust-A-Move 3000    \n53\n        tbd
# 8415        8415  Men in Black II: Alien Escape   \ntbd\n        tbd
#
#       release_date  positive_critics  neutral_critics  negative_critics  \
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df["developer"] = df["developer"].str.extract("\s*\n\s*(\w+)\s*")

# %%
df.drop("developer2",axis=1, inplace=True)

# %%
df
# Out:
#                                Name metascore user_score  release_date  \
# 0                        Wii Sports    \n76\n        8.0  Nov 19, 2006
# 1                    Mario Kart Wii    \n82\n        8.4  Apr 27, 2008
# 2                 Wii Sports Resort    \n80\n        8.1  Jul 26, 2009
# 3             New Super Mario Bros.    \n89\n        8.5  May 15, 2006
# 4                          Wii Play    \n58\n        6.5  Feb 12, 2007
# ...                             ...       ...        ...           ...
# 8411            Mini Desktop Racing   \n2.3\n        2.3  Dec  4, 2007
# 8412              PGA European Tour    \n58\n        8.0  Jun 15, 2000
# 8413                Planet Monsters    \n67\n        tbd  Dec  6, 2001
# 8414               Bust-A-Move 3000    \n53\n        tbd  Feb 12, 2003
# 8415  Men in Black II: Alien Escape   \ntbd\n        tbd  Feb 27, 2003
#
#       positive_critics  neutral_critics  negative_critics positive_users  \
# ...

# %%
games_df = pd.read_csv("../Resources/vgsales.csv.zip")

# %%
games_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
combo_df = pd.merge(games_df, df, on=["Name"], how="left")

# %%
sns.heatmap(combo_df.isnull(), yticklabels=False, cbar=False, cmap="viridis")

# %%
combo_df[combo_df["Name"] == "Call of Duty: Modern Warfare 2"]
# Out:
#       Rank                            Name Platform    Year    Genre  \
# 51      37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 52      37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 79      56  Call of Duty: Modern Warfare 2      PS3  2009.0  Shooter
# 80      56  Call of Duty: Modern Warfare 2      PS3  2009.0  Shooter
# 4797  2349  Call of Duty: Modern Warfare 2       PC  2009.0  Shooter
# 4798  2349  Call of Duty: Modern Warfare 2       PC  2009.0  Shooter
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  ...  \
# 51    Activision      8.52      3.63      0.08         1.29  ...
# 52    Activision      8.52      3.63      0.08         1.29  ...
# 79    Activision      4.99      3.69      0.38         1.63  ...
# 80    Activision      4.99      3.69      0.38         1.63  ...
# 4797  Activision      0.01      0.79      0.00         0.09  ...
# 4798  Activision      0.01      0.79      0.00         0.09  ...
#
# ...

# %%
combo_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 28509  16597                     Men in Black II: Alien Escape       GC
# 28510  16597                     Men in Black II: Alien Escape       GC
# 28511  16598  SCORE International Baja 1000: The Official Game      PS2
# 28512  16599                                        Know How 2       DS
# 28513  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Out:
# 25014

# %%
games_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df = pd.read_csv('../Resources/final_scrape5.csv')
df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
combo_df = pd.merge(games_df, df, how="left", left_on=["Name", "Platform"], right_on=["Name","Platform"])

# %% [markdown]
# df.head()

# %%
combo_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df["Platform"].value_counts().index.tolist()
# Out:
# ['playstation-2',
#  'xbox-360',
#  'playstation-3',
#  'ds',
#  'wii',
#  'xbox',
#  'psp',
#  'gamecube',
#  'game-boy-advance',
#  'playstation-4',
#  'playstation',
#  'playstation-vita',
#  'wii-u',
#  'nintendo-64',
#  'dreamcast']

# %%
games_df["Platform"].value_counts().index.tolist()
# Out:
# ['DS',
#  'PS2',
#  'PS3',
#  'Wii',
#  'X360',
#  'PSP',
#  'PS',
#  'PC',
#  'XB',
#  'GBA',
#  'GC',
#  '3DS',
#  'PSV',
#  'PS4',
#  'N64',
#  'SNES',
#  'XOne',
#  'SAT',
#  'WiiU',
#  '2600',
#  'NES',
#  'GB',
#  'DC',
#  'GEN',
#  'NG',
#  'SCD',
#  'WS',
#  '3DO',
#  'TG16',
#  'PCFX',
#  'GG']

# %%
games= games_df["Name"].tolist()
ratings = df["Name"].tolist()
def returnNotMatches(games, ratings):
    return [[x for x in games if x not in ratings], [x for x in ratings if x not in games]]

# %%
returnNotMatches(games, ratings)
# Out:
# [['Super Mario Bros.',
#   'Pokemon Red/Pokemon Blue',
#   'Tetris',
#   'Duck Hunt',
#   'Nintendogs',
#   'Pokemon Gold/Pokemon Silver',
#   'Super Mario World',
#   'Pokemon Diamond/Pokemon Pearl',
#   'Super Mario Land',
#   'Super Mario Bros. 3',
#   'Pokemon Ruby/Pokemon Sapphire',
#   'Pokemon Black/Pokemon White',
#   'Pokémon Yellow: Special Pikachu Edition',
#   'Pokemon X/Pokemon Y',
#   'Call of Duty: Black Ops 3',
#   'Mario Kart 7',
#   'Pokemon HeartGold/Pokemon SoulSilver',
#   'Pokemon Omega Ruby/Pokemon Alpha Sapphire',
#   'Super Mario Land 2: 6 Golden Coins',
#   'Super Mario 3D Land',
#   'Super Mario All-Stars',
#   'Pokemon FireRed/Pokemon LeafGreen',
#   'New Super Mario Bros. 2',
#   'Animal Crossing: New Leaf',
#   'Super Mario Kart',
#   'Pokemon Black 2/Pokemon White 2',
#   'Pokémon Platinum Version',
#   'Pac-Man',
#   'Star Wars Battlefront (2015)',
#   'Crash Bandicoot 2: Cortex Strikes Back',
#   'Super Mario Bros. 2',
# ...

# %%
# Out:
#   File "<ipython-input-58-a7c8bd52d566>", line 2
#     print(len(x) + len(games_df)) e
#                                   ^
# SyntaxError: invalid syntax
