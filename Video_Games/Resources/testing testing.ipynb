# %%
import pandas as pd
df = pd.read_csv('../Resources/final_scrape.csv')

# %%
df
# Out:
#       Unnamed: 0                           Name metascore user_score  \
# 0              0                     Wii Sports    \n76\n        8.0
# 1              1                 Mario Kart Wii    \n82\n        8.4
# 2              2              Wii Sports Resort    \n80\n        8.1
# 3              3          New Super Mario Bros.    \n89\n        8.5
# 4              4                       Wii Play    \n58\n        6.5
# ...          ...                            ...       ...        ...
# 8411        8411            Mini Desktop Racing   \n2.3\n        2.3
# 8412        8412              PGA European Tour    \n58\n        8.0
# 8413        8413                Planet Monsters    \n67\n        tbd
# 8414        8414               Bust-A-Move 3000    \n53\n        tbd
# 8415        8415  Men in Black II: Alien Escape   \ntbd\n        tbd
#
#       release_date  positive_critics  neutral_critics  negative_critics  \
# ...
